# %%
import pandas as pd
import numpy as np
import random

# ============= تنظیمات GA و Leader Correction ============
POP_SIZE = 30
CROSSOVER_RATE = 0.8
MUTATION_RATE = 0.12
N_GENERATIONS = 50
ELITE_SIZE = 2
WINDOW_SIZE = 200

MODELS = ['PPPL', 'dSMA']
PARAM_BOUNDS = {
    'PPPL': {'n_SMA': (14, 20), 'd11': (0.05, 0.2), 'SL': (50, 150), 'TP': (50, 200)},
    'dSMA': {'n_SMA': (14, 20), 'd11': (0.05, 0.2), 'SL': (50, 150), 'TP': (50, 200)}
}

# ================= توابع محاسبات =================
def ValueATR(df, period):
    df['ValueATR'] = (df['High'] - df['Low']).rolling(window=period).mean()
    return df

def avgHL(df, period):
    df['avgHL'] = (df['High'] - df['Low']).rolling(window=period).mean()
    return df

def pp_pl(df, period):
    df['d'] = df['Close'] - df['Open']
    df['pp'] = df['d'].apply(lambda x: x if x > 0 else 0).rolling(period).mean()
    df['pl'] = df['d'].apply(lambda x: abs(x) if x < 0 else 0).rolling(period).mean()
    df['dP'] = abs(df['pp'] - df['pl']) / df[['pp', 'pl']].max(axis=1)
    return df

def DSMA(df, period):
    df['aa'] = df['Open']
    df['bb'] = df['Close'].rolling(period).mean()
    df['dSMA'] = df['aa'] - df['bb']
    df['dD'] = abs(df['dSMA']) / df[['aa', 'bb']].max(axis=1)
    return df

def Setup_Sell_Buy(flag_buy, flag_sell, Open, avgHL_val, wsp_Sl, wsp_Tp):
    dSl, dTp = avgHL_val * wsp_Sl, avgHL_val * wsp_Tp
    Sl, Tp = None, None
    if flag_buy == 1:
        Sl = Open - dSl
        Tp = Open + dTp
    elif flag_sell == 1:
        Sl = Open + dSl
        Tp = Open - dTp
    return Sl, Tp

# ================= بک‌تست با استفاده از iloc =================
def backtest_model(model_name, params, data):
    n_sma, d11, wsp_Sl, wsp_Tp = params
    df = data.copy()
    pp_pl(df, int(n_sma))
    DSMA(df, int(n_sma))
    ValueATR(df, int(n_sma))
    avgHL(df, int(n_sma))

    df['dd1'] = abs(df['dP'] - df['dD'])
    df['BSPower'] = df['dP']

    flag_buy, flag_sell = 0, 0
    net_profit, trades = 0, 0

    for i in range(1, len(df)):
        if 7 <= df['Hour'].iloc[i] < 19 and (flag_buy + flag_sell) == 0:
            if df['ValueATR'].iloc[i-1] > 0 and df['BSPower'].iloc[i-1] > 0:
                if model_name == 'PPPL' and df['dSMA'].iloc[i-1] > 0 and df['pp'].iloc[i-1] > df['pl'].iloc[i-1]:
                    flag_buy = 1
                    Sl, Tp = Setup_Sell_Buy(flag_buy, flag_sell, df['Open'].iloc[i], df['avgHL'].iloc[i-1], wsp_Sl, wsp_Tp)
                    trades += 1
                    if df['Low'].iloc[i] <= Sl:
                        net_profit += Sl - df['Open'].iloc[i]
                        flag_buy = 0
                    elif df['High'].iloc[i] >= Tp:
                        net_profit += Tp - df['Open'].iloc[i]
                        flag_buy = 0

                elif model_name == 'dSMA' and df['dSMA'].iloc[i-1] < 0 and df['pp'].iloc[i-1] < df['pl'].iloc[i-1]:
                    flag_sell = 1
                    Sl, Tp = Setup_Sell_Buy(flag_buy, flag_sell, df['Open'].iloc[i], df['avgHL'].iloc[i-1], wsp_Sl, wsp_Tp)
                    trades += 1
                    if df['High'].iloc[i] >= Sl:
                        net_profit += df['Open'].iloc[i] - Sl
                        flag_sell = 0
                    elif df['Low'].iloc[i] <= Tp:
                        net_profit += df['Open'].iloc[i] - Tp
                        flag_sell = 0

    net_profit *= 100000
    avg_profit = net_profit / trades if trades > 0 else 0
    avg_loss = abs(avg_profit * d11)
    profit_risk_ratio = avg_profit / avg_loss if avg_loss else 0
    equity_curve = df['Close'].cummax() - df['Close']
    drawdown = equity_curve.max() / df['Close'].max()
    return net_profit, profit_risk_ratio, drawdown

# ================= GA استاندارد =================
def initialize_population(bounds):
    return [[random.uniform(bounds[key][0], bounds[key][1]) for key in bounds] for _ in range(POP_SIZE)]

def evaluate_population(pop, objective_func):
    return [objective_func(ind) for ind in pop]

def tournament_selection(pop, scores, k=3):
    selected = []
    for _ in range(len(pop)):
        aspirants = random.sample(list(zip(pop, scores)), k)
        selected.append(max(aspirants, key=lambda x: x[1])[0])
    return selected

def crossover(p1, p2):
    if random.random() < CROSSOVER_RATE:
        point = random.randint(1, len(p1) - 1)
        return p1[:point] + p2[point:], p2[:point] + p1[point:]
    return p1, p2

def mutate(ind, bounds):
    for i, key in enumerate(bounds):
        if random.random() < MUTATION_RATE:
            ind[i] = random.uniform(bounds[key][0], bounds[key][1])
    return ind

def elitism_selection(pop, scores):
    elite_idx = np.argsort(scores)[-ELITE_SIZE:]
    return [pop[i] for i in elite_idx]

# ================= Leader Correction با ایندکس ریست‌شده =================
def genetic_algorithm_leader_correction(data):
    results = []
    for start in range(0, len(data) - WINDOW_SIZE, WINDOW_SIZE):
        window_data = data.iloc[start:start+WINDOW_SIZE].reset_index(drop=True)

        best_models, base_metrics, best_scores = {}, {}, {}
        for model in MODELS:
            bounds = PARAM_BOUNDS[model]
            pop = initialize_population(bounds)
            for _ in range(N_GENERATIONS):
                scores = evaluate_population(pop, lambda p: backtest_model(model, p, window_data)[0])
                elite = elitism_selection(pop, scores)
                selected = tournament_selection(pop, scores)
                children = []
                for i in range(0, POP_SIZE, 2):
                    c1, c2 = crossover(selected[i], selected[(i+1) % POP_SIZE])
                    children.append(mutate(c1, bounds))
                    children.append(mutate(c2, bounds))
                pop = elite + children[:POP_SIZE-ELITE_SIZE]
            final_scores = evaluate_population(pop, lambda p: backtest_model(model, p, window_data)[0])
            best_idx = np.argmax(final_scores)
            best_models[model] = pop[best_idx]
            best_scores[model] = final_scores[best_idx]
            base_metrics[model] = backtest_model(model, pop[best_idx], window_data)

        leader_model = max(best_scores, key=best_scores.get)
        leader_params = best_models[leader_model]
        net_profit, profit_risk, drawdown = base_metrics[leader_model]

        before_np = np.mean([m[0] for m in base_metrics.values()])
        before_pr = np.mean([m[1] for m in base_metrics.values()])
        before_dd = np.mean([m[2] for m in base_metrics.values()])

        results.append({
            'Window_Start': start,
            'Leader_Model': leader_model,
            'n_SMA': leader_params[0], 'd11': leader_params[1],
            'SL': leader_params[2], 'TP': leader_params[3],
            'Net_Profit': net_profit,
            'Profit/Risk': profit_risk,
            'Drawdown': drawdown,
            '%Improvement_NP': (net_profit - before_np) / abs(before_np) * 100 if before_np else 0,
            '%Improvement_PR': (profit_risk - before_pr) / abs(before_pr) * 100 if before_pr else 0,
            '%Improvement_DD': (before_dd - drawdown) / abs(before_dd) * 100 if before_dd else 0
        })
    return pd.DataFrame(results)

# ================= اجرای یک‌بار =================
if __name__ == "__main__":
    df_train = pd.read_csv("EURUSD_H4.csv")
    df_train['Date'] = pd.to_datetime(df_train['Date'])
    df_train['Hour'] = pd.to_datetime(df_train['Time'], format='%H:%M:%S').dt.hour

    df_test = pd.read_csv("USDCHF_H4.csv")
    df_test['Date'] = pd.to_datetime(df_test['Date'])
    df_test['Hour'] = pd.to_datetime(df_test['Time'], format='%H:%M:%S').dt.hour

    train_results = genetic_algorithm_leader_correction(df_train)
    train_results.to_excel("LC_results_train.xlsx", index=False)

    test_results = genetic_algorithm_leader_correction(df_test)
    test_results.to_excel("LC_results_test.xlsx", index=False)

    print("✅ خروجی‌ها ساخته شدند و ذخیره شدند.")
    print("فایل‌ها آماده: LC_results_train.xlsx و LC_results_test.xlsx")
# Out:
# ✅ خروجی‌ها ساخته شدند و ذخیره شدند.
# فایل‌ها آماده: LC_results_train.xlsx و LC_results_test.xlsx

# %%
import os
print(os.listdir('/content'))
# Out:
# ['.config', 'LC_results_train.xlsx', 'LC_results_test.xlsx', 'USDCHF_H4.csv', 'drive', 'EURUSD_H4.csv', 'sample_data']

# %%
from google.colab import files
files.download('LC_results_train.xlsx')
files.download('LC_results_test.xlsx')

# %%
import pandas as pd
import numpy as np

# ===== بک‌تست واقعی =====
def backtest_model(df, params, model_name):
    initial_capital = 10000
    lot_size = 0.1
    stop_loss_pips = float(params.get('SL', 90))
    take_profit_pips = float(params.get('TP', 130))

    equity = initial_capital
    peak_equity = initial_capital
    trades = []

    for i in range(1, len(df)):
        signal = None
        # نمونه ساده سیگنال؛ در پایان با منطق واقعی مدل جایگزین شود
        if float(df['Close'].iloc[i]) > float(df['Close'].iloc[i-1]):
            signal = 'BUY'
        elif float(df['Close'].iloc[i]) < float(df['Close'].iloc[i-1]):
            signal = 'SELL'

        if signal:
            entry_price = float(df['Close'].iloc[i])
            if signal == 'BUY':
                exit_price = entry_price + (take_profit_pips * 0.0001) \
                             if np.random.rand() > 0.5 else entry_price - (stop_loss_pips * 0.0001)
            else:
                exit_price = entry_price - (take_profit_pips * 0.0001) \
                             if np.random.rand() > 0.5 else entry_price + (stop_loss_pips * 0.0001)

            profit = (exit_price - entry_price) * (100000 * lot_size) if signal == 'BUY' \
                     else (entry_price - exit_price) * (100000 * lot_size)
            equity += profit
            trades.append(profit)
            peak_equity = max(peak_equity, equity)

    net_profit = equity - initial_capital
    if trades:
        if any(t < 0 for t in trades):
            profit_risk = np.mean([t for t in trades if t > 0]) / abs(np.mean([t for t in trades if t < 0]))
        else:
            profit_risk = np.inf
    else:
        profit_risk = 0
    drawdown = (peak_equity - equity) / peak_equity * 100

    return net_profit, profit_risk, drawdown

# ===== GA ساده =====
def ga_optimize(df, model_name, param_bounds):
    best_params = None
    best_score = -np.inf
    for _ in range(30):  # جمعیت نمونه
        candidate = {k: float(np.random.uniform(low, high)) for k, (low, high) in param_bounds.items()}
        npf, prr, dd = backtest_model(df, candidate, model_name)
        if npf > best_score:
            best_params = candidate
            best_score = npf
    return best_params

# ===== Leader Correction =====
def leader_correction(train_df, test_df, models, bounds, window_size=200):
    results_train = []
    results_test = []

    for start in range(0, len(train_df)-window_size, window_size):
        window = train_df.iloc[start:start+window_size].reset_index(drop=True)
        winners = {}
        for model in models:
            params = ga_optimize(window, model, bounds[model])
            npf, prr, dd = backtest_model(window, params, model)
            winners[model] = (npf, prr, dd, params)

        leader = max(winners, key=lambda m: winners[m][0])
        best_npf, best_prr, best_dd, best_params = winners[leader]

        # قبل از بهینه‌سازی
        base_npf, base_prr, base_dd = backtest_model(window, {k: float(v[0]) for k,v in bounds[leader].items()}, leader)

        results_train.append({
            'Window_Start': start,
            'Leader_Model': leader,
            **best_params,
            'Net_Profit': best_npf,
            'Profit/Risk': best_prr,
            'Drawdown': best_dd,
            '%Improvement_NP': ((best_npf - base_npf) / abs(base_npf) * 100) if base_npf != 0 else np.nan,
            '%Improvement_PR': ((best_prr - base_prr) / abs(base_prr) * 100) if base_prr != 0 else np.nan,
            '%Improvement_DD': ((base_dd - best_dd) / abs(base_dd) * 100) if base_dd != 0 else np.nan
        })

    # تست فقط با پارامترهای بهترین رهبر آموزش
    for res in results_train:
        npf, prr, dd = backtest_model(test_df, {k: float(res[k]) for k in bounds[res['Leader_Model']]}, res['Leader_Model'])
        results_test.append({
            **res,
            'Net_Profit': npf,
            'Profit/Risk': prr,
            'Drawdown': dd
        })

    return pd.DataFrame(results_train), pd.DataFrame(results_test)

# ===== اجرای اصلی =====
if __name__ == "__main__":
    train_df = pd.read_csv("USDCHF_H4.csv")
    test_df = pd.read_csv("USDCHF_H4_TesT.csv")

    models = ['PPPL', 'dSMA']
    bounds = {
        'PPPL': {'n_SMA': (14, 20), 'd11': (0.1, 0.3), 'SL': (80, 120), 'TP': (120, 150)},
        'dSMA': {'n_SMA': (10, 18), 'd11': (0.05, 0.2), 'SL': (70, 110), 'TP': (110, 140)}
    }

    res_train, res_test = leader_correction(train_df, test_df, models, bounds, window_size=200)

    res_train.to_excel("LC_results_train.xlsx", index=False)
    res_test.to_excel("LC_results_test.xlsx", index=False)

    print("✅ Files saved: LC_results_train.xlsx, LC_results_test.xlsx")
# Out:
# ✅ Files saved: LC_results_train.xlsx, LC_results_test.xlsx

# %%
from google.colab import files
files.download('LC_results_train.xlsx')
files.download('LC_results_test.xlsx')

# %%
import pandas as pd
import numpy as np

# ===== بک‌تسته =====
def backtest_model(df, params, model_name):
    initial_capital = 10000
    lot_size = 0.1
    stop_loss_pips = float(params.get('SL', 90))
    take_profit_pips = float(params.get('TP', 130))

    equity = initial_capital
    peak_equity = initial_capital
    trades = []

    for i in range(1, len(df)):
        signal = None
        # نمونه ساده سیگنال؛ منطق واقعی مدل را جایگزین کنید
        if float(df['Close'].iloc[i]) > float(df['Close'].iloc[i-1]):
            signal = 'BUY'
        elif float(df['Close'].iloc[i]) < float(df['Close'].iloc[i-1]):
            signal = 'SELL'

        if signal:
            entry_price = float(df['Close'].iloc[i])
            if signal == 'BUY':
                exit_price = entry_price + (take_profit_pips * 0.0001) \
                             if np.random.rand() > 0.5 else entry_price - (stop_loss_pips * 0.0001)
            else:
                exit_price = entry_price - (take_profit_pips * 0.0001) \
                             if np.random.rand() > 0.5 else entry_price + (stop_loss_pips * 0.0001)

            profit = (exit_price - entry_price) * (100000 * lot_size) if signal == 'BUY' \
                     else (entry_price - exit_price) * (100000 * lot_size)
            equity += profit
            trades.append(profit)
            peak_equity = max(peak_equity, equity)

    net_profit = equity - initial_capital
    if trades:
        if any(t < 0 for t in trades):
            profit_risk = np.mean([t for t in trades if t > 0]) / abs(np.mean([t for t in trades if t < 0]))
        else:
            profit_risk = np.inf
    else:
        profit_risk = 0
    drawdown = (peak_equity - equity) / peak_equity * 100

    return net_profit, profit_risk, drawdown

# ===== PSO ساده برای بهینه‌سازی پارامترها =====
def pso_optimize(df, model_name, param_bounds, pop_size=30, n_gen=50, w=0.7, c1=1.5, c2=1.5):
    dim = len(param_bounds)
    lb = np.array([v[0] for v in param_bounds.values()])
    ub = np.array([v[1] for v in param_bounds.values()])
    keys = list(param_bounds.keys())

    # مقداردهی اولیه ذرات و سرعت‌ها
    positions = np.random.uniform(low=lb, high=ub, size=(pop_size, dim))
    vmax = (ub - lb) * 0.2
    velocities = np.random.uniform(low=-vmax, high=vmax, size=(pop_size, dim))

    pbest_positions = positions.copy()
    pbest_scores = np.array([-np.inf] * pop_size)

    # ارزیابی اولیه ذرات
    for i in range(pop_size):
        params = {keys[j]: positions[i, j] for j in range(dim)}
        npf, _, _ = backtest_model(df, params, model_name)
        pbest_scores[i] = npf

    gbest_index = np.argmax(pbest_scores)
    gbest_position = pbest_positions[gbest_index].copy()
    gbest_score = pbest_scores[gbest_index]

    for gen in range(n_gen):
        for i in range(pop_size):
            r1, r2 = np.random.rand(dim), np.random.rand(dim)
            velocities[i] = (w * velocities[i] +
                             c1 * r1 * (pbest_positions[i] - positions[i]) +
                             c2 * r2 * (gbest_position - positions[i]))
            velocities[i] = np.clip(velocities[i], -vmax, vmax)

            positions[i] = positions[i] + velocities[i]
            positions[i] = np.clip(positions[i], lb, ub)

            params = {keys[j]: positions[i, j] for j in range(dim)}
            npf, _, _ = backtest_model(df, params, model_name)

            if npf > pbest_scores[i]:
                pbest_scores[i] = npf
                pbest_positions[i] = positions[i].copy()

                if npf > gbest_score:
                    gbest_score = npf
                    gbest_position = positions[i].copy()
        print(f"نسل {gen+1}/{n_gen} بهترین سود خالص: {gbest_score:.2f}")

    best_params = {keys[j]: gbest_position[j] for j in range(dim)}
    return best_params, gbest_score

# ===== Leader Correction با استفاده از PSO =====
def leader_correction_pso(train_df, test_df, models, bounds, window_size=200):
    results_train = []
    results_test = []

    for start in range(0, len(train_df) - window_size, window_size):
        window = train_df.iloc[start:start + window_size].reset_index(drop=True)
        winners = {}
        for model in models:
            params, score = pso_optimize(window, model, bounds[model])
            npf, prr, dd = backtest_model(window, params, model)
            winners[model] = (npf, prr, dd, params)

        leader = max(winners, key=lambda m: winners[m][0])
        best_npf, best_prr, best_dd, best_params = winners[leader]

        # محاسبه عملکرد پایه با پارامترهای حد پایین (یا میانگین) برای مقایسه
        base_params = {k: float(v[0]) for k, v in bounds[leader].items()}
        base_npf, base_prr, base_dd = backtest_model(window, base_params, leader)

        results_train.append({
            'Window_Start': start,
            'Leader_Model': leader,
            **best_params,
            'Net_Profit': best_npf,
            'Profit/Risk': best_prr,
            'Drawdown': best_dd,
            '%Improvement_NP': ((best_npf - base_npf) / abs(base_npf) * 100) if base_npf != 0 else np.nan,
            '%Improvement_PR': ((best_prr - base_prr) / abs(base_prr) * 100) if base_prr != 0 else np.nan,
            '%Improvement_DD': ((base_dd - best_dd) / abs(base_dd) * 100) if base_dd != 0 else np.nan
        })

    # تست بر اساس پارامترهای رهبر به دست آمده در هر پنجره
    for res in results_train:
        npf, prr, dd = backtest_model(test_df, {k: float(res[k]) for k in bounds[res['Leader_Model']]}, res['Leader_Model'])
        results_test.append({
            **res,
            'Net_Profit': npf,
            'Profit/Risk': prr,
            'Drawdown': dd
        })

    return pd.DataFrame(results_train), pd.DataFrame(results_test)


# ===== اجرای اصلی =====
if __name__ == "__main__":
    train_df = pd.read_csv("USDCHF_H4.csv")
    test_df = pd.read_csv("USDCHF_H4_TesT.csv")

    models = ['PPPL', 'dSMA']
    bounds = {
        'PPPL': {'n_SMA': (14, 20), 'd11': (0.1, 0.3), 'SL': (80, 120), 'TP': (120, 150)},
        'dSMA': {'n_SMA': (10, 18), 'd11': (0.05, 0.2), 'SL': (70, 110), 'TP': (110, 140)}
    }

    res_train, res_test = leader_correction_pso(train_df, test_df, models, bounds, window_size=200)

    res_train.to_excel("LC_results_train_PSO.xlsx", index=False)
    res_test.to_excel("LC_results_test_PSO.xlsx", index=False)

    print("✅ فایل‌ها ذخیره شدند: LC_results_train_PSO.xlsx, LC_results_test_PSO.xlsx")
# Out:
# نسل 1/50 بهترین سود خالص: 7741.14
# نسل 2/50 بهترین سود خالص: 9404.25
# نسل 3/50 بهترین سود خالص: 9840.00
# نسل 4/50 بهترین سود خالص: 9840.00
# نسل 5/50 بهترین سود خالص: 9840.00
# نسل 6/50 بهترین سود خالص: 9840.00
# نسل 7/50 بهترین سود خالص: 9840.00
# نسل 8/50 بهترین سود خالص: 9840.00
# نسل 9/50 بهترین سود خالص: 9840.00
# نسل 10/50 بهترین سود خالص: 10070.00
# نسل 11/50 بهترین سود خالص: 10760.00
# نسل 12/50 بهترین سود خالص: 10760.00
# نسل 13/50 بهترین سود خالص: 10760.00
# نسل 14/50 بهترین سود خالص: 10760.00
# نسل 15/50 بهترین سود خالص: 10760.00
# نسل 16/50 بهترین سود خالص: 10760.00
# نسل 17/50 بهترین سود خالص: 10760.00
# نسل 18/50 بهترین سود خالص: 10760.00
# نسل 19/50 بهترین سود خالص: 10760.00
# نسل 20/50 بهترین سود خالص: 10990.00
# نسل 21/50 بهترین سود خالص: 10990.00
# نسل 22/50 بهترین سود خالص: 11276.83
# نسل 23/50 بهترین سود خالص: 11276.83
# نسل 24/50 بهترین سود خالص: 11276.83
# نسل 25/50 بهترین سود خالص: 11276.83
# نسل 26/50 بهترین سود خالص: 11276.83
# نسل 27/50 بهترین سود خالص: 11276.83
# نسل 28/50 بهترین سود خالص: 11276.83
# نسل 29/50 بهترین سود خالص: 11276.83
# نسل 30/50 بهترین سود خالص: 11276.83
# نسل 31/50 بهترین سود خالص: 11276.83
# نسل 32/50 بهترین سود خالص: 11276.83
# نسل 33/50 بهترین سود خالص: 11276.83
# نسل 34/50 بهترین سود خالص: 11276.83
# نسل 35/50 بهترین سود خالص: 11653.59
# نسل 36/50 بهترین سود خالص: 11653.59
# نسل 37/50 بهترین سود خالص: 11653.59
# نسل 38/50 بهترین سود خالص: 11653.59
# نسل 39/50 بهترین سود خالص: 11653.59
# نسل 40/50 بهترین سود خالص: 11653.59
# نسل 41/50 بهترین سود خالص: 11653.59
# نسل 42/50 بهترین سود خالص: 11653.59
# نسل 43/50 بهترین سود خالص: 11653.59
# نسل 44/50 بهترین سود خالص: 11653.59
# نسل 45/50 بهترین سود خالص: 11653.59
# نسل 46/50 بهترین سود خالص: 11653.59
# نسل 47/50 بهترین سود خالص: 11653.59
# نسل 48/50 بهترین سود خالص: 11653.59
# نسل 49/50 بهترین سود خالص: 11653.59
# نسل 50/50 بهترین سود خالص: 11653.59
# نسل 1/50 بهترین سود خالص: 6853.20
# نسل 2/50 بهترین سود خالص: 7564.67
# نسل 3/50 بهترین سود خالص: 8311.29
# نسل 4/50 بهترین سود خالص: 8311.29
# نسل 5/50 بهترین سود خالص: 8311.29
# نسل 6/50 بهترین سود خالص: 10224.38
# نسل 7/50 بهترین سود خالص: 10224.38
# نسل 8/50 بهترین سود خالص: 10224.38
# نسل 9/50 بهترین سود خالص: 10224.38
# نسل 10/50 بهترین سود خالص: 10224.38
# نسل 11/50 بهترین سود خالص: 10224.38
# نسل 12/50 بهترین سود خالص: 10224.38
# نسل 13/50 بهترین سود خالص: 10224.38
# نسل 14/50 بهترین سود خالص: 10224.38
# نسل 15/50 بهترین سود خالص: 10224.38
# نسل 16/50 بهترین سود خالص: 10317.95
# نسل 17/50 بهترین سود خالص: 10317.95
# نسل 18/50 بهترین سود خالص: 10317.95
# نسل 19/50 بهترین سود خالص: 10317.95
# نسل 20/50 بهترین سود خالص: 10317.95
# نسل 21/50 بهترین سود خالص: 10317.95
# نسل 22/50 بهترین سود خالص: 10317.95
# نسل 23/50 بهترین سود خالص: 10317.95
# نسل 24/50 بهترین سود خالص: 10317.95
# نسل 25/50 بهترین سود خالص: 10317.95
# نسل 26/50 بهترین سود خالص: 10317.95
# نسل 27/50 بهترین سود خالص: 10317.95
# نسل 28/50 بهترین سود خالص: 10317.95
# نسل 29/50 بهترین سود خالص: 10317.95
# نسل 30/50 بهترین سود خالص: 10317.95
# نسل 31/50 بهترین سود خالص: 10317.95
# نسل 32/50 بهترین سود خالص: 10317.95
# نسل 33/50 بهترین سود خالص: 10317.95
# نسل 34/50 بهترین سود خالص: 10317.95
# نسل 35/50 بهترین سود خالص: 10317.95
# نسل 36/50 بهترین سود خالص: 10317.95
# نسل 37/50 بهترین سود خالص: 10317.95
# نسل 38/50 بهترین سود خالص: 10317.95
# نسل 39/50 بهترین سود خالص: 10317.95
# نسل 40/50 بهترین سود خالص: 10317.95
# نسل 41/50 بهترین سود خالص: 10317.95
# نسل 42/50 بهترین سود خالص: 10317.95
# نسل 43/50 بهترین سود خالص: 10317.95
# نسل 44/50 بهترین سود خالص: 10317.95
# نسل 45/50 بهترین سود خالص: 10317.95
# نسل 46/50 بهترین سود خالص: 10317.95
# نسل 47/50 بهترین سود خالص: 10317.95
# نسل 48/50 بهترین سود خالص: 10317.95
# نسل 49/50 بهترین سود خالص: 10317.95
# نسل 50/50 بهترین سود خالص: 10317.95
# نسل 1/50 بهترین سود خالص: 10013.74
# نسل 2/50 بهترین سود خالص: 10013.74
# نسل 3/50 بهترین سود خالص: 10013.74
# نسل 4/50 بهترین سود خالص: 10013.74
# نسل 5/50 بهترین سود خالص: 11036.04
# نسل 6/50 بهترین سود خالص: 11036.04
# نسل 7/50 بهترین سود خالص: 11036.04
# نسل 8/50 بهترین سود خالص: 11036.04
# نسل 9/50 بهترین سود خالص: 11036.04
# نسل 10/50 بهترین سود خالص: 11036.04
# نسل 11/50 بهترین سود خالص: 11036.04
# نسل 12/50 بهترین سود خالص: 11036.04
# نسل 13/50 بهترین سود خالص: 11036.04
# نسل 14/50 بهترین سود خالص: 11036.04
# نسل 15/50 بهترین سود خالص: 11036.04
# نسل 16/50 بهترین سود خالص: 11036.04
# نسل 17/50 بهترین سود خالص: 11036.04
# نسل 18/50 بهترین سود خالص: 11036.04
# نسل 19/50 بهترین سود خالص: 11036.04
# نسل 20/50 بهترین سود خالص: 11036.04
# نسل 21/50 بهترین سود خالص: 11036.04
# نسل 22/50 بهترین سود خالص: 11036.04
# نسل 23/50 بهترین سود خالص: 11036.04
# نسل 24/50 بهترین سود خالص: 11036.04
# نسل 25/50 بهترین سود خالص: 11036.04
# نسل 26/50 بهترین سود خالص: 11036.04
# نسل 27/50 بهترین سود خالص: 11036.04
# نسل 28/50 بهترین سود خالص: 11036.04
# نسل 29/50 بهترین سود خالص: 11036.04
# نسل 30/50 بهترین سود خالص: 11036.04
# نسل 31/50 بهترین سود خالص: 11036.04
# نسل 32/50 بهترین سود خالص: 11036.04
# نسل 33/50 بهترین سود خالص: 11036.04
# نسل 34/50 بهترین سود خالص: 11036.04
# نسل 35/50 بهترین سود خالص: 11036.04
# نسل 36/50 بهترین سود خالص: 11036.04
# نسل 37/50 بهترین سود خالص: 11036.04
# نسل 38/50 بهترین سود خالص: 11036.04
# نسل 39/50 بهترین سود خالص: 11036.04
# نسل 40/50 بهترین سود خالص: 11036.04
# نسل 41/50 بهترین سود خالص: 11036.04
# نسل 42/50 بهترین سود خالص: 11036.04
# نسل 43/50 بهترین سود خالص: 11036.04
# نسل 44/50 بهترین سود خالص: 11036.04
# نسل 45/50 بهترین سود خالص: 11036.04
# نسل 46/50 بهترین سود خالص: 11036.04
# نسل 47/50 بهترین سود خالص: 11036.04
# نسل 48/50 بهترین سود خالص: 11036.04
# نسل 49/50 بهترین سود خالص: 11036.04
# نسل 50/50 بهترین سود خالص: 11036.04
# نسل 1/50 بهترین سود خالص: 7229.51
# نسل 2/50 بهترین سود خالص: 7471.44
# نسل 3/50 بهترین سود خالص: 9304.81
# نسل 4/50 بهترین سود خالص: 10392.05
# نسل 5/50 بهترین سود خالص: 10824.41
# نسل 6/50 بهترین سود خالص: 10824.41
# نسل 7/50 بهترین سود خالص: 10824.41
# نسل 8/50 بهترین سود خالص: 10824.41
# نسل 9/50 بهترین سود خالص: 10824.41
# نسل 10/50 بهترین سود خالص: 10824.41
# نسل 11/50 بهترین سود خالص: 10824.41
# نسل 12/50 بهترین سود خالص: 10824.41
# نسل 13/50 بهترین سود خالص: 10824.41
# نسل 14/50 بهترین سود خالص: 10824.41
# نسل 15/50 بهترین سود خالص: 10824.41
# نسل 16/50 بهترین سود خالص: 10824.41
# نسل 17/50 بهترین سود خالص: 10824.41
# نسل 18/50 بهترین سود خالص: 10824.41
# نسل 19/50 بهترین سود خالص: 10824.41
# نسل 20/50 بهترین سود خالص: 10824.41
# نسل 21/50 بهترین سود خالص: 10824.41
# نسل 22/50 بهترین سود خالص: 10836.16
# نسل 23/50 بهترین سود خالص: 11029.19
# نسل 24/50 بهترین سود خالص: 11029.19
# نسل 25/50 بهترین سود خالص: 11029.19
# نسل 26/50 بهترین سود خالص: 11029.19
# نسل 27/50 بهترین سود خالص: 11029.19
# نسل 28/50 بهترین سود خالص: 11029.19
# نسل 29/50 بهترین سود خالص: 11029.19
# نسل 30/50 بهترین سود خالص: 11029.19
# نسل 31/50 بهترین سود خالص: 11029.19
# نسل 32/50 بهترین سود خالص: 11029.19
# نسل 33/50 بهترین سود خالص: 11029.19
# نسل 34/50 بهترین سود خالص: 11029.19
# نسل 35/50 بهترین سود خالص: 11270.00
# نسل 36/50 بهترین سود خالص: 11270.00
# نسل 37/50 بهترین سود خالص: 11270.00
# نسل 38/50 بهترین سود خالص: 11270.00
# نسل 39/50 بهترین سود خالص: 11270.00
# نسل 40/50 بهترین سود خالص: 11270.00
# نسل 41/50 بهترین سود خالص: 11270.00
# نسل 42/50 بهترین سود خالص: 11270.00
# نسل 43/50 بهترین سود خالص: 11270.00
# نسل 44/50 بهترین سود خالص: 11270.00
# نسل 45/50 بهترین سود خالص: 11270.00
# نسل 46/50 بهترین سود خالص: 11270.00
# نسل 47/50 بهترین سود خالص: 11270.00
# نسل 48/50 بهترین سود خالص: 11270.00
# نسل 49/50 بهترین سود خالص: 11270.00
# نسل 50/50 بهترین سود خالص: 11474.23
# نسل 1/50 بهترین سود خالص: 7168.26
# نسل 2/50 بهترین سود خالص: 9649.04
# نسل 3/50 بهترین سود خالص: 9649.04
# نسل 4/50 بهترین سود خالص: 9649.04
# نسل 5/50 بهترین سود خالص: 9649.04
# نسل 6/50 بهترین سود خالص: 9649.04
# نسل 7/50 بهترین سود خالص: 9649.04
# نسل 8/50 بهترین سود خالص: 9649.04
# نسل 9/50 بهترین سود خالص: 9649.04
# نسل 10/50 بهترین سود خالص: 9649.04
# نسل 11/50 بهترین سود خالص: 9955.97
# نسل 12/50 بهترین سود خالص: 9955.97
# نسل 13/50 بهترین سود خالص: 9955.97
# نسل 14/50 بهترین سود خالص: 9955.97
# نسل 15/50 بهترین سود خالص: 9955.97
# نسل 16/50 بهترین سود خالص: 9955.97
# نسل 17/50 بهترین سود خالص: 9955.97
# نسل 18/50 بهترین سود خالص: 9955.97
# نسل 19/50 بهترین سود خالص: 9955.97
# نسل 20/50 بهترین سود خالص: 9955.97
# نسل 21/50 بهترین سود خالص: 9955.97
# نسل 22/50 بهترین سود خالص: 9955.97
# نسل 23/50 بهترین سود خالص: 9955.97
# نسل 24/50 بهترین سود خالص: 9955.97
# نسل 25/50 بهترین سود خالص: 9955.97
# نسل 26/50 بهترین سود خالص: 9955.97
# نسل 27/50 بهترین سود خالص: 9955.97
# نسل 28/50 بهترین سود خالص: 9955.97
# نسل 29/50 بهترین سود خالص: 9955.97
# نسل 30/50 بهترین سود خالص: 9955.97
# نسل 31/50 بهترین سود خالص: 9955.97
# نسل 32/50 بهترین سود خالص: 9955.97
# نسل 33/50 بهترین سود خالص: 9955.97
# نسل 34/50 بهترین سود خالص: 9955.97
# نسل 35/50 بهترین سود خالص: 9955.97
# نسل 36/50 بهترین سود خالص: 10258.83
# نسل 37/50 بهترین سود خالص: 10258.83
# نسل 38/50 بهترین سود خالص: 10258.83
# نسل 39/50 بهترین سود خالص: 10258.83
# نسل 40/50 بهترین سود خالص: 10258.83
# نسل 41/50 بهترین سود خالص: 10321.64
# نسل 42/50 بهترین سود خالص: 10321.64
# نسل 43/50 بهترین سود خالص: 10321.64
# نسل 44/50 بهترین سود خالص: 10321.64
# نسل 45/50 بهترین سود خالص: 10321.64
# نسل 46/50 بهترین سود خالص: 10321.64
# نسل 47/50 بهترین سود خالص: 10321.64
# نسل 48/50 بهترین سود خالص: 10321.64
# نسل 49/50 بهترین سود خالص: 10321.64
# نسل 50/50 بهترین سود خالص: 10321.64
# نسل 1/50 بهترین سود خالص: 8925.95
# نسل 2/50 بهترین سود خالص: 8925.95
# نسل 3/50 بهترین سود خالص: 8925.95
# نسل 4/50 بهترین سود خالص: 9311.66
# نسل 5/50 بهترین سود خالص: 9311.66
# نسل 6/50 بهترین سود خالص: 9311.66
# نسل 7/50 بهترین سود خالص: 9311.66
# نسل 8/50 بهترین سود خالص: 9311.66
# نسل 9/50 بهترین سود خالص: 9311.66
# نسل 10/50 بهترین سود خالص: 9311.66
# نسل 11/50 بهترین سود خالص: 9476.45
# نسل 12/50 بهترین سود خالص: 9476.45
# نسل 13/50 بهترین سود خالص: 9476.45
# نسل 14/50 بهترین سود خالص: 9672.59
# نسل 15/50 بهترین سود خالص: 9672.59
# نسل 16/50 بهترین سود خالص: 10053.60
# نسل 17/50 بهترین سود خالص: 10053.60
# نسل 18/50 بهترین سود خالص: 10053.60
# نسل 19/50 بهترین سود خالص: 10053.60
# نسل 20/50 بهترین سود خالص: 10053.60
# نسل 21/50 بهترین سود خالص: 10053.60
# نسل 22/50 بهترین سود خالص: 10053.60
# نسل 23/50 بهترین سود خالص: 10053.60
# نسل 24/50 بهترین سود خالص: 10053.60
# نسل 25/50 بهترین سود خالص: 10053.60
# نسل 26/50 بهترین سود خالص: 10053.60
# نسل 27/50 بهترین سود خالص: 10053.60
# نسل 28/50 بهترین سود خالص: 10053.60
# نسل 29/50 بهترین سود خالص: 10053.60
# نسل 30/50 بهترین سود خالص: 10053.60
# نسل 31/50 بهترین سود خالص: 10468.82
# نسل 32/50 بهترین سود خالص: 10468.82
# نسل 33/50 بهترین سود خالص: 10468.82
# نسل 34/50 بهترین سود خالص: 11720.40
# نسل 35/50 بهترین سود خالص: 11720.40
# نسل 36/50 بهترین سود خالص: 11720.40
# نسل 37/50 بهترین سود خالص: 11720.40
# نسل 38/50 بهترین سود خالص: 11720.40
# نسل 39/50 بهترین سود خالص: 11720.40
# نسل 40/50 بهترین سود خالص: 11720.40
# نسل 41/50 بهترین سود خالص: 11720.40
# نسل 42/50 بهترین سود خالص: 11720.40
# نسل 43/50 بهترین سود خالص: 11720.40
# نسل 44/50 بهترین سود خالص: 11720.40
# نسل 45/50 بهترین سود خالص: 11720.40
# نسل 46/50 بهترین سود خالص: 11720.40
# نسل 47/50 بهترین سود خالص: 11720.40
# نسل 48/50 بهترین سود خالص: 11720.40
# نسل 49/50 بهترین سود خالص: 11720.40
# نسل 50/50 بهترین سود خالص: 12649.47
# نسل 1/50 بهترین سود خالص: 9350.81
# نسل 2/50 بهترین سود خالص: 9350.81
# نسل 3/50 بهترین سود خالص: 9840.41
# نسل 4/50 بهترین سود خالص: 9840.41
# نسل 5/50 بهترین سود خالص: 10146.85
# نسل 6/50 بهترین سود خالص: 10690.00
# نسل 7/50 بهترین سود خالص: 10690.00
# نسل 8/50 بهترین سود خالص: 10690.00
# نسل 9/50 بهترین سود خالص: 10690.00
# نسل 10/50 بهترین سود خالص: 10690.00
# نسل 11/50 بهترین سود خالص: 11150.00
# نسل 12/50 بهترین سود خالص: 11150.00
# نسل 13/50 بهترین سود خالص: 11150.00
# نسل 14/50 بهترین سود خالص: 11150.00
# نسل 15/50 بهترین سود خالص: 11150.00
# نسل 16/50 بهترین سود خالص: 11150.00
# نسل 17/50 بهترین سود خالص: 11150.00
# نسل 18/50 بهترین سود خالص: 11150.00
# نسل 19/50 بهترین سود خالص: 11280.90
# نسل 20/50 بهترین سود خالص: 11280.90
# نسل 21/50 بهترین سود خالص: 11280.90
# نسل 22/50 بهترین سود خالص: 11280.90
# نسل 23/50 بهترین سود خالص: 11280.90
# نسل 24/50 بهترین سود خالص: 11280.90
# نسل 25/50 بهترین سود خالص: 11280.90
# نسل 26/50 بهترین سود خالص: 11280.90
# نسل 27/50 بهترین سود خالص: 11280.90
# نسل 28/50 بهترین سود خالص: 11280.90
# نسل 29/50 بهترین سود خالص: 11280.90
# نسل 30/50 بهترین سود خالص: 11280.90
# نسل 31/50 بهترین سود خالص: 11280.90
# نسل 32/50 بهترین سود خالص: 11280.90
# نسل 33/50 بهترین سود خالص: 11280.90
# نسل 34/50 بهترین سود خالص: 11918.52
# نسل 35/50 بهترین سود خالص: 11918.52
# نسل 36/50 بهترین سود خالص: 11918.52
# نسل 37/50 بهترین سود خالص: 11918.52
# نسل 38/50 بهترین سود خالص: 11918.52
# نسل 39/50 بهترین سود خالص: 11918.52
# نسل 40/50 بهترین سود خالص: 12387.00
# نسل 41/50 بهترین سود خالص: 12387.00
# نسل 42/50 بهترین سود خالص: 12387.00
# نسل 43/50 بهترین سود خالص: 12387.00
# نسل 44/50 بهترین سود خالص: 12387.00
# نسل 45/50 بهترین سود خالص: 12387.00
# نسل 46/50 بهترین سود خالص: 12387.00
# نسل 47/50 بهترین سود خالص: 12387.00
# نسل 48/50 بهترین سود خالص: 12387.00
# نسل 49/50 بهترین سود خالص: 12387.00
# نسل 50/50 بهترین سود خالص: 12387.00
# نسل 1/50 بهترین سود خالص: 6793.35
# نسل 2/50 بهترین سود خالص: 6793.35
# نسل 3/50 بهترین سود خالص: 6793.35
# نسل 4/50 بهترین سود خالص: 6793.35
# نسل 5/50 بهترین سود خالص: 6793.35
# نسل 6/50 بهترین سود خالص: 6827.97
# نسل 7/50 بهترین سود خالص: 6827.97
# نسل 8/50 بهترین سود خالص: 6827.97
# نسل 9/50 بهترین سود خالص: 7155.35
# نسل 10/50 بهترین سود خالص: 7155.35
# نسل 11/50 بهترین سود خالص: 7155.35
# نسل 12/50 بهترین سود خالص: 7155.35
# نسل 13/50 بهترین سود خالص: 7155.35
# نسل 14/50 بهترین سود خالص: 7155.35
# نسل 15/50 بهترین سود خالص: 7155.35
# نسل 16/50 بهترین سود خالص: 7155.35
# نسل 17/50 بهترین سود خالص: 7155.35
# نسل 18/50 بهترین سود خالص: 7155.35
# نسل 19/50 بهترین سود خالص: 7155.35
# نسل 20/50 بهترین سود خالص: 7155.35
# نسل 21/50 بهترین سود خالص: 7155.35
# نسل 22/50 بهترین سود خالص: 7875.48
# نسل 23/50 بهترین سود خالص: 7875.48
# نسل 24/50 بهترین سود خالص: 7875.48
# نسل 25/50 بهترین سود خالص: 7875.48
# نسل 26/50 بهترین سود خالص: 7875.48
# نسل 27/50 بهترین سود خالص: 7875.48
# نسل 28/50 بهترین سود خالص: 7875.48
# نسل 29/50 بهترین سود خالص: 7875.48
# نسل 30/50 بهترین سود خالص: 7875.48
# نسل 31/50 بهترین سود خالص: 7875.48
# نسل 32/50 بهترین سود خالص: 7875.48
# نسل 33/50 بهترین سود خالص: 7875.48
# نسل 34/50 بهترین سود خالص: 7875.48
# نسل 35/50 بهترین سود خالص: 7875.48
# نسل 36/50 بهترین سود خالص: 7875.48
# نسل 37/50 بهترین سود خالص: 7875.48
# نسل 38/50 بهترین سود خالص: 7875.48
# نسل 39/50 بهترین سود خالص: 7875.48
# نسل 40/50 بهترین سود خالص: 7875.48
# نسل 41/50 بهترین سود خالص: 7875.48
# نسل 42/50 بهترین سود خالص: 8086.08
# نسل 43/50 بهترین سود خالص: 9737.49
# نسل 44/50 بهترین سود خالص: 9737.49
# نسل 45/50 بهترین سود خالص: 9737.49
# نسل 46/50 بهترین سود خالص: 9737.49
# نسل 47/50 بهترین سود خالص: 9737.49
# نسل 48/50 بهترین سود خالص: 9737.49
# نسل 49/50 بهترین سود خالص: 9737.49
# نسل 50/50 بهترین سود خالص: 9737.49
# نسل 1/50 بهترین سود خالص: 8265.93
# نسل 2/50 بهترین سود خالص: 8453.22
# نسل 3/50 بهترین سود خالص: 8453.22
# نسل 4/50 بهترین سود خالص: 8453.22
# نسل 5/50 بهترین سود خالص: 9777.45
# نسل 6/50 بهترین سود خالص: 9777.45
# نسل 7/50 بهترین سود خالص: 9777.45
# نسل 8/50 بهترین سود خالص: 9777.45
# نسل 9/50 بهترین سود خالص: 9777.45
# نسل 10/50 بهترین سود خالص: 9777.45
# نسل 11/50 بهترین سود خالص: 9777.45
# نسل 12/50 بهترین سود خالص: 9777.45
# نسل 13/50 بهترین سود خالص: 9777.45
# نسل 14/50 بهترین سود خالص: 9777.45
# نسل 15/50 بهترین سود خالص: 9777.45
# نسل 16/50 بهترین سود خالص: 9777.45
# نسل 17/50 بهترین سود خالص: 9777.45
# نسل 18/50 بهترین سود خالص: 9777.45
# نسل 19/50 بهترین سود خالص: 9777.45
# نسل 20/50 بهترین سود خالص: 9777.45
# نسل 21/50 بهترین سود خالص: 9777.45
# نسل 22/50 بهترین سود خالص: 9777.45
# نسل 23/50 بهترین سود خالص: 9777.45
# نسل 24/50 بهترین سود خالص: 9777.45
# نسل 25/50 بهترین سود خالص: 9777.45
# نسل 26/50 بهترین سود خالص: 9777.45
# نسل 27/50 بهترین سود خالص: 9777.45
# نسل 28/50 بهترین سود خالص: 9777.45
# نسل 29/50 بهترین سود خالص: 9777.45
# نسل 30/50 بهترین سود خالص: 9777.45
# نسل 31/50 بهترین سود خالص: 9777.45
# نسل 32/50 بهترین سود خالص: 9777.45
# نسل 33/50 بهترین سود خالص: 9777.45
# نسل 34/50 بهترین سود خالص: 9777.45
# نسل 35/50 بهترین سود خالص: 9777.45
# نسل 36/50 بهترین سود خالص: 9777.45
# نسل 37/50 بهترین سود خالص: 9777.45
# نسل 38/50 بهترین سود خالص: 10835.51
# نسل 39/50 بهترین سود خالص: 10835.51
# نسل 40/50 بهترین سود خالص: 10835.51
# نسل 41/50 بهترین سود خالص: 10835.51
# نسل 42/50 بهترین سود خالص: 10835.51
# نسل 43/50 بهترین سود خالص: 10835.51
# نسل 44/50 بهترین سود خالص: 10835.51
# نسل 45/50 بهترین سود خالص: 10835.51
# نسل 46/50 بهترین سود خالص: 10835.51
# نسل 47/50 بهترین سود خالص: 10835.51
# نسل 48/50 بهترین سود خالص: 10835.51
# نسل 49/50 بهترین سود خالص: 10835.51
# نسل 50/50 بهترین سود خالص: 10835.51
# نسل 1/50 بهترین سود خالص: 7240.26
# نسل 2/50 بهترین سود خالص: 9271.19
# نسل 3/50 بهترین سود خالص: 9271.19
# نسل 4/50 بهترین سود خالص: 9271.19
# نسل 5/50 بهترین سود خالص: 9271.19
# نسل 6/50 بهترین سود خالص: 9271.19
# نسل 7/50 بهترین سود خالص: 9271.19
# نسل 8/50 بهترین سود خالص: 9595.01
# نسل 9/50 بهترین سود خالص: 9595.01
# نسل 10/50 بهترین سود خالص: 9595.01
# نسل 11/50 بهترین سود خالص: 9595.01
# نسل 12/50 بهترین سود خالص: 9595.01
# نسل 13/50 بهترین سود خالص: 9595.01
# نسل 14/50 بهترین سود خالص: 9595.01
# نسل 15/50 بهترین سود خالص: 9595.01
# نسل 16/50 بهترین سود خالص: 9595.01
# نسل 17/50 بهترین سود خالص: 10084.51
# نسل 18/50 بهترین سود خالص: 10084.51
# نسل 19/50 بهترین سود خالص: 10084.51
# نسل 20/50 بهترین سود خالص: 10084.51
# نسل 21/50 بهترین سود خالص: 10084.51
# نسل 22/50 بهترین سود خالص: 10084.51
# نسل 23/50 بهترین سود خالص: 10084.51
# نسل 24/50 بهترین سود خالص: 10084.51
# نسل 25/50 بهترین سود خالص: 10084.51
# نسل 26/50 بهترین سود خالص: 10330.54
# نسل 27/50 بهترین سود خالص: 10330.54
# نسل 28/50 بهترین سود خالص: 10330.54
# نسل 29/50 بهترین سود خالص: 10330.54
# نسل 30/50 بهترین سود خالص: 10330.54
# نسل 31/50 بهترین سود خالص: 10330.54
# نسل 32/50 بهترین سود خالص: 10330.54
# نسل 33/50 بهترین سود خالص: 10330.54
# نسل 34/50 بهترین سود خالص: 10330.54
# نسل 35/50 بهترین سود خالص: 10330.54
# نسل 36/50 بهترین سود خالص: 10330.54
# نسل 37/50 بهترین سود خالص: 10330.54
# نسل 38/50 بهترین سود خالص: 10330.54
# نسل 39/50 بهترین سود خالص: 10330.54
# نسل 40/50 بهترین سود خالص: 10330.54
# نسل 41/50 بهترین سود خالص: 10330.54
# نسل 42/50 بهترین سود خالص: 10330.54
# نسل 43/50 بهترین سود خالص: 10330.54
# نسل 44/50 بهترین سود خالص: 10330.54
# نسل 45/50 بهترین سود خالص: 10330.54
# نسل 46/50 بهترین سود خالص: 10330.54
# نسل 47/50 بهترین سود خالص: 10330.54
# نسل 48/50 بهترین سود خالص: 10330.54
# نسل 49/50 بهترین سود خالص: 10330.54
# نسل 50/50 بهترین سود خالص: 10330.54
# نسل 1/50 بهترین سود خالص: 8162.12
# نسل 2/50 بهترین سود خالص: 8162.12
# نسل 3/50 بهترین سود خالص: 8214.97
# نسل 4/50 بهترین سود خالص: 8214.97
# نسل 5/50 بهترین سود خالص: 8214.97
# نسل 6/50 بهترین سود خالص: 8435.33
# نسل 7/50 بهترین سود خالص: 9086.94
# نسل 8/50 بهترین سود خالص: 9086.94
# نسل 9/50 بهترین سود خالص: 9086.94
# نسل 10/50 بهترین سود خالص: 9086.94
# نسل 11/50 بهترین سود خالص: 9086.94
# نسل 12/50 بهترین سود خالص: 9086.94
# نسل 13/50 بهترین سود خالص: 9086.94
# نسل 14/50 بهترین سود خالص: 9086.94
# نسل 15/50 بهترین سود خالص: 9086.94
# نسل 16/50 بهترین سود خالص: 9086.94
# نسل 17/50 بهترین سود خالص: 9086.94
# نسل 18/50 بهترین سود خالص: 9086.94
# نسل 19/50 بهترین سود خالص: 9086.94
# نسل 20/50 بهترین سود خالص: 9086.94
# نسل 21/50 بهترین سود خالص: 9474.49
# نسل 22/50 بهترین سود خالص: 11286.64
# نسل 23/50 بهترین سود خالص: 11502.87
# نسل 24/50 بهترین سود خالص: 11502.87
# نسل 25/50 بهترین سود خالص: 11502.87
# نسل 26/50 بهترین سود خالص: 11502.87
# نسل 27/50 بهترین سود خالص: 11502.87
# نسل 28/50 بهترین سود خالص: 11502.87
# نسل 29/50 بهترین سود خالص: 11502.87
# نسل 30/50 بهترین سود خالص: 11502.87
# نسل 31/50 بهترین سود خالص: 11502.87
# نسل 32/50 بهترین سود خالص: 11502.87
# نسل 33/50 بهترین سود خالص: 11502.87
# نسل 34/50 بهترین سود خالص: 11502.87
# نسل 35/50 بهترین سود خالص: 11502.87
# نسل 36/50 بهترین سود خالص: 11502.87
# نسل 37/50 بهترین سود خالص: 11502.87
# نسل 38/50 بهترین سود خالص: 11502.87
# نسل 39/50 بهترین سود خالص: 11502.87
# نسل 40/50 بهترین سود خالص: 11502.87
# نسل 41/50 بهترین سود خالص: 11502.87
# نسل 42/50 بهترین سود خالص: 11502.87
# نسل 43/50 بهترین سود خالص: 11502.87
# نسل 44/50 بهترین سود خالص: 11502.87
# نسل 45/50 بهترین سود خالص: 11502.87
# نسل 46/50 بهترین سود خالص: 11502.87
# نسل 47/50 بهترین سود خالص: 11502.87
# نسل 48/50 بهترین سود خالص: 11502.87
# نسل 49/50 بهترین سود خالص: 11502.87
# نسل 50/50 بهترین سود خالص: 11502.87
# نسل 1/50 بهترین سود خالص: 9201.78
# نسل 2/50 بهترین سود خالص: 9201.78
# نسل 3/50 بهترین سود خالص: 9201.78
# نسل 4/50 بهترین سود خالص: 9865.46
# نسل 5/50 بهترین سود خالص: 9865.46
# نسل 6/50 بهترین سود خالص: 10710.00
# نسل 7/50 بهترین سود خالص: 10710.00
# نسل 8/50 بهترین سود خالص: 10710.00
# نسل 9/50 بهترین سود خالص: 10710.00
# نسل 10/50 بهترین سود خالص: 10710.00
# نسل 11/50 بهترین سود خالص: 10901.63
# نسل 12/50 بهترین سود خالص: 10901.63
# نسل 13/50 بهترین سود خالص: 10901.63
# نسل 14/50 بهترین سود خالص: 10901.63
# نسل 15/50 بهترین سود خالص: 10901.63
# نسل 16/50 بهترین سود خالص: 10901.63
# نسل 17/50 بهترین سود خالص: 10901.63
# نسل 18/50 بهترین سود خالص: 10901.63
# نسل 19/50 بهترین سود خالص: 10901.63
# نسل 20/50 بهترین سود خالص: 10901.63
# نسل 21/50 بهترین سود خالص: 10901.63
# نسل 22/50 بهترین سود خالص: 10901.63
# نسل 23/50 بهترین سود خالص: 10901.63
# نسل 24/50 بهترین سود خالص: 10901.63
# نسل 25/50 بهترین سود خالص: 10901.63
# نسل 26/50 بهترین سود خالص: 10901.63
# نسل 27/50 بهترین سود خالص: 10901.63
# نسل 28/50 بهترین سود خالص: 10901.63
# نسل 29/50 بهترین سود خالص: 10901.63
# نسل 30/50 بهترین سود خالص: 10901.63
# نسل 31/50 بهترین سود خالص: 10901.63
# نسل 32/50 بهترین سود خالص: 10901.63
# نسل 33/50 بهترین سود خالص: 10901.63
# نسل 34/50 بهترین سود خالص: 11334.31
# نسل 35/50 بهترین سود خالص: 11334.31
# نسل 36/50 بهترین سود خالص: 11334.31
# نسل 37/50 بهترین سود خالص: 11334.31
# نسل 38/50 بهترین سود خالص: 11334.31
# نسل 39/50 بهترین سود خالص: 11334.31
# نسل 40/50 بهترین سود خالص: 11334.31
# نسل 41/50 بهترین سود خالص: 11334.31
# نسل 42/50 بهترین سود خالص: 11334.31
# نسل 43/50 بهترین سود خالص: 11334.31
# نسل 44/50 بهترین سود خالص: 11334.31
# نسل 45/50 بهترین سود خالص: 11334.31
# نسل 46/50 بهترین سود خالص: 11334.31
# نسل 47/50 بهترین سود خالص: 11334.31
# نسل 48/50 بهترین سود خالص: 11334.31
# نسل 49/50 بهترین سود خالص: 11334.31
# نسل 50/50 بهترین سود خالص: 11334.31
# نسل 1/50 بهترین سود خالص: 8029.62
# نسل 2/50 بهترین سود خالص: 8412.28
# نسل 3/50 بهترین سود خالص: 8412.28
# نسل 4/50 بهترین سود خالص: 8572.74
# نسل 5/50 بهترین سود خالص: 9257.07
# نسل 6/50 بهترین سود خالص: 9257.07
# نسل 7/50 بهترین سود خالص: 9257.07
# نسل 8/50 بهترین سود خالص: 9866.89
# نسل 9/50 بهترین سود خالص: 9866.89
# نسل 10/50 بهترین سود خالص: 9866.89
# نسل 11/50 بهترین سود خالص: 9866.89
# نسل 12/50 بهترین سود خالص: 9866.89
# نسل 13/50 بهترین سود خالص: 9866.89
# نسل 14/50 بهترین سود خالص: 9866.89
# نسل 15/50 بهترین سود خالص: 9866.89
# نسل 16/50 بهترین سود خالص: 10961.09
# نسل 17/50 بهترین سود خالص: 10961.09
# نسل 18/50 بهترین سود خالص: 10961.09
# نسل 19/50 بهترین سود خالص: 10961.09
# نسل 20/50 بهترین سود خالص: 10961.09
# نسل 21/50 بهترین سود خالص: 10961.09
# نسل 22/50 بهترین سود خالص: 10961.09
# نسل 23/50 بهترین سود خالص: 10961.09
# نسل 24/50 بهترین سود خالص: 10961.09
# نسل 25/50 بهترین سود خالص: 10961.09
# نسل 26/50 بهترین سود خالص: 10961.09
# نسل 27/50 بهترین سود خالص: 10961.09
# نسل 28/50 بهترین سود خالص: 10961.09
# نسل 29/50 بهترین سود خالص: 10961.09
# نسل 30/50 بهترین سود خالص: 10961.09
# نسل 31/50 بهترین سود خالص: 10961.09
# نسل 32/50 بهترین سود خالص: 10961.09
# نسل 33/50 بهترین سود خالص: 10961.09
# نسل 34/50 بهترین سود خالص: 10961.09
# نسل 35/50 بهترین سود خالص: 10961.09
# نسل 36/50 بهترین سود خالص: 11685.67
# نسل 37/50 بهترین سود خالص: 11685.67
# نسل 38/50 بهترین سود خالص: 11685.67
# نسل 39/50 بهترین سود خالص: 11685.67
# نسل 40/50 بهترین سود خالص: 11685.67
# نسل 41/50 بهترین سود خالص: 11685.67
# نسل 42/50 بهترین سود خالص: 11685.67
# نسل 43/50 بهترین سود خالص: 11685.67
# نسل 44/50 بهترین سود خالص: 11685.67
# نسل 45/50 بهترین سود خالص: 11685.67
# نسل 46/50 بهترین سود خالص: 11685.67
# نسل 47/50 بهترین سود خالص: 11685.67
# نسل 48/50 بهترین سود خالص: 11685.67
# نسل 49/50 بهترین سود خالص: 11685.67
# نسل 50/50 بهترین سود خالص: 11685.67
# نسل 1/50 بهترین سود خالص: 8799.29
# نسل 2/50 بهترین سود خالص: 9341.48
# نسل 3/50 بهترین سود خالص: 9341.48
# نسل 4/50 بهترین سود خالص: 9341.48
# نسل 5/50 بهترین سود خالص: 9341.48
# نسل 6/50 بهترین سود خالص: 9341.48
# نسل 7/50 بهترین سود خالص: 9341.48
# نسل 8/50 بهترین سود خالص: 9341.48
# نسل 9/50 بهترین سود خالص: 9341.48
# نسل 10/50 بهترین سود خالص: 9341.48
# نسل 11/50 بهترین سود خالص: 9341.48
# نسل 12/50 بهترین سود خالص: 9341.48
# نسل 13/50 بهترین سود خالص: 9341.48
# نسل 14/50 بهترین سود خالص: 9341.48
# نسل 15/50 بهترین سود خالص: 9341.48
# نسل 16/50 بهترین سود خالص: 9341.48
# نسل 17/50 بهترین سود خالص: 9341.48
# نسل 18/50 بهترین سود خالص: 9341.48
# نسل 19/50 بهترین سود خالص: 9341.48
# نسل 20/50 بهترین سود خالص: 9341.48
# نسل 21/50 بهترین سود خالص: 9341.48
# نسل 22/50 بهترین سود خالص: 9341.48
# نسل 23/50 بهترین سود خالص: 9341.48
# نسل 24/50 بهترین سود خالص: 9341.48
# نسل 25/50 بهترین سود خالص: 9341.48
# نسل 26/50 بهترین سود خالص: 9341.48
# نسل 27/50 بهترین سود خالص: 9341.48
# نسل 28/50 بهترین سود خالص: 9341.48
# نسل 29/50 بهترین سود خالص: 9341.48
# نسل 30/50 بهترین سود خالص: 9341.48
# نسل 31/50 بهترین سود خالص: 9341.48
# نسل 32/50 بهترین سود خالص: 9341.48
# نسل 33/50 بهترین سود خالص: 9341.48
# نسل 34/50 بهترین سود خالص: 9341.48
# نسل 35/50 بهترین سود خالص: 9341.48
# نسل 36/50 بهترین سود خالص: 9341.48
# نسل 37/50 بهترین سود خالص: 9341.48
# نسل 38/50 بهترین سود خالص: 9341.48
# نسل 39/50 بهترین سود خالص: 9341.48
# نسل 40/50 بهترین سود خالص: 9544.24
# نسل 41/50 بهترین سود خالص: 9544.24
# نسل 42/50 بهترین سود خالص: 9544.24
# نسل 43/50 بهترین سود خالص: 9653.06
# نسل 44/50 بهترین سود خالص: 9653.06
# نسل 45/50 بهترین سود خالص: 9653.06
# نسل 46/50 بهترین سود خالص: 9653.06
# نسل 47/50 بهترین سود خالص: 9653.06
# نسل 48/50 بهترین سود خالص: 9653.06
# نسل 49/50 بهترین سود خالص: 9653.06
# نسل 50/50 بهترین سود خالص: 9653.06
# نسل 1/50 بهترین سود خالص: 7696.78
# نسل 2/50 بهترین سود خالص: 8938.81
# نسل 3/50 بهترین سود خالص: 8938.81
# نسل 4/50 بهترین سود خالص: 8938.81
# نسل 5/50 بهترین سود خالص: 8938.81
# نسل 6/50 بهترین سود خالص: 8938.81
# نسل 7/50 بهترین سود خالص: 8938.81
# نسل 8/50 بهترین سود خالص: 8938.81
# نسل 9/50 بهترین سود خالص: 8938.81
# نسل 10/50 بهترین سود خالص: 8938.81
# نسل 11/50 بهترین سود خالص: 8938.81
# نسل 12/50 بهترین سود خالص: 8938.81
# نسل 13/50 بهترین سود خالص: 8938.81
# نسل 14/50 بهترین سود خالص: 8938.81
# نسل 15/50 بهترین سود خالص: 8938.81
# نسل 16/50 بهترین سود خالص: 8938.81
# نسل 17/50 بهترین سود خالص: 8938.81
# نسل 18/50 بهترین سود خالص: 8938.81
# نسل 19/50 بهترین سود خالص: 8938.81
# نسل 20/50 بهترین سود خالص: 8938.81
# نسل 21/50 بهترین سود خالص: 8938.81
# نسل 22/50 بهترین سود خالص: 8938.81
# نسل 23/50 بهترین سود خالص: 8938.81
# نسل 24/50 بهترین سود خالص: 8938.81
# نسل 25/50 بهترین سود خالص: 8938.81
# نسل 26/50 بهترین سود خالص: 8938.81
# نسل 27/50 بهترین سود خالص: 8938.81
# نسل 28/50 بهترین سود خالص: 8938.81
# نسل 29/50 بهترین سود خالص: 8938.81
# نسل 30/50 بهترین سود خالص: 8938.81
# نسل 31/50 بهترین سود خالص: 8938.81
# نسل 32/50 بهترین سود خالص: 8938.81
# نسل 33/50 بهترین سود خالص: 8938.81
# نسل 34/50 بهترین سود خالص: 8938.81
# نسل 35/50 بهترین سود خالص: 8938.81
# نسل 36/50 بهترین سود خالص: 8938.81
# نسل 37/50 بهترین سود خالص: 8938.81
# نسل 38/50 بهترین سود خالص: 8938.81
# نسل 39/50 بهترین سود خالص: 8938.81
# نسل 40/50 بهترین سود خالص: 8938.81
# نسل 41/50 بهترین سود خالص: 8938.81
# نسل 42/50 بهترین سود خالص: 8938.81
# نسل 43/50 بهترین سود خالص: 8938.81
# نسل 44/50 بهترین سود خالص: 8938.81
# نسل 45/50 بهترین سود خالص: 8938.81
# نسل 46/50 بهترین سود خالص: 8938.81
# نسل 47/50 بهترین سود خالص: 8938.81
# نسل 48/50 بهترین سود خالص: 8938.81
# نسل 49/50 بهترین سود خالص: 8938.81
# نسل 50/50 بهترین سود خالص: 8938.81
# نسل 1/50 بهترین سود خالص: 9173.53
# نسل 2/50 بهترین سود خالص: 9173.53
# نسل 3/50 بهترین سود خالص: 9173.53
# نسل 4/50 بهترین سود خالص: 9173.53
# نسل 5/50 بهترین سود خالص: 9173.53
# نسل 6/50 بهترین سود خالص: 9180.78
# نسل 7/50 بهترین سود خالص: 9927.76
# نسل 8/50 بهترین سود خالص: 10296.16
# نسل 9/50 بهترین سود خالص: 10523.45
# نسل 10/50 بهترین سود خالص: 10570.00
# نسل 11/50 بهترین سود خالص: 10570.00
# نسل 12/50 بهترین سود خالص: 10570.00
# نسل 13/50 بهترین سود خالص: 10570.00
# نسل 14/50 بهترین سود خالص: 10570.00
# نسل 15/50 بهترین سود خالص: 10570.00
# نسل 16/50 بهترین سود خالص: 10570.00
# نسل 17/50 بهترین سود خالص: 10990.00
# نسل 18/50 بهترین سود خالص: 10990.00
# نسل 19/50 بهترین سود خالص: 10990.00
# نسل 20/50 بهترین سود خالص: 10990.00
# نسل 21/50 بهترین سود خالص: 10990.00
# نسل 22/50 بهترین سود خالص: 10990.00
# نسل 23/50 بهترین سود خالص: 10990.00
# نسل 24/50 بهترین سود خالص: 10990.00
# نسل 25/50 بهترین سود خالص: 10990.00
# نسل 26/50 بهترین سود خالص: 10990.00
# نسل 27/50 بهترین سود خالص: 10990.00
# نسل 28/50 بهترین سود خالص: 10990.00
# نسل 29/50 بهترین سود خالص: 10990.00
# نسل 30/50 بهترین سود خالص: 10990.00
# نسل 31/50 بهترین سود خالص: 10990.00
# نسل 32/50 بهترین سود خالص: 10990.00
# نسل 33/50 بهترین سود خالص: 10990.00
# نسل 34/50 بهترین سود خالص: 10990.00
# نسل 35/50 بهترین سود خالص: 10990.00
# نسل 36/50 بهترین سود خالص: 10990.00
# نسل 37/50 بهترین سود خالص: 10990.00
# نسل 38/50 بهترین سود خالص: 10990.00
# نسل 39/50 بهترین سود خالص: 10990.00
# نسل 40/50 بهترین سود خالص: 10990.00
# نسل 41/50 بهترین سود خالص: 10990.00
# نسل 42/50 بهترین سود خالص: 10990.00
# نسل 43/50 بهترین سود خالص: 10990.00
# نسل 44/50 بهترین سود خالص: 10990.00
# نسل 45/50 بهترین سود خالص: 10990.00
# نسل 46/50 بهترین سود خالص: 10990.00
# نسل 47/50 بهترین سود خالص: 10990.00
# نسل 48/50 بهترین سود خالص: 10990.00
# نسل 49/50 بهترین سود خالص: 10990.00
# نسل 50/50 بهترین سود خالص: 10990.00
# نسل 1/50 بهترین سود خالص: 6889.41
# نسل 2/50 بهترین سود خالص: 8083.29
# نسل 3/50 بهترین سود خالص: 8106.17
# نسل 4/50 بهترین سود خالص: 9580.71
# نسل 5/50 بهترین سود خالص: 9580.71
# نسل 6/50 بهترین سود خالص: 9580.71
# نسل 7/50 بهترین سود خالص: 10229.31
# نسل 8/50 بهترین سود خالص: 10229.31
# نسل 9/50 بهترین سود خالص: 10229.31
# نسل 10/50 بهترین سود خالص: 10229.31
# نسل 11/50 بهترین سود خالص: 10229.31
# نسل 12/50 بهترین سود خالص: 10229.31
# نسل 13/50 بهترین سود خالص: 10229.31
# نسل 14/50 بهترین سود خالص: 10229.31
# نسل 15/50 بهترین سود خالص: 10229.31
# نسل 16/50 بهترین سود خالص: 10229.31
# نسل 17/50 بهترین سود خالص: 10229.31
# نسل 18/50 بهترین سود خالص: 10229.31
# نسل 19/50 بهترین سود خالص: 10229.31
# نسل 20/50 بهترین سود خالص: 10229.31
# نسل 21/50 بهترین سود خالص: 10229.31
# نسل 22/50 بهترین سود خالص: 10229.31
# نسل 23/50 بهترین سود خالص: 10229.31
# نسل 24/50 بهترین سود خالص: 10229.31
# نسل 25/50 بهترین سود خالص: 10229.31
# نسل 26/50 بهترین سود خالص: 10229.31
# نسل 27/50 بهترین سود خالص: 10229.31
# نسل 28/50 بهترین سود خالص: 10229.31
# نسل 29/50 بهترین سود خالص: 10229.31
# نسل 30/50 بهترین سود خالص: 10229.31
# نسل 31/50 بهترین سود خالص: 10229.31
# نسل 32/50 بهترین سود خالص: 10229.31
# نسل 33/50 بهترین سود خالص: 10229.31
# نسل 34/50 بهترین سود خالص: 10229.31
# نسل 35/50 بهترین سود خالص: 10229.31
# نسل 36/50 بهترین سود خالص: 10229.31
# نسل 37/50 بهترین سود خالص: 10422.86
# نسل 38/50 بهترین سود خالص: 10422.86
# نسل 39/50 بهترین سود خالص: 10422.86
# نسل 40/50 بهترین سود خالص: 10422.86
# نسل 41/50 بهترین سود خالص: 10422.86
# نسل 42/50 بهترین سود خالص: 10422.86
# نسل 43/50 بهترین سود خالص: 10422.86
# نسل 44/50 بهترین سود خالص: 10422.86
# نسل 45/50 بهترین سود خالص: 10422.86
# نسل 46/50 بهترین سود خالص: 10422.86
# نسل 47/50 بهترین سود خالص: 10422.86
# نسل 48/50 بهترین سود خالص: 10422.86
# نسل 49/50 بهترین سود خالص: 10422.86
# نسل 50/50 بهترین سود خالص: 10422.86
# نسل 1/50 بهترین سود خالص: 8617.24
# نسل 2/50 بهترین سود خالص: 8617.24
# نسل 3/50 بهترین سود خالص: 8617.24
# نسل 4/50 بهترین سود خالص: 8617.24
# نسل 5/50 بهترین سود خالص: 8802.86
# نسل 6/50 بهترین سود خالص: 9867.61
# نسل 7/50 بهترین سود خالص: 9867.61
# نسل 8/50 بهترین سود خالص: 9867.61
# نسل 9/50 بهترین سود خالص: 9867.61
# نسل 10/50 بهترین سود خالص: 9867.61
# نسل 11/50 بهترین سود خالص: 9867.61
# نسل 12/50 بهترین سود خالص: 9867.61
# نسل 13/50 بهترین سود خالص: 9867.61
# نسل 14/50 بهترین سود خالص: 10370.73
# نسل 15/50 بهترین سود خالص: 11221.67
# نسل 16/50 بهترین سود خالص: 11221.67
# نسل 17/50 بهترین سود خالص: 11221.67
# نسل 18/50 بهترین سود خالص: 13730.82
# نسل 19/50 بهترین سود خالص: 13730.82
# نسل 20/50 بهترین سود خالص: 13730.82
# نسل 21/50 بهترین سود خالص: 13730.82
# نسل 22/50 بهترین سود خالص: 13730.82
# نسل 23/50 بهترین سود خالص: 13730.82
# نسل 24/50 بهترین سود خالص: 13730.82
# نسل 25/50 بهترین سود خالص: 13730.82
# نسل 26/50 بهترین سود خالص: 13730.82
# نسل 27/50 بهترین سود خالص: 13730.82
# نسل 28/50 بهترین سود خالص: 13730.82
# نسل 29/50 بهترین سود خالص: 13730.82
# نسل 30/50 بهترین سود خالص: 13730.82
# نسل 31/50 بهترین سود خالص: 13730.82
# نسل 32/50 بهترین سود خالص: 13730.82
# نسل 33/50 بهترین سود خالص: 13730.82
# نسل 34/50 بهترین سود خالص: 13730.82
# نسل 35/50 بهترین سود خالص: 13730.82
# نسل 36/50 بهترین سود خالص: 13730.82
# نسل 37/50 بهترین سود خالص: 13730.82
# نسل 38/50 بهترین سود خالص: 13730.82
# نسل 39/50 بهترین سود خالص: 13730.82
# نسل 40/50 بهترین سود خالص: 13730.82
# نسل 41/50 بهترین سود خالص: 13730.82
# نسل 42/50 بهترین سود خالص: 13730.82
# نسل 43/50 بهترین سود خالص: 13730.82
# نسل 44/50 بهترین سود خالص: 13730.82
# نسل 45/50 بهترین سود خالص: 13730.82
# نسل 46/50 بهترین سود خالص: 13730.82
# نسل 47/50 بهترین سود خالص: 13730.82
# نسل 48/50 بهترین سود خالص: 13730.82
# نسل 49/50 بهترین سود خالص: 13730.82
# نسل 50/50 بهترین سود خالص: 13730.82
# ✅ فایل‌ها ذخیره شدند: LC_results_train_PSO.xlsx, LC_results_test_PSO.xlsx

# %%
from google.colab import files
files.download('LC_results_train_PSO.xlsx')
files.download('LC_results_test_PSO.xlsx')

# %%
import pandas as pd
import numpy as np
import random, math, time

# ===== بک‌تست مشابه GA/PSO =====
def backtest_model(df, params, model_name):
    initial_capital = 10000
    lot_size = 0.1
    stop_loss_pips = float(params.get('SL', 90))
    take_profit_pips = float(params.get('TP', 130))

    equity = initial_capital
    peak_equity = initial_capital
    trades = []

    for i in range(1, len(df)):
        signal = None
        if float(df['Close'].iloc[i]) > float(df['Close'].iloc[i - 1]):
            signal = 'BUY'
        elif float(df['Close'].iloc[i]) < float(df['Close'].iloc[i - 1]):
            signal = 'SELL'

        if signal:
            entry_price = float(df['Close'].iloc[i])
            if signal == 'BUY':
                exit_price = entry_price + (take_profit_pips * 0.0001) \
                             if np.random.rand() > 0.5 else entry_price - (stop_loss_pips * 0.0001)
            else:
                exit_price = entry_price - (take_profit_pips * 0.0001) \
                             if np.random.rand() > 0.5 else entry_price + (stop_loss_pips * 0.0001)

            profit = (exit_price - entry_price) * (100000 * lot_size) if signal == 'BUY' \
                     else (entry_price - exit_price) * (100000 * lot_size)
            equity += profit
            trades.append(profit)
            peak_equity = max(peak_equity, equity)

    net_profit = equity - initial_capital
    profit_risk = (np.mean([t for t in trades if t > 0]) / abs(np.mean([t for t in trades if t < 0]))
                   if trades and any(t < 0 for t in trades) else (np.inf if trades else 0))
    drawdown = (peak_equity - equity) / peak_equity * 100
    return net_profit, profit_risk, drawdown

# ===== WOA =====
def woa_optimize(df, model_name, param_bounds, pop_size=30, n_gen=50):
    dim = len(param_bounds)
    lb = np.array([v[0] for v in param_bounds.values()])
    ub = np.array([v[1] for v in param_bounds.values()])
    keys = list(param_bounds.keys())

    positions = np.random.uniform(low=lb, high=ub, size=(pop_size, dim))
    leader_pos = np.zeros(dim)
    leader_score = -np.inf
    convergence_curve = []

    for t in range(n_gen):
        for i in range(pop_size):
            params = {keys[j]: positions[i, j] for j in range(dim)}
            fitness, _, _ = backtest_model(df, params, model_name)
            if fitness > leader_score:
                leader_score = fitness
                leader_pos = positions[i].copy()

        a = 2 - t * (2 / n_gen)
        a2 = -1 + t * (-1 / n_gen)

        for i in range(pop_size):
            r1, r2 = np.random.rand(), np.random.rand()
            A = 2 * a * r1 - a
            C = 2 * r2
            l = (a2 - 1) * random.random() + 1
            p = random.random()

            for j in range(dim):
                if p < 0.5:
                    if abs(A) >= 1:
                        rand_idx = math.floor(pop_size * random.random())
                        X_rand = positions[rand_idx]
                        D_X_rand = abs(C * X_rand[j] - positions[i, j])
                        positions[i, j] = X_rand[j] - A * D_X_rand
                    else:
                        D_leader = abs(C * leader_pos[j] - positions[i, j])
                        positions[i, j] = leader_pos[j] - A * D_leader
                else:
                    distance2Leader = abs(leader_pos[j] - positions[i, j])
                    positions[i, j] = distance2Leader * math.exp(1 * l) * math.cos(l * 2 * math.pi) + leader_pos[j]

            positions[i] = np.clip(positions[i], lb, ub)

        convergence_curve.append(leader_score)
        print(f"WOA نسل {t+1}/{n_gen} بهترین سود خالص: {leader_score:.2f}")

    best_params = {keys[j]: leader_pos[j] for j in range(dim)}
    return best_params, leader_score

# ===== Leader Correction با WOA =====
def leader_correction_woa(train_df, test_df, models, bounds, window_size=200):
    results_train, results_test = [], []

    for start in range(0, len(train_df) - window_size, window_size):
        window = train_df.iloc[start:start + window_size].reset_index(drop=True)
        winners = {}
        for model in models:
            params, score = woa_optimize(window, model, bounds[model])
            npf, prr, dd = backtest_model(window, params, model)
            winners[model] = (npf, prr, dd, params)

        leader = max(winners, key=lambda m: winners[m][0])
        best_npf, best_prr, best_dd, best_params = winners[leader]

        base_params = {k: float(v[0]) for k, v in bounds[leader].items()}
        base_npf, base_prr, base_dd = backtest_model(window, base_params, leader)

        results_train.append({
            'Window_Start': start,
            'Leader_Model': leader,
            **best_params,
            'Net_Profit': best_npf,
            'Profit/Risk': best_prr,
            'Drawdown': best_dd,
            '%Improvement_NP': ((best_npf - base_npf) / abs(base_npf) * 100) if base_npf != 0 else np.nan,
            '%Improvement_PR': ((best_prr - base_prr) / abs(base_prr) * 100) if base_prr != 0 else np.nan,
            '%Improvement_DD': ((base_dd - best_dd) / abs(base_dd) * 100) if base_dd != 0 else np.nan
        })

    for res in results_train:
        npf, prr, dd = backtest_model(test_df,
                                      {k: float(res[k]) for k in bounds[res['Leader_Model']]},
                                      res['Leader_Model'])
        results_test.append({
            **res,
            'Net_Profit': npf,
            'Profit/Risk': prr,
            'Drawdown': dd
        })

    return pd.DataFrame(results_train), pd.DataFrame(results_test)

# ===== اجرای اصلی =====
if __name__ == "__main__":
    train_df = pd.read_csv("USDCHF_H4.csv")
    test_df = pd.read_csv("USDCHF_H4_TesT.csv")

    models = ['PPPL', 'dSMA']
    bounds = {
        'PPPL': {'n_SMA': (14, 20), 'd11': (0.1, 0.3), 'SL': (80, 120), 'TP': (120, 150)},
        'dSMA': {'n_SMA': (10, 18), 'd11': (0.05, 0.2), 'SL': (70, 110), 'TP': (110, 140)}
    }

    res_train, res_test = leader_correction_woa(train_df, test_df, models, bounds, window_size=200)
    res_train.to_excel("LC_results_train_WOA.xlsx", index=False)
    res_test.to_excel("LC_results_test_WOA.xlsx", index=False)
    print("✅ فایل‌ها ذخیره شدند: LC_results_train_WOA.xlsx, LC_results_test_WOA.xlsx")
# Out:
# WOA نسل 1/50 بهترین سود خالص: 8757.19
# WOA نسل 2/50 بهترین سود خالص: 9075.20
# WOA نسل 3/50 بهترین سود خالص: 9075.20
# WOA نسل 4/50 بهترین سود خالص: 9075.20
# WOA نسل 5/50 بهترین سود خالص: 10161.48
# WOA نسل 6/50 بهترین سود خالص: 10161.48
# WOA نسل 7/50 بهترین سود خالص: 10161.48
# WOA نسل 8/50 بهترین سود خالص: 13286.73
# WOA نسل 9/50 بهترین سود خالص: 13286.73
# WOA نسل 10/50 بهترین سود خالص: 13286.73
# WOA نسل 11/50 بهترین سود خالص: 13286.73
# WOA نسل 12/50 بهترین سود خالص: 13286.73
# WOA نسل 13/50 بهترین سود خالص: 13286.73
# WOA نسل 14/50 بهترین سود خالص: 13286.73
# WOA نسل 15/50 بهترین سود خالص: 13286.73
# WOA نسل 16/50 بهترین سود خالص: 13286.73
# WOA نسل 17/50 بهترین سود خالص: 13286.73
# WOA نسل 18/50 بهترین سود خالص: 13286.73
# WOA نسل 19/50 بهترین سود خالص: 13286.73
# WOA نسل 20/50 بهترین سود خالص: 13286.73
# WOA نسل 21/50 بهترین سود خالص: 13286.73
# WOA نسل 22/50 بهترین سود خالص: 13286.73
# WOA نسل 23/50 بهترین سود خالص: 13286.73
# WOA نسل 24/50 بهترین سود خالص: 13286.73
# WOA نسل 25/50 بهترین سود خالص: 13286.73
# WOA نسل 26/50 بهترین سود خالص: 13286.73
# WOA نسل 27/50 بهترین سود خالص: 13286.73
# WOA نسل 28/50 بهترین سود خالص: 13286.73
# WOA نسل 29/50 بهترین سود خالص: 13286.73
# WOA نسل 30/50 بهترین سود خالص: 13286.73
# WOA نسل 31/50 بهترین سود خالص: 13286.73
# WOA نسل 32/50 بهترین سود خالص: 13286.73
# WOA نسل 33/50 بهترین سود خالص: 13286.73
# WOA نسل 34/50 بهترین سود خالص: 13286.73
# WOA نسل 35/50 بهترین سود خالص: 13286.73
# WOA نسل 36/50 بهترین سود خالص: 13286.73
# WOA نسل 37/50 بهترین سود خالص: 13286.73
# WOA نسل 38/50 بهترین سود خالص: 13286.73
# WOA نسل 39/50 بهترین سود خالص: 13286.73
# WOA نسل 40/50 بهترین سود خالص: 13286.73
# WOA نسل 41/50 بهترین سود خالص: 13286.73
# WOA نسل 42/50 بهترین سود خالص: 13286.73
# WOA نسل 43/50 بهترین سود خالص: 13286.73
# WOA نسل 44/50 بهترین سود خالص: 13286.73
# WOA نسل 45/50 بهترین سود خالص: 13286.73
# WOA نسل 46/50 بهترین سود خالص: 13286.73
# WOA نسل 47/50 بهترین سود خالص: 13286.73
# WOA نسل 48/50 بهترین سود خالص: 13286.73
# WOA نسل 49/50 بهترین سود خالص: 13286.73
# WOA نسل 50/50 بهترین سود خالص: 13286.73
# WOA نسل 1/50 بهترین سود خالص: 6774.54
# WOA نسل 2/50 بهترین سود خالص: 7514.09
# WOA نسل 3/50 بهترین سود خالص: 9014.83
# WOA نسل 4/50 بهترین سود خالص: 9014.83
# WOA نسل 5/50 بهترین سود خالص: 9014.83
# WOA نسل 6/50 بهترین سود خالص: 10150.75
# WOA نسل 7/50 بهترین سود خالص: 10150.75
# WOA نسل 8/50 بهترین سود خالص: 10150.75
# WOA نسل 9/50 بهترین سود خالص: 10150.75
# WOA نسل 10/50 بهترین سود خالص: 10355.48
# WOA نسل 11/50 بهترین سود خالص: 10355.48
# WOA نسل 12/50 بهترین سود خالص: 10355.48
# WOA نسل 13/50 بهترین سود خالص: 10355.48
# WOA نسل 14/50 بهترین سود خالص: 10355.48
# WOA نسل 15/50 بهترین سود خالص: 10355.48
# WOA نسل 16/50 بهترین سود خالص: 10355.48
# WOA نسل 17/50 بهترین سود خالص: 10355.48
# WOA نسل 18/50 بهترین سود خالص: 10355.48
# WOA نسل 19/50 بهترین سود خالص: 10355.48
# WOA نسل 20/50 بهترین سود خالص: 10355.48
# WOA نسل 21/50 بهترین سود خالص: 10355.48
# WOA نسل 22/50 بهترین سود خالص: 10355.48
# WOA نسل 23/50 بهترین سود خالص: 10355.48
# WOA نسل 24/50 بهترین سود خالص: 10355.48
# WOA نسل 25/50 بهترین سود خالص: 10670.14
# WOA نسل 26/50 بهترین سود خالص: 10670.14
# WOA نسل 27/50 بهترین سود خالص: 10670.14
# WOA نسل 28/50 بهترین سود خالص: 10670.14
# WOA نسل 29/50 بهترین سود خالص: 10670.14
# WOA نسل 30/50 بهترین سود خالص: 10670.14
# WOA نسل 31/50 بهترین سود خالص: 10670.14
# WOA نسل 32/50 بهترین سود خالص: 10670.14
# WOA نسل 33/50 بهترین سود خالص: 10670.14
# WOA نسل 34/50 بهترین سود خالص: 10670.14
# WOA نسل 35/50 بهترین سود خالص: 10670.14
# WOA نسل 36/50 بهترین سود خالص: 10670.14
# WOA نسل 37/50 بهترین سود خالص: 10670.14
# WOA نسل 38/50 بهترین سود خالص: 10670.14
# WOA نسل 39/50 بهترین سود خالص: 10670.14
# WOA نسل 40/50 بهترین سود خالص: 10670.14
# WOA نسل 41/50 بهترین سود خالص: 10670.14
# WOA نسل 42/50 بهترین سود خالص: 10670.14
# WOA نسل 43/50 بهترین سود خالص: 10670.14
# WOA نسل 44/50 بهترین سود خالص: 10670.14
# WOA نسل 45/50 بهترین سود خالص: 10670.14
# WOA نسل 46/50 بهترین سود خالص: 10670.14
# WOA نسل 47/50 بهترین سود خالص: 10670.14
# WOA نسل 48/50 بهترین سود خالص: 10670.14
# WOA نسل 49/50 بهترین سود خالص: 10670.14
# WOA نسل 50/50 بهترین سود خالص: 10670.14
# WOA نسل 1/50 بهترین سود خالص: 7920.85
# WOA نسل 2/50 بهترین سود خالص: 8646.88
# WOA نسل 3/50 بهترین سود خالص: 8646.88
# WOA نسل 4/50 بهترین سود خالص: 10300.00
# WOA نسل 5/50 بهترین سود خالص: 10300.00
# WOA نسل 6/50 بهترین سود خالص: 10300.00
# WOA نسل 7/50 بهترین سود خالص: 12964.58
# WOA نسل 8/50 بهترین سود خالص: 12964.58
# WOA نسل 9/50 بهترین سود خالص: 12964.58
# WOA نسل 10/50 بهترین سود خالص: 12964.58
# WOA نسل 11/50 بهترین سود خالص: 12964.58
# WOA نسل 12/50 بهترین سود خالص: 12964.58
# WOA نسل 13/50 بهترین سود خالص: 12964.58
# WOA نسل 14/50 بهترین سود خالص: 12964.58
# WOA نسل 15/50 بهترین سود خالص: 12964.58
# WOA نسل 16/50 بهترین سود خالص: 12964.58
# WOA نسل 17/50 بهترین سود خالص: 12964.58
# WOA نسل 18/50 بهترین سود خالص: 12964.58
# WOA نسل 19/50 بهترین سود خالص: 12964.58
# WOA نسل 20/50 بهترین سود خالص: 12964.58
# WOA نسل 21/50 بهترین سود خالص: 12964.58
# WOA نسل 22/50 بهترین سود خالص: 12964.58
# WOA نسل 23/50 بهترین سود خالص: 12964.58
# WOA نسل 24/50 بهترین سود خالص: 12964.58
# WOA نسل 25/50 بهترین سود خالص: 12964.58
# WOA نسل 26/50 بهترین سود خالص: 12964.58
# WOA نسل 27/50 بهترین سود خالص: 12964.58
# WOA نسل 28/50 بهترین سود خالص: 12964.58
# WOA نسل 29/50 بهترین سود خالص: 12964.58
# WOA نسل 30/50 بهترین سود خالص: 12964.58
# WOA نسل 31/50 بهترین سود خالص: 12964.58
# WOA نسل 32/50 بهترین سود خالص: 12964.58
# WOA نسل 33/50 بهترین سود خالص: 12964.58
# WOA نسل 34/50 بهترین سود خالص: 12964.58
# WOA نسل 35/50 بهترین سود خالص: 12964.58
# WOA نسل 36/50 بهترین سود خالص: 12964.58
# WOA نسل 37/50 بهترین سود خالص: 12964.58
# WOA نسل 38/50 بهترین سود خالص: 12964.58
# WOA نسل 39/50 بهترین سود خالص: 12964.58
# WOA نسل 40/50 بهترین سود خالص: 12964.58
# WOA نسل 41/50 بهترین سود خالص: 12964.58
# WOA نسل 42/50 بهترین سود خالص: 12964.58
# WOA نسل 43/50 بهترین سود خالص: 12964.58
# WOA نسل 44/50 بهترین سود خالص: 12964.58
# WOA نسل 45/50 بهترین سود خالص: 12964.58
# WOA نسل 46/50 بهترین سود خالص: 12964.58
# WOA نسل 47/50 بهترین سود خالص: 12964.58
# WOA نسل 48/50 بهترین سود خالص: 12964.58
# WOA نسل 49/50 بهترین سود خالص: 12964.58
# WOA نسل 50/50 بهترین سود خالص: 12964.58
# WOA نسل 1/50 بهترین سود خالص: 7092.23
# WOA نسل 2/50 بهترین سود خالص: 8384.19
# WOA نسل 3/50 بهترین سود خالص: 8384.19
# WOA نسل 4/50 بهترین سود خالص: 8384.19
# WOA نسل 5/50 بهترین سود خالص: 8384.19
# WOA نسل 6/50 بهترین سود خالص: 8384.19
# WOA نسل 7/50 بهترین سود خالص: 8384.19
# WOA نسل 8/50 بهترین سود خالص: 8814.59
# WOA نسل 9/50 بهترین سود خالص: 8814.59
# WOA نسل 10/50 بهترین سود خالص: 9247.65
# WOA نسل 11/50 بهترین سود خالص: 9247.65
# WOA نسل 12/50 بهترین سود خالص: 9247.65
# WOA نسل 13/50 بهترین سود خالص: 9247.65
# WOA نسل 14/50 بهترین سود خالص: 9247.65
# WOA نسل 15/50 بهترین سود خالص: 9539.80
# WOA نسل 16/50 بهترین سود خالص: 9539.80
# WOA نسل 17/50 بهترین سود خالص: 9539.80
# WOA نسل 18/50 بهترین سود خالص: 9539.80
# WOA نسل 19/50 بهترین سود خالص: 9572.49
# WOA نسل 20/50 بهترین سود خالص: 9572.49
# WOA نسل 21/50 بهترین سود خالص: 9572.49
# WOA نسل 22/50 بهترین سود خالص: 9572.49
# WOA نسل 23/50 بهترین سود خالص: 9923.56
# WOA نسل 24/50 بهترین سود خالص: 10154.25
# WOA نسل 25/50 بهترین سود خالص: 10684.98
# WOA نسل 26/50 بهترین سود خالص: 10684.98
# WOA نسل 27/50 بهترین سود خالص: 10684.98
# WOA نسل 28/50 بهترین سود خالص: 10684.98
# WOA نسل 29/50 بهترین سود خالص: 10684.98
# WOA نسل 30/50 بهترین سود خالص: 10684.98
# WOA نسل 31/50 بهترین سود خالص: 10684.98
# WOA نسل 32/50 بهترین سود خالص: 10684.98
# WOA نسل 33/50 بهترین سود خالص: 10684.98
# WOA نسل 34/50 بهترین سود خالص: 10684.98
# WOA نسل 35/50 بهترین سود خالص: 10684.98
# WOA نسل 36/50 بهترین سود خالص: 10684.98
# WOA نسل 37/50 بهترین سود خالص: 10684.98
# WOA نسل 38/50 بهترین سود خالص: 10684.98
# WOA نسل 39/50 بهترین سود خالص: 10684.98
# WOA نسل 40/50 بهترین سود خالص: 10684.98
# WOA نسل 41/50 بهترین سود خالص: 10684.98
# WOA نسل 42/50 بهترین سود خالص: 10684.98
# WOA نسل 43/50 بهترین سود خالص: 10684.98
# WOA نسل 44/50 بهترین سود خالص: 10684.98
# WOA نسل 45/50 بهترین سود خالص: 10684.98
# WOA نسل 46/50 بهترین سود خالص: 10684.98
# WOA نسل 47/50 بهترین سود خالص: 10684.98
# WOA نسل 48/50 بهترین سود خالص: 10684.98
# WOA نسل 49/50 بهترین سود خالص: 10684.98
# WOA نسل 50/50 بهترین سود خالص: 10765.56
# WOA نسل 1/50 بهترین سود خالص: 6486.59
# WOA نسل 2/50 بهترین سود خالص: 7391.93
# WOA نسل 3/50 بهترین سود خالص: 9071.46
# WOA نسل 4/50 بهترین سود خالص: 9071.46
# WOA نسل 5/50 بهترین سود خالص: 9071.46
# WOA نسل 6/50 بهترین سود خالص: 9071.46
# WOA نسل 7/50 بهترین سود خالص: 9071.46
# WOA نسل 8/50 بهترین سود خالص: 9071.46
# WOA نسل 9/50 بهترین سود خالص: 9071.46
# WOA نسل 10/50 بهترین سود خالص: 9071.46
# WOA نسل 11/50 بهترین سود خالص: 9071.46
# WOA نسل 12/50 بهترین سود خالص: 9071.46
# WOA نسل 13/50 بهترین سود خالص: 9071.46
# WOA نسل 14/50 بهترین سود خالص: 9071.46
# WOA نسل 15/50 بهترین سود خالص: 9071.46
# WOA نسل 16/50 بهترین سود خالص: 9071.46
# WOA نسل 17/50 بهترین سود خالص: 9071.46
# WOA نسل 18/50 بهترین سود خالص: 9071.46
# WOA نسل 19/50 بهترین سود خالص: 9071.46
# WOA نسل 20/50 بهترین سود خالص: 9369.62
# WOA نسل 21/50 بهترین سود خالص: 9369.62
# WOA نسل 22/50 بهترین سود خالص: 9369.62
# WOA نسل 23/50 بهترین سود خالص: 9369.62
# WOA نسل 24/50 بهترین سود خالص: 9369.62
# WOA نسل 25/50 بهترین سود خالص: 9369.62
# WOA نسل 26/50 بهترین سود خالص: 9369.62
# WOA نسل 27/50 بهترین سود خالص: 9369.62
# WOA نسل 28/50 بهترین سود خالص: 9369.62
# WOA نسل 29/50 بهترین سود خالص: 9369.62
# WOA نسل 30/50 بهترین سود خالص: 9369.62
# WOA نسل 31/50 بهترین سود خالص: 9369.62
# WOA نسل 32/50 بهترین سود خالص: 9369.62
# WOA نسل 33/50 بهترین سود خالص: 9369.62
# WOA نسل 34/50 بهترین سود خالص: 9369.62
# WOA نسل 35/50 بهترین سود خالص: 9369.62
# WOA نسل 36/50 بهترین سود خالص: 9369.62
# WOA نسل 37/50 بهترین سود خالص: 9369.62
# WOA نسل 38/50 بهترین سود خالص: 9369.62
# WOA نسل 39/50 بهترین سود خالص: 9369.62
# WOA نسل 40/50 بهترین سود خالص: 9369.62
# WOA نسل 41/50 بهترین سود خالص: 9369.62
# WOA نسل 42/50 بهترین سود خالص: 9369.62
# WOA نسل 43/50 بهترین سود خالص: 9369.62
# WOA نسل 44/50 بهترین سود خالص: 9369.62
# WOA نسل 45/50 بهترین سود خالص: 9369.62
# WOA نسل 46/50 بهترین سود خالص: 9369.62
# WOA نسل 47/50 بهترین سود خالص: 9369.62
# WOA نسل 48/50 بهترین سود خالص: 9369.62
# WOA نسل 49/50 بهترین سود خالص: 9369.62
# WOA نسل 50/50 بهترین سود خالص: 9369.62
# WOA نسل 1/50 بهترین سود خالص: 7786.67
# WOA نسل 2/50 بهترین سود خالص: 7786.67
# WOA نسل 3/50 بهترین سود خالص: 7795.57
# WOA نسل 4/50 بهترین سود خالص: 10220.00
# WOA نسل 5/50 بهترین سود خالص: 10674.76
# WOA نسل 6/50 بهترین سود خالص: 10674.76
# WOA نسل 7/50 بهترین سود خالص: 10674.76
# WOA نسل 8/50 بهترین سود خالص: 10674.76
# WOA نسل 9/50 بهترین سود خالص: 10674.76
# WOA نسل 10/50 بهترین سود خالص: 10674.76
# WOA نسل 11/50 بهترین سود خالص: 10674.76
# WOA نسل 12/50 بهترین سود خالص: 10674.76
# WOA نسل 13/50 بهترین سود خالص: 10674.76
# WOA نسل 14/50 بهترین سود خالص: 10674.76
# WOA نسل 15/50 بهترین سود خالص: 10674.76
# WOA نسل 16/50 بهترین سود خالص: 10674.76
# WOA نسل 17/50 بهترین سود خالص: 10674.76
# WOA نسل 18/50 بهترین سود خالص: 10674.76
# WOA نسل 19/50 بهترین سود خالص: 10674.76
# WOA نسل 20/50 بهترین سود خالص: 10674.76
# WOA نسل 21/50 بهترین سود خالص: 10674.76
# WOA نسل 22/50 بهترین سود خالص: 10674.76
# WOA نسل 23/50 بهترین سود خالص: 10674.76
# WOA نسل 24/50 بهترین سود خالص: 10674.76
# WOA نسل 25/50 بهترین سود خالص: 10674.76
# WOA نسل 26/50 بهترین سود خالص: 10674.76
# WOA نسل 27/50 بهترین سود خالص: 10674.76
# WOA نسل 28/50 بهترین سود خالص: 10674.76
# WOA نسل 29/50 بهترین سود خالص: 10674.76
# WOA نسل 30/50 بهترین سود خالص: 10674.76
# WOA نسل 31/50 بهترین سود خالص: 10674.76
# WOA نسل 32/50 بهترین سود خالص: 10674.76
# WOA نسل 33/50 بهترین سود خالص: 10674.76
# WOA نسل 34/50 بهترین سود خالص: 10674.76
# WOA نسل 35/50 بهترین سود خالص: 10674.76
# WOA نسل 36/50 بهترین سود خالص: 10674.76
# WOA نسل 37/50 بهترین سود خالص: 10674.76
# WOA نسل 38/50 بهترین سود خالص: 10674.76
# WOA نسل 39/50 بهترین سود خالص: 10674.76
# WOA نسل 40/50 بهترین سود خالص: 10674.76
# WOA نسل 41/50 بهترین سود خالص: 10674.76
# WOA نسل 42/50 بهترین سود خالص: 10674.76
# WOA نسل 43/50 بهترین سود خالص: 10674.76
# WOA نسل 44/50 بهترین سود خالص: 10674.76
# WOA نسل 45/50 بهترین سود خالص: 10674.76
# WOA نسل 46/50 بهترین سود خالص: 10674.76
# WOA نسل 47/50 بهترین سود خالص: 10674.76
# WOA نسل 48/50 بهترین سود خالص: 10674.76
# WOA نسل 49/50 بهترین سود خالص: 10674.76
# WOA نسل 50/50 بهترین سود خالص: 10674.76
# WOA نسل 1/50 بهترین سود خالص: 7817.51
# WOA نسل 2/50 بهترین سود خالص: 8438.49
# WOA نسل 3/50 بهترین سود خالص: 8438.49
# WOA نسل 4/50 بهترین سود خالص: 9028.17
# WOA نسل 5/50 بهترین سود خالص: 9028.17
# WOA نسل 6/50 بهترین سود خالص: 10920.00
# WOA نسل 7/50 بهترین سود خالص: 10920.00
# WOA نسل 8/50 بهترین سود خالص: 10920.00
# WOA نسل 9/50 بهترین سود خالص: 10920.00
# WOA نسل 10/50 بهترین سود خالص: 10920.00
# WOA نسل 11/50 بهترین سود خالص: 10920.00
# WOA نسل 12/50 بهترین سود خالص: 10920.00
# WOA نسل 13/50 بهترین سود خالص: 10920.00
# WOA نسل 14/50 بهترین سود خالص: 10920.00
# WOA نسل 15/50 بهترین سود خالص: 10920.00
# WOA نسل 16/50 بهترین سود خالص: 10920.00
# WOA نسل 17/50 بهترین سود خالص: 10920.00
# WOA نسل 18/50 بهترین سود خالص: 10920.00
# WOA نسل 19/50 بهترین سود خالص: 10920.00
# WOA نسل 20/50 بهترین سود خالص: 10920.00
# WOA نسل 21/50 بهترین سود خالص: 10920.00
# WOA نسل 22/50 بهترین سود خالص: 12530.00
# WOA نسل 23/50 بهترین سود خالص: 12530.00
# WOA نسل 24/50 بهترین سود خالص: 12530.00
# WOA نسل 25/50 بهترین سود خالص: 12530.00
# WOA نسل 26/50 بهترین سود خالص: 12530.00
# WOA نسل 27/50 بهترین سود خالص: 12530.00
# WOA نسل 28/50 بهترین سود خالص: 12530.00
# WOA نسل 29/50 بهترین سود خالص: 12530.00
# WOA نسل 30/50 بهترین سود خالص: 12530.00
# WOA نسل 31/50 بهترین سود خالص: 12530.00
# WOA نسل 32/50 بهترین سود خالص: 12530.00
# WOA نسل 33/50 بهترین سود خالص: 12530.00
# WOA نسل 34/50 بهترین سود خالص: 12530.00
# WOA نسل 35/50 بهترین سود خالص: 12530.00
# WOA نسل 36/50 بهترین سود خالص: 12530.00
# WOA نسل 37/50 بهترین سود خالص: 12530.00
# WOA نسل 38/50 بهترین سود خالص: 12530.00
# WOA نسل 39/50 بهترین سود خالص: 12530.00
# WOA نسل 40/50 بهترین سود خالص: 12530.00
# WOA نسل 41/50 بهترین سود خالص: 12530.00
# WOA نسل 42/50 بهترین سود خالص: 12530.00
# WOA نسل 43/50 بهترین سود خالص: 12530.00
# WOA نسل 44/50 بهترین سود خالص: 12530.00
# WOA نسل 45/50 بهترین سود خالص: 12530.00
# WOA نسل 46/50 بهترین سود خالص: 12530.00
# WOA نسل 47/50 بهترین سود خالص: 12530.00
# WOA نسل 48/50 بهترین سود خالص: 12530.00
# WOA نسل 49/50 بهترین سود خالص: 12530.00
# WOA نسل 50/50 بهترین سود خالص: 12530.00
# WOA نسل 1/50 بهترین سود خالص: 7320.96
# WOA نسل 2/50 بهترین سود خالص: 7844.15
# WOA نسل 3/50 بهترین سود خالص: 8353.93
# WOA نسل 4/50 بهترین سود خالص: 8401.07
# WOA نسل 5/50 بهترین سود خالص: 8401.07
# WOA نسل 6/50 بهترین سود خالص: 8916.71
# WOA نسل 7/50 بهترین سود خالص: 9278.47
# WOA نسل 8/50 بهترین سود خالص: 9278.47
# WOA نسل 9/50 بهترین سود خالص: 9278.47
# WOA نسل 10/50 بهترین سود خالص: 9278.47
# WOA نسل 11/50 بهترین سود خالص: 9278.47
# WOA نسل 12/50 بهترین سود خالص: 9278.47
# WOA نسل 13/50 بهترین سود خالص: 9278.47
# WOA نسل 14/50 بهترین سود خالص: 9278.47
# WOA نسل 15/50 بهترین سود خالص: 9278.47
# WOA نسل 16/50 بهترین سود خالص: 9278.47
# WOA نسل 17/50 بهترین سود خالص: 9278.47
# WOA نسل 18/50 بهترین سود خالص: 9278.47
# WOA نسل 19/50 بهترین سود خالص: 9278.47
# WOA نسل 20/50 بهترین سود خالص: 9278.47
# WOA نسل 21/50 بهترین سود خالص: 9933.22
# WOA نسل 22/50 بهترین سود خالص: 9933.22
# WOA نسل 23/50 بهترین سود خالص: 9933.22
# WOA نسل 24/50 بهترین سود خالص: 9933.22
# WOA نسل 25/50 بهترین سود خالص: 9933.22
# WOA نسل 26/50 بهترین سود خالص: 9933.22
# WOA نسل 27/50 بهترین سود خالص: 9933.22
# WOA نسل 28/50 بهترین سود خالص: 9933.22
# WOA نسل 29/50 بهترین سود خالص: 9933.22
# WOA نسل 30/50 بهترین سود خالص: 9933.22
# WOA نسل 31/50 بهترین سود خالص: 9933.22
# WOA نسل 32/50 بهترین سود خالص: 9933.22
# WOA نسل 33/50 بهترین سود خالص: 9933.22
# WOA نسل 34/50 بهترین سود خالص: 9933.22
# WOA نسل 35/50 بهترین سود خالص: 9933.22
# WOA نسل 36/50 بهترین سود خالص: 9933.22
# WOA نسل 37/50 بهترین سود خالص: 9933.22
# WOA نسل 38/50 بهترین سود خالص: 9933.22
# WOA نسل 39/50 بهترین سود خالص: 9933.22
# WOA نسل 40/50 بهترین سود خالص: 12250.00
# WOA نسل 41/50 بهترین سود خالص: 12250.00
# WOA نسل 42/50 بهترین سود خالص: 12250.00
# WOA نسل 43/50 بهترین سود خالص: 12250.00
# WOA نسل 44/50 بهترین سود خالص: 12250.00
# WOA نسل 45/50 بهترین سود خالص: 12250.00
# WOA نسل 46/50 بهترین سود خالص: 12250.00
# WOA نسل 47/50 بهترین سود خالص: 12250.00
# WOA نسل 48/50 بهترین سود خالص: 12250.00
# WOA نسل 49/50 بهترین سود خالص: 12250.00
# WOA نسل 50/50 بهترین سود خالص: 12250.00
# WOA نسل 1/50 بهترین سود خالص: 8022.37
# WOA نسل 2/50 بهترین سود خالص: 8469.55
# WOA نسل 3/50 بهترین سود خالص: 8699.73
# WOA نسل 4/50 بهترین سود خالص: 8699.73
# WOA نسل 5/50 بهترین سود خالص: 8699.73
# WOA نسل 6/50 بهترین سود خالص: 9173.91
# WOA نسل 7/50 بهترین سود خالص: 9173.91
# WOA نسل 8/50 بهترین سود خالص: 10187.19
# WOA نسل 9/50 بهترین سود خالص: 10187.19
# WOA نسل 10/50 بهترین سود خالص: 10187.19
# WOA نسل 11/50 بهترین سود خالص: 10187.19
# WOA نسل 12/50 بهترین سود خالص: 10187.19
# WOA نسل 13/50 بهترین سود خالص: 10187.19
# WOA نسل 14/50 بهترین سود خالص: 10187.19
# WOA نسل 15/50 بهترین سود خالص: 10187.19
# WOA نسل 16/50 بهترین سود خالص: 10476.30
# WOA نسل 17/50 بهترین سود خالص: 10476.30
# WOA نسل 18/50 بهترین سود خالص: 10476.30
# WOA نسل 19/50 بهترین سود خالص: 10476.30
# WOA نسل 20/50 بهترین سود خالص: 10476.30
# WOA نسل 21/50 بهترین سود خالص: 10476.30
# WOA نسل 22/50 بهترین سود خالص: 10476.30
# WOA نسل 23/50 بهترین سود خالص: 10476.30
# WOA نسل 24/50 بهترین سود خالص: 10476.30
# WOA نسل 25/50 بهترین سود خالص: 10476.30
# WOA نسل 26/50 بهترین سود خالص: 10476.30
# WOA نسل 27/50 بهترین سود خالص: 11184.30
# WOA نسل 28/50 بهترین سود خالص: 11184.30
# WOA نسل 29/50 بهترین سود خالص: 11184.30
# WOA نسل 30/50 بهترین سود خالص: 11662.66
# WOA نسل 31/50 بهترین سود خالص: 11662.66
# WOA نسل 32/50 بهترین سود خالص: 11662.66
# WOA نسل 33/50 بهترین سود خالص: 11662.66
# WOA نسل 34/50 بهترین سود خالص: 11662.66
# WOA نسل 35/50 بهترین سود خالص: 11662.66
# WOA نسل 36/50 بهترین سود خالص: 11662.66
# WOA نسل 37/50 بهترین سود خالص: 11673.14
# WOA نسل 38/50 بهترین سود خالص: 11673.14
# WOA نسل 39/50 بهترین سود خالص: 11673.14
# WOA نسل 40/50 بهترین سود خالص: 11673.14
# WOA نسل 41/50 بهترین سود خالص: 11673.14
# WOA نسل 42/50 بهترین سود خالص: 11673.14
# WOA نسل 43/50 بهترین سود خالص: 11673.14
# WOA نسل 44/50 بهترین سود خالص: 11673.14
# WOA نسل 45/50 بهترین سود خالص: 11673.14
# WOA نسل 46/50 بهترین سود خالص: 11673.14
# WOA نسل 47/50 بهترین سود خالص: 11673.14
# WOA نسل 48/50 بهترین سود خالص: 11673.14
# WOA نسل 49/50 بهترین سود خالص: 11673.14
# WOA نسل 50/50 بهترین سود خالص: 11673.14
# WOA نسل 1/50 بهترین سود خالص: 7004.53
# WOA نسل 2/50 بهترین سود خالص: 7679.51
# WOA نسل 3/50 بهترین سود خالص: 9322.20
# WOA نسل 4/50 بهترین سود خالص: 9322.20
# WOA نسل 5/50 بهترین سود خالص: 9322.20
# WOA نسل 6/50 بهترین سود خالص: 9322.20
# WOA نسل 7/50 بهترین سود خالص: 9322.20
# WOA نسل 8/50 بهترین سود خالص: 9322.20
# WOA نسل 9/50 بهترین سود خالص: 9322.20
# WOA نسل 10/50 بهترین سود خالص: 9322.20
# WOA نسل 11/50 بهترین سود خالص: 9322.20
# WOA نسل 12/50 بهترین سود خالص: 9322.20
# WOA نسل 13/50 بهترین سود خالص: 9322.20
# WOA نسل 14/50 بهترین سود خالص: 9800.00
# WOA نسل 15/50 بهترین سود خالص: 9800.00
# WOA نسل 16/50 بهترین سود خالص: 10475.18
# WOA نسل 17/50 بهترین سود خالص: 10475.18
# WOA نسل 18/50 بهترین سود خالص: 10475.18
# WOA نسل 19/50 بهترین سود خالص: 10475.18
# WOA نسل 20/50 بهترین سود خالص: 10475.18
# WOA نسل 21/50 بهترین سود خالص: 10475.18
# WOA نسل 22/50 بهترین سود خالص: 10475.18
# WOA نسل 23/50 بهترین سود خالص: 10475.18
# WOA نسل 24/50 بهترین سود خالص: 10475.18
# WOA نسل 25/50 بهترین سود خالص: 10475.18
# WOA نسل 26/50 بهترین سود خالص: 10475.18
# WOA نسل 27/50 بهترین سود خالص: 10475.18
# WOA نسل 28/50 بهترین سود خالص: 10475.18
# WOA نسل 29/50 بهترین سود خالص: 10475.18
# WOA نسل 30/50 بهترین سود خالص: 10475.18
# WOA نسل 31/50 بهترین سود خالص: 10475.18
# WOA نسل 32/50 بهترین سود خالص: 10567.06
# WOA نسل 33/50 بهترین سود خالص: 10567.06
# WOA نسل 34/50 بهترین سود خالص: 10567.06
# WOA نسل 35/50 بهترین سود خالص: 10567.06
# WOA نسل 36/50 بهترین سود خالص: 10567.06
# WOA نسل 37/50 بهترین سود خالص: 10567.06
# WOA نسل 38/50 بهترین سود خالص: 10567.06
# WOA نسل 39/50 بهترین سود خالص: 10567.06
# WOA نسل 40/50 بهترین سود خالص: 10567.06
# WOA نسل 41/50 بهترین سود خالص: 10567.06
# WOA نسل 42/50 بهترین سود خالص: 10567.06
# WOA نسل 43/50 بهترین سود خالص: 10567.06
# WOA نسل 44/50 بهترین سود خالص: 10567.06
# WOA نسل 45/50 بهترین سود خالص: 10567.06
# WOA نسل 46/50 بهترین سود خالص: 10567.06
# WOA نسل 47/50 بهترین سود خالص: 10567.06
# WOA نسل 48/50 بهترین سود خالص: 10567.06
# WOA نسل 49/50 بهترین سود خالص: 10567.06
# WOA نسل 50/50 بهترین سود خالص: 10567.06
# WOA نسل 1/50 بهترین سود خالص: 7077.28
# WOA نسل 2/50 بهترین سود خالص: 9522.24
# WOA نسل 3/50 بهترین سود خالص: 9918.82
# WOA نسل 4/50 بهترین سود خالص: 9918.82
# WOA نسل 5/50 بهترین سود خالص: 9918.82
# WOA نسل 6/50 بهترین سود خالص: 9918.82
# WOA نسل 7/50 بهترین سود خالص: 9918.82
# WOA نسل 8/50 بهترین سود خالص: 9918.82
# WOA نسل 9/50 بهترین سود خالص: 9918.82
# WOA نسل 10/50 بهترین سود خالص: 9918.82
# WOA نسل 11/50 بهترین سود خالص: 9918.82
# WOA نسل 12/50 بهترین سود خالص: 9918.82
# WOA نسل 13/50 بهترین سود خالص: 9918.82
# WOA نسل 14/50 بهترین سود خالص: 9918.82
# WOA نسل 15/50 بهترین سود خالص: 9918.82
# WOA نسل 16/50 بهترین سود خالص: 9918.82
# WOA نسل 17/50 بهترین سود خالص: 9950.46
# WOA نسل 18/50 بهترین سود خالص: 9950.46
# WOA نسل 19/50 بهترین سود خالص: 9950.46
# WOA نسل 20/50 بهترین سود خالص: 9950.46
# WOA نسل 21/50 بهترین سود خالص: 9950.46
# WOA نسل 22/50 بهترین سود خالص: 10177.50
# WOA نسل 23/50 بهترین سود خالص: 10177.50
# WOA نسل 24/50 بهترین سود خالص: 10177.50
# WOA نسل 25/50 بهترین سود خالص: 10177.50
# WOA نسل 26/50 بهترین سود خالص: 10177.50
# WOA نسل 27/50 بهترین سود خالص: 10177.50
# WOA نسل 28/50 بهترین سود خالص: 10177.50
# WOA نسل 29/50 بهترین سود خالص: 10424.11
# WOA نسل 30/50 بهترین سود خالص: 10424.11
# WOA نسل 31/50 بهترین سود خالص: 10424.11
# WOA نسل 32/50 بهترین سود خالص: 10424.11
# WOA نسل 33/50 بهترین سود خالص: 10424.11
# WOA نسل 34/50 بهترین سود خالص: 10424.11
# WOA نسل 35/50 بهترین سود خالص: 10424.11
# WOA نسل 36/50 بهترین سود خالص: 10424.11
# WOA نسل 37/50 بهترین سود خالص: 10424.11
# WOA نسل 38/50 بهترین سود خالص: 12183.70
# WOA نسل 39/50 بهترین سود خالص: 12183.70
# WOA نسل 40/50 بهترین سود خالص: 12183.70
# WOA نسل 41/50 بهترین سود خالص: 12183.70
# WOA نسل 42/50 بهترین سود خالص: 12183.70
# WOA نسل 43/50 بهترین سود خالص: 12183.70
# WOA نسل 44/50 بهترین سود خالص: 12183.70
# WOA نسل 45/50 بهترین سود خالص: 12183.70
# WOA نسل 46/50 بهترین سود خالص: 12183.70
# WOA نسل 47/50 بهترین سود خالص: 12183.70
# WOA نسل 48/50 بهترین سود خالص: 12183.70
# WOA نسل 49/50 بهترین سود خالص: 12183.70
# WOA نسل 50/50 بهترین سود خالص: 12183.70
# WOA نسل 1/50 بهترین سود خالص: 7038.94
# WOA نسل 2/50 بهترین سود خالص: 7429.23
# WOA نسل 3/50 بهترین سود خالص: 9088.10
# WOA نسل 4/50 بهترین سود خالص: 9333.77
# WOA نسل 5/50 بهترین سود خالص: 9333.77
# WOA نسل 6/50 بهترین سود خالص: 9333.77
# WOA نسل 7/50 بهترین سود خالص: 9333.77
# WOA نسل 8/50 بهترین سود خالص: 9789.36
# WOA نسل 9/50 بهترین سود خالص: 9789.36
# WOA نسل 10/50 بهترین سود خالص: 9789.36
# WOA نسل 11/50 بهترین سود خالص: 9789.36
# WOA نسل 12/50 بهترین سود خالص: 9789.36
# WOA نسل 13/50 بهترین سود خالص: 9789.36
# WOA نسل 14/50 بهترین سود خالص: 9789.36
# WOA نسل 15/50 بهترین سود خالص: 9789.36
# WOA نسل 16/50 بهترین سود خالص: 9789.36
# WOA نسل 17/50 بهترین سود خالص: 9789.36
# WOA نسل 18/50 بهترین سود خالص: 9789.36
# WOA نسل 19/50 بهترین سود خالص: 9789.36
# WOA نسل 20/50 بهترین سود خالص: 9789.36
# WOA نسل 21/50 بهترین سود خالص: 9789.36
# WOA نسل 22/50 بهترین سود خالص: 9789.36
# WOA نسل 23/50 بهترین سود خالص: 9789.36
# WOA نسل 24/50 بهترین سود خالص: 9789.36
# WOA نسل 25/50 بهترین سود خالص: 9789.36
# WOA نسل 26/50 بهترین سود خالص: 9789.36
# WOA نسل 27/50 بهترین سود خالص: 9789.36
# WOA نسل 28/50 بهترین سود خالص: 9789.36
# WOA نسل 29/50 بهترین سود خالص: 9789.36
# WOA نسل 30/50 بهترین سود خالص: 9789.36
# WOA نسل 31/50 بهترین سود خالص: 9789.36
# WOA نسل 32/50 بهترین سود خالص: 9789.36
# WOA نسل 33/50 بهترین سود خالص: 9789.36
# WOA نسل 34/50 بهترین سود خالص: 9789.36
# WOA نسل 35/50 بهترین سود خالص: 9789.36
# WOA نسل 36/50 بهترین سود خالص: 9789.36
# WOA نسل 37/50 بهترین سود خالص: 9789.36
# WOA نسل 38/50 بهترین سود خالص: 9789.36
# WOA نسل 39/50 بهترین سود خالص: 9789.36
# WOA نسل 40/50 بهترین سود خالص: 9789.36
# WOA نسل 41/50 بهترین سود خالص: 9789.36
# WOA نسل 42/50 بهترین سود خالص: 9789.36
# WOA نسل 43/50 بهترین سود خالص: 10419.04
# WOA نسل 44/50 بهترین سود خالص: 10419.04
# WOA نسل 45/50 بهترین سود خالص: 10419.04
# WOA نسل 46/50 بهترین سود خالص: 10419.04
# WOA نسل 47/50 بهترین سود خالص: 10419.04
# WOA نسل 48/50 بهترین سود خالص: 10419.04
# WOA نسل 49/50 بهترین سود خالص: 10419.04
# WOA نسل 50/50 بهترین سود خالص: 10419.04
# WOA نسل 1/50 بهترین سود خالص: 7846.40
# WOA نسل 2/50 بهترین سود خالص: 7846.40
# WOA نسل 3/50 بهترین سود خالص: 8915.82
# WOA نسل 4/50 بهترین سود خالص: 8915.82
# WOA نسل 5/50 بهترین سود خالص: 8915.82
# WOA نسل 6/50 بهترین سود خالص: 9174.56
# WOA نسل 7/50 بهترین سود خالص: 9174.56
# WOA نسل 8/50 بهترین سود خالص: 9174.56
# WOA نسل 9/50 بهترین سود خالص: 9174.56
# WOA نسل 10/50 بهترین سود خالص: 9174.56
# WOA نسل 11/50 بهترین سود خالص: 9174.56
# WOA نسل 12/50 بهترین سود خالص: 9174.56
# WOA نسل 13/50 بهترین سود خالص: 9174.56
# WOA نسل 14/50 بهترین سود خالص: 9174.56
# WOA نسل 15/50 بهترین سود خالص: 9174.56
# WOA نسل 16/50 بهترین سود خالص: 9174.56
# WOA نسل 17/50 بهترین سود خالص: 9174.56
# WOA نسل 18/50 بهترین سود خالص: 9174.56
# WOA نسل 19/50 بهترین سود خالص: 9174.56
# WOA نسل 20/50 بهترین سود خالص: 9174.56
# WOA نسل 21/50 بهترین سود خالص: 9174.56
# WOA نسل 22/50 بهترین سود خالص: 9174.56
# WOA نسل 23/50 بهترین سود خالص: 9174.56
# WOA نسل 24/50 بهترین سود خالص: 9174.56
# WOA نسل 25/50 بهترین سود خالص: 9220.53
# WOA نسل 26/50 بهترین سود خالص: 9220.53
# WOA نسل 27/50 بهترین سود خالص: 9220.53
# WOA نسل 28/50 بهترین سود خالص: 9220.53
# WOA نسل 29/50 بهترین سود خالص: 9220.53
# WOA نسل 30/50 بهترین سود خالص: 9220.53
# WOA نسل 31/50 بهترین سود خالص: 9265.33
# WOA نسل 32/50 بهترین سود خالص: 9515.76
# WOA نسل 33/50 بهترین سود خالص: 9515.76
# WOA نسل 34/50 بهترین سود خالص: 9515.76
# WOA نسل 35/50 بهترین سود خالص: 9515.76
# WOA نسل 36/50 بهترین سود خالص: 9515.76
# WOA نسل 37/50 بهترین سود خالص: 9515.76
# WOA نسل 38/50 بهترین سود خالص: 9515.76
# WOA نسل 39/50 بهترین سود خالص: 9515.76
# WOA نسل 40/50 بهترین سود خالص: 9515.76
# WOA نسل 41/50 بهترین سود خالص: 9515.76
# WOA نسل 42/50 بهترین سود خالص: 9515.76
# WOA نسل 43/50 بهترین سود خالص: 9515.76
# WOA نسل 44/50 بهترین سود خالص: 9515.76
# WOA نسل 45/50 بهترین سود خالص: 9515.76
# WOA نسل 46/50 بهترین سود خالص: 9515.76
# WOA نسل 47/50 بهترین سود خالص: 9515.76
# WOA نسل 48/50 بهترین سود خالص: 9560.78
# WOA نسل 49/50 بهترین سود خالص: 9560.78
# WOA نسل 50/50 بهترین سود خالص: 9560.78
# WOA نسل 1/50 بهترین سود خالص: 8136.43
# WOA نسل 2/50 بهترین سود خالص: 8136.43
# WOA نسل 3/50 بهترین سود خالص: 9163.81
# WOA نسل 4/50 بهترین سود خالص: 9163.81
# WOA نسل 5/50 بهترین سود خالص: 9229.26
# WOA نسل 6/50 بهترین سود خالص: 9229.26
# WOA نسل 7/50 بهترین سود خالص: 9229.26
# WOA نسل 8/50 بهترین سود خالص: 9229.26
# WOA نسل 9/50 بهترین سود خالص: 9229.26
# WOA نسل 10/50 بهترین سود خالص: 9229.26
# WOA نسل 11/50 بهترین سود خالص: 9229.26
# WOA نسل 12/50 بهترین سود خالص: 9229.26
# WOA نسل 13/50 بهترین سود خالص: 9229.26
# WOA نسل 14/50 بهترین سود خالص: 9229.26
# WOA نسل 15/50 بهترین سود خالص: 9402.22
# WOA نسل 16/50 بهترین سود خالص: 9856.84
# WOA نسل 17/50 بهترین سود خالص: 9856.84
# WOA نسل 18/50 بهترین سود خالص: 9856.84
# WOA نسل 19/50 بهترین سود خالص: 9856.84
# WOA نسل 20/50 بهترین سود خالص: 10067.97
# WOA نسل 21/50 بهترین سود خالص: 10067.97
# WOA نسل 22/50 بهترین سود خالص: 10067.97
# WOA نسل 23/50 بهترین سود خالص: 10067.97
# WOA نسل 24/50 بهترین سود خالص: 10067.97
# WOA نسل 25/50 بهترین سود خالص: 10067.97
# WOA نسل 26/50 بهترین سود خالص: 10067.97
# WOA نسل 27/50 بهترین سود خالص: 10067.97
# WOA نسل 28/50 بهترین سود خالص: 10067.97
# WOA نسل 29/50 بهترین سود خالص: 10067.97
# WOA نسل 30/50 بهترین سود خالص: 10067.97
# WOA نسل 31/50 بهترین سود خالص: 10067.97
# WOA نسل 32/50 بهترین سود خالص: 10067.97
# WOA نسل 33/50 بهترین سود خالص: 10067.97
# WOA نسل 34/50 بهترین سود خالص: 10067.97
# WOA نسل 35/50 بهترین سود خالص: 11238.51
# WOA نسل 36/50 بهترین سود خالص: 11238.51
# WOA نسل 37/50 بهترین سود خالص: 11238.51
# WOA نسل 38/50 بهترین سود خالص: 11238.51
# WOA نسل 39/50 بهترین سود خالص: 11238.51
# WOA نسل 40/50 بهترین سود خالص: 11238.51
# WOA نسل 41/50 بهترین سود خالص: 11238.51
# WOA نسل 42/50 بهترین سود خالص: 11238.51
# WOA نسل 43/50 بهترین سود خالص: 11238.51
# WOA نسل 44/50 بهترین سود خالص: 11238.51
# WOA نسل 45/50 بهترین سود خالص: 11238.51
# WOA نسل 46/50 بهترین سود خالص: 11238.51
# WOA نسل 47/50 بهترین سود خالص: 11238.51
# WOA نسل 48/50 بهترین سود خالص: 11238.51
# WOA نسل 49/50 بهترین سود خالص: 11238.51
# WOA نسل 50/50 بهترین سود خالص: 11238.51
# WOA نسل 1/50 بهترین سود خالص: 6705.99
# WOA نسل 2/50 بهترین سود خالص: 6840.00
# WOA نسل 3/50 بهترین سود خالص: 6840.00
# WOA نسل 4/50 بهترین سود خالص: 6840.00
# WOA نسل 5/50 بهترین سود خالص: 6840.00
# WOA نسل 6/50 بهترین سود خالص: 8356.88
# WOA نسل 7/50 بهترین سود خالص: 8356.88
# WOA نسل 8/50 بهترین سود خالص: 8356.88
# WOA نسل 9/50 بهترین سود خالص: 8356.88
# WOA نسل 10/50 بهترین سود خالص: 8356.88
# WOA نسل 11/50 بهترین سود خالص: 8708.62
# WOA نسل 12/50 بهترین سود خالص: 8708.62
# WOA نسل 13/50 بهترین سود خالص: 8708.62
# WOA نسل 14/50 بهترین سود خالص: 8708.62
# WOA نسل 15/50 بهترین سود خالص: 8963.27
# WOA نسل 16/50 بهترین سود خالص: 8963.27
# WOA نسل 17/50 بهترین سود خالص: 8963.27
# WOA نسل 18/50 بهترین سود خالص: 8963.27
# WOA نسل 19/50 بهترین سود خالص: 8963.27
# WOA نسل 20/50 بهترین سود خالص: 8963.27
# WOA نسل 21/50 بهترین سود خالص: 8963.27
# WOA نسل 22/50 بهترین سود خالص: 8963.27
# WOA نسل 23/50 بهترین سود خالص: 8963.27
# WOA نسل 24/50 بهترین سود خالص: 8963.27
# WOA نسل 25/50 بهترین سود خالص: 8963.27
# WOA نسل 26/50 بهترین سود خالص: 8963.27
# WOA نسل 27/50 بهترین سود خالص: 8963.27
# WOA نسل 28/50 بهترین سود خالص: 8963.27
# WOA نسل 29/50 بهترین سود خالص: 8963.27
# WOA نسل 30/50 بهترین سود خالص: 8963.27
# WOA نسل 31/50 بهترین سود خالص: 9117.12
# WOA نسل 32/50 بهترین سود خالص: 9117.12
# WOA نسل 33/50 بهترین سود خالص: 9117.12
# WOA نسل 34/50 بهترین سود خالص: 9297.47
# WOA نسل 35/50 بهترین سود خالص: 9297.47
# WOA نسل 36/50 بهترین سود خالص: 9297.47
# WOA نسل 37/50 بهترین سود خالص: 9297.47
# WOA نسل 38/50 بهترین سود خالص: 9297.47
# WOA نسل 39/50 بهترین سود خالص: 9297.47
# WOA نسل 40/50 بهترین سود خالص: 9532.26
# WOA نسل 41/50 بهترین سود خالص: 9532.26
# WOA نسل 42/50 بهترین سود خالص: 9532.26
# WOA نسل 43/50 بهترین سود خالص: 9532.26
# WOA نسل 44/50 بهترین سود خالص: 9532.26
# WOA نسل 45/50 بهترین سود خالص: 9532.26
# WOA نسل 46/50 بهترین سود خالص: 9532.26
# WOA نسل 47/50 بهترین سود خالص: 9532.26
# WOA نسل 48/50 بهترین سود خالص: 9532.26
# WOA نسل 49/50 بهترین سود خالص: 9532.26
# WOA نسل 50/50 بهترین سود خالص: 10313.39
# WOA نسل 1/50 بهترین سود خالص: 6976.25
# WOA نسل 2/50 بهترین سود خالص: 9769.30
# WOA نسل 3/50 بهترین سود خالص: 9769.30
# WOA نسل 4/50 بهترین سود خالص: 9769.30
# WOA نسل 5/50 بهترین سود خالص: 9769.30
# WOA نسل 6/50 بهترین سود خالص: 9769.30
# WOA نسل 7/50 بهترین سود خالص: 9769.30
# WOA نسل 8/50 بهترین سود خالص: 9769.30
# WOA نسل 9/50 بهترین سود خالص: 9769.30
# WOA نسل 10/50 بهترین سود خالص: 9769.30
# WOA نسل 11/50 بهترین سود خالص: 9769.30
# WOA نسل 12/50 بهترین سود خالص: 9769.30
# WOA نسل 13/50 بهترین سود خالص: 9769.30
# WOA نسل 14/50 بهترین سود خالص: 9769.30
# WOA نسل 15/50 بهترین سود خالص: 9769.30
# WOA نسل 16/50 بهترین سود خالص: 9769.30
# WOA نسل 17/50 بهترین سود خالص: 9769.30
# WOA نسل 18/50 بهترین سود خالص: 9769.30
# WOA نسل 19/50 بهترین سود خالص: 9769.30
# WOA نسل 20/50 بهترین سود خالص: 9769.30
# WOA نسل 21/50 بهترین سود خالص: 9769.30
# WOA نسل 22/50 بهترین سود خالص: 9769.30
# WOA نسل 23/50 بهترین سود خالص: 9769.30
# WOA نسل 24/50 بهترین سود خالص: 9769.30
# WOA نسل 25/50 بهترین سود خالص: 9769.30
# WOA نسل 26/50 بهترین سود خالص: 9769.30
# WOA نسل 27/50 بهترین سود خالص: 9769.30
# WOA نسل 28/50 بهترین سود خالص: 9769.30
# WOA نسل 29/50 بهترین سود خالص: 9769.30
# WOA نسل 30/50 بهترین سود خالص: 9769.30
# WOA نسل 31/50 بهترین سود خالص: 9769.30
# WOA نسل 32/50 بهترین سود خالص: 9769.30
# WOA نسل 33/50 بهترین سود خالص: 10260.14
# WOA نسل 34/50 بهترین سود خالص: 10260.14
# WOA نسل 35/50 بهترین سود خالص: 10260.14
# WOA نسل 36/50 بهترین سود خالص: 10260.14
# WOA نسل 37/50 بهترین سود خالص: 10260.14
# WOA نسل 38/50 بهترین سود خالص: 10260.14
# WOA نسل 39/50 بهترین سود خالص: 10260.14
# WOA نسل 40/50 بهترین سود خالص: 10260.14
# WOA نسل 41/50 بهترین سود خالص: 10260.14
# WOA نسل 42/50 بهترین سود خالص: 10260.14
# WOA نسل 43/50 بهترین سود خالص: 10260.14
# WOA نسل 44/50 بهترین سود خالص: 10260.14
# WOA نسل 45/50 بهترین سود خالص: 10260.14
# WOA نسل 46/50 بهترین سود خالص: 10260.14
# WOA نسل 47/50 بهترین سود خالص: 10260.14
# WOA نسل 48/50 بهترین سود خالص: 10260.14
# WOA نسل 49/50 بهترین سود خالص: 10260.14
# WOA نسل 50/50 بهترین سود خالص: 10260.14
# WOA نسل 1/50 بهترین سود خالص: 10495.69
# WOA نسل 2/50 بهترین سود خالص: 10495.69
# WOA نسل 3/50 بهترین سود خالص: 10495.69
# WOA نسل 4/50 بهترین سود خالص: 10495.69
# WOA نسل 5/50 بهترین سود خالص: 10495.69
# WOA نسل 6/50 بهترین سود خالص: 10739.41
# WOA نسل 7/50 بهترین سود خالص: 10739.41
# WOA نسل 8/50 بهترین سود خالص: 10739.41
# WOA نسل 9/50 بهترین سود خالص: 10739.41
# WOA نسل 10/50 بهترین سود خالص: 10739.41
# WOA نسل 11/50 بهترین سود خالص: 10739.41
# WOA نسل 12/50 بهترین سود خالص: 10739.41
# WOA نسل 13/50 بهترین سود خالص: 10739.41
# WOA نسل 14/50 بهترین سود خالص: 10739.41
# WOA نسل 15/50 بهترین سود خالص: 10739.41
# WOA نسل 16/50 بهترین سود خالص: 10739.41
# WOA نسل 17/50 بهترین سود خالص: 10739.41
# WOA نسل 18/50 بهترین سود خالص: 10739.41
# WOA نسل 19/50 بهترین سود خالص: 10739.41
# WOA نسل 20/50 بهترین سود خالص: 10739.41
# WOA نسل 21/50 بهترین سود خالص: 10739.41
# WOA نسل 22/50 بهترین سود خالص: 10739.41
# WOA نسل 23/50 بهترین سود خالص: 10739.41
# WOA نسل 24/50 بهترین سود خالص: 10739.41
# WOA نسل 25/50 بهترین سود خالص: 10739.41
# WOA نسل 26/50 بهترین سود خالص: 10980.01
# WOA نسل 27/50 بهترین سود خالص: 10980.01
# WOA نسل 28/50 بهترین سود خالص: 10980.01
# WOA نسل 29/50 بهترین سود خالص: 10980.01
# WOA نسل 30/50 بهترین سود خالص: 10980.01
# WOA نسل 31/50 بهترین سود خالص: 10980.01
# WOA نسل 32/50 بهترین سود خالص: 10980.01
# WOA نسل 33/50 بهترین سود خالص: 10980.01
# WOA نسل 34/50 بهترین سود خالص: 10980.01
# WOA نسل 35/50 بهترین سود خالص: 10980.01
# WOA نسل 36/50 بهترین سود خالص: 10980.01
# WOA نسل 37/50 بهترین سود خالص: 10980.01
# WOA نسل 38/50 بهترین سود خالص: 11648.87
# WOA نسل 39/50 بهترین سود خالص: 11648.87
# WOA نسل 40/50 بهترین سود خالص: 11648.87
# WOA نسل 41/50 بهترین سود خالص: 11648.87
# WOA نسل 42/50 بهترین سود خالص: 11648.87
# WOA نسل 43/50 بهترین سود خالص: 11648.87
# WOA نسل 44/50 بهترین سود خالص: 11648.87
# WOA نسل 45/50 بهترین سود خالص: 11648.87
# WOA نسل 46/50 بهترین سود خالص: 11648.87
# WOA نسل 47/50 بهترین سود خالص: 11648.87
# WOA نسل 48/50 بهترین سود خالص: 11648.87
# WOA نسل 49/50 بهترین سود خالص: 11648.87
# WOA نسل 50/50 بهترین سود خالص: 11648.87
# WOA نسل 1/50 بهترین سود خالص: 7603.15
# WOA نسل 2/50 بهترین سود خالص: 7874.34
# WOA نسل 3/50 بهترین سود خالص: 8222.93
# WOA نسل 4/50 بهترین سود خالص: 10500.00
# WOA نسل 5/50 بهترین سود خالص: 10500.00
# WOA نسل 6/50 بهترین سود خالص: 10500.00
# WOA نسل 7/50 بهترین سود خالص: 10500.00
# WOA نسل 8/50 بهترین سود خالص: 11340.00
# WOA نسل 9/50 بهترین سود خالص: 11340.00
# WOA نسل 10/50 بهترین سود خالص: 11340.00
# WOA نسل 11/50 بهترین سود خالص: 11340.00
# WOA نسل 12/50 بهترین سود خالص: 11340.00
# WOA نسل 13/50 بهترین سود خالص: 11340.00
# WOA نسل 14/50 بهترین سود خالص: 11340.00
# WOA نسل 15/50 بهترین سود خالص: 11340.00
# WOA نسل 16/50 بهترین سود خالص: 11340.00
# WOA نسل 17/50 بهترین سود خالص: 11340.00
# WOA نسل 18/50 بهترین سود خالص: 11340.00
# WOA نسل 19/50 بهترین سود خالص: 11340.00
# WOA نسل 20/50 بهترین سود خالص: 11340.00
# WOA نسل 21/50 بهترین سود خالص: 11340.00
# WOA نسل 22/50 بهترین سود خالص: 11340.00
# WOA نسل 23/50 بهترین سود خالص: 11340.00
# WOA نسل 24/50 بهترین سود خالص: 11340.00
# WOA نسل 25/50 بهترین سود خالص: 11340.00
# WOA نسل 26/50 بهترین سود خالص: 11340.00
# WOA نسل 27/50 بهترین سود خالص: 11340.00
# WOA نسل 28/50 بهترین سود خالص: 11340.00
# WOA نسل 29/50 بهترین سود خالص: 11340.00
# WOA نسل 30/50 بهترین سود خالص: 11340.00
# WOA نسل 31/50 بهترین سود خالص: 11340.00
# WOA نسل 32/50 بهترین سود خالص: 11340.00
# WOA نسل 33/50 بهترین سود خالص: 11340.00
# WOA نسل 34/50 بهترین سود خالص: 11340.00
# WOA نسل 35/50 بهترین سود خالص: 11340.00
# WOA نسل 36/50 بهترین سود خالص: 11340.00
# WOA نسل 37/50 بهترین سود خالص: 11340.00
# WOA نسل 38/50 بهترین سود خالص: 11340.00
# WOA نسل 39/50 بهترین سود خالص: 11340.00
# WOA نسل 40/50 بهترین سود خالص: 11340.00
# WOA نسل 41/50 بهترین سود خالص: 11340.00
# WOA نسل 42/50 بهترین سود خالص: 11340.00
# WOA نسل 43/50 بهترین سود خالص: 11340.00
# WOA نسل 44/50 بهترین سود خالص: 11340.00
# WOA نسل 45/50 بهترین سود خالص: 11340.00
# WOA نسل 46/50 بهترین سود خالص: 11340.00
# WOA نسل 47/50 بهترین سود خالص: 11340.00
# WOA نسل 48/50 بهترین سود خالص: 11340.00
# WOA نسل 49/50 بهترین سود خالص: 11340.00
# WOA نسل 50/50 بهترین سود خالص: 11340.00
# ✅ فایل‌ها ذخیره شدند: LC_results_train_WOA.xlsx, LC_results_test_WOA.xlsx

# %%
from google.colab import files
files.download('LC_results_train_WOA.xlsx')
files.download('LC_results_test_WOA.xlsx')

# %%
import pandas as pd
import numpy as np
import random, math, time

# ===== بک‌تست مشابه GA/PSO/WOA =====
def backtest_model(df, params, model_name):
    initial_capital = 10000
    lot_size = 0.1
    stop_loss_pips = float(params.get('SL', 90))
    take_profit_pips = float(params.get('TP', 130))

    equity = initial_capital
    peak_equity = initial_capital
    trades = []

    for i in range(1, len(df)):
        signal = None
        if float(df['Close'].iloc[i]) > float(df['Close'].iloc[i - 1]):
            signal = 'BUY'
        elif float(df['Close'].iloc[i]) < float(df['Close'].iloc[i - 1]):
            signal = 'SELL'

        if signal:
            entry_price = float(df['Close'].iloc[i])
            if signal == 'BUY':
                exit_price = entry_price + (take_profit_pips * 0.0001) if np.random.rand() > 0.5 \
                             else entry_price - (stop_loss_pips * 0.0001)
            else:
                exit_price = entry_price - (take_profit_pips * 0.0001) if np.random.rand() > 0.5 \
                             else entry_price + (stop_loss_pips * 0.0001)

            profit = (exit_price - entry_price) * (100000 * lot_size) if signal == 'BUY' \
                     else (entry_price - exit_price) * (100000 * lot_size)
            equity += profit
            trades.append(profit)
            peak_equity = max(peak_equity, equity)

    net_profit = equity - initial_capital
    profit_risk = (np.mean([t for t in trades if t > 0]) / abs(np.mean([t for t in trades if t < 0]))
                   if trades and any(t < 0 for t in trades) else (np.inf if trades else 0))
    drawdown = (peak_equity - equity) / peak_equity * 100
    return net_profit, profit_risk, drawdown

# ===== الگوریتم SBO ساده =====
def sbo_optimize(df, model_name, param_bounds, pop_size=30, n_leaders=3,
                 n_followers=20, n_scouts=7, max_gen=50, exploration_coef=0.8):
    dim = len(param_bounds)
    lb = np.array([v[0] for v in param_bounds.values()])
    ub = np.array([v[1] for v in param_bounds.values()])
    keys = list(param_bounds.keys())

    positions = np.random.uniform(low=lb, high=ub, size=(pop_size, dim))
    leader_pos = np.zeros(dim)
    leader_score = -np.inf
    convergence_curve = []

    for gen in range(max_gen):
        # ارزیابی کل جمعیت
        for i in range(pop_size):
            params = {keys[j]: positions[i, j] for j in range(dim)}
            fitness, _, _ = backtest_model(df, params, model_name)
            if fitness > leader_score:
                leader_score = fitness
                leader_pos = positions[i].copy()

        # حرکت کاوشگرها و رهبرها (کد ساده، قابل تعویض با نسخه اصلی SBO)
        for i in range(pop_size):
            if i < n_leaders:
                positions[i] += np.random.uniform(-exploration_coef, exploration_coef, dim)
            else:
                positions[i] += (leader_pos - positions[i]) * np.random.uniform(0, 1, dim)

            positions[i] = np.clip(positions[i], lb, ub)

        convergence_curve.append(leader_score)
        print(f"SBO نسل {gen+1}/{max_gen} بهترین سود خالص: {leader_score:.2f}")

    best_params = {keys[j]: leader_pos[j] for j in range(dim)}
    return best_params, leader_score

# ===== Leader Correction با SBO =====
def leader_correction_sbo(train_df, test_df, models, bounds, window_size=200):
    results_train, results_test = [], []

    # sliding window روی داده آموزش
    for start in range(0, len(train_df) - window_size, window_size):
        window = train_df.iloc[start:start + window_size].reset_index(drop=True)
        winners = {}
        for model in models:
            params, score = sbo_optimize(window, model, bounds[model])
            npf, prr, dd = backtest_model(window, params, model)
            winners[model] = (npf, prr, dd, params)

        # انتخاب مدل رهبر
        leader = max(winners, key=lambda m: winners[m][0])
        best_npf, best_prr, best_dd, best_params = winners[leader]

        # نتایج قبل از بهینه‌سازی (پارامتر پایه)
        base_params = {k: float(v[0]) for k, v in bounds[leader].items()}
        base_npf, base_prr, base_dd = backtest_model(window, base_params, leader)

        results_train.append({
            'Window_Start': start,
            'Leader_Model': leader,
            **best_params,
            'Net_Profit': best_npf,
            'Profit/Risk': best_prr,
            'Drawdown': best_dd,
            '%Improvement_NP': ((best_npf - base_npf) / abs(base_npf) * 100) if base_npf != 0 else np.nan,
            '%Improvement_PR': ((best_prr - base_prr) / abs(base_prr) * 100) if base_prr != 0 else np.nan,
            '%Improvement_DD': ((base_dd - best_dd) / abs(base_dd) * 100) if base_dd != 0 else np.nan
        })

    # اجرای تست با پارامترهای بهینه هر پنجره
    for res in results_train:
        params_test = {k: float(res[k]) for k in bounds[res['Leader_Model']].keys()}
        npf, prr, dd = backtest_model(test_df, params_test, res['Leader_Model'])
        results_test.append({
            **res,
            'Net_Profit': npf,
            'Profit/Risk': prr,
            'Drawdown': dd
        })

    return pd.DataFrame(results_train), pd.DataFrame(results_test)

# ===== اجرای اصلی =====
if __name__ == "__main__":
    train_df = pd.read_csv("USDCHF_H4.csv")
    test_df = pd.read_csv("USDCHF_H4_TesT.csv")

    models = ['PPPL', 'dSMA']
    bounds = {
        'PPPL': {'n_SMA': (14, 20), 'd11': (0.1, 0.3), 'SL': (80, 120), 'TP': (120, 150)},
        'dSMA': {'n_SMA': (10, 18), 'd11': (0.05, 0.2), 'SL': (70, 110), 'TP': (110, 140)}
    }

    res_train, res_test = leader_correction_sbo(train_df, test_df, models, bounds, window_size=200)
    res_train.to_excel("LC_results_train_SBO.xlsx", index=False)
    res_test.to_excel("LC_results_test_SBO.xlsx", index=False)
    print("✅ فایل‌ها ذخیره شدند: LC_results_train_SBO.xlsx, LC_results_test_SBO.xlsx")
# Out:
# SBO نسل 1/50 بهترین سود خالص: 7754.48
# SBO نسل 2/50 بهترین سود خالص: 7993.13
# SBO نسل 3/50 بهترین سود خالص: 8112.01
# SBO نسل 4/50 بهترین سود خالص: 8321.86
# SBO نسل 5/50 بهترین سود خالص: 9564.39
# SBO نسل 6/50 بهترین سود خالص: 9564.39
# SBO نسل 7/50 بهترین سود خالص: 9564.39
# SBO نسل 8/50 بهترین سود خالص: 9564.39
# SBO نسل 9/50 بهترین سود خالص: 9580.90
# SBO نسل 10/50 بهترین سود خالص: 9580.90
# SBO نسل 11/50 بهترین سود خالص: 9580.90
# SBO نسل 12/50 بهترین سود خالص: 9580.90
# SBO نسل 13/50 بهترین سود خالص: 9580.90
# SBO نسل 14/50 بهترین سود خالص: 9580.90
# SBO نسل 15/50 بهترین سود خالص: 9580.90
# SBO نسل 16/50 بهترین سود خالص: 9680.24
# SBO نسل 17/50 بهترین سود خالص: 9680.24
# SBO نسل 18/50 بهترین سود خالص: 9680.24
# SBO نسل 19/50 بهترین سود خالص: 10010.00
# SBO نسل 20/50 بهترین سود خالص: 10010.00
# SBO نسل 21/50 بهترین سود خالص: 10010.00
# SBO نسل 22/50 بهترین سود خالص: 10715.15
# SBO نسل 23/50 بهترین سود خالص: 10715.15
# SBO نسل 24/50 بهترین سود خالص: 10715.15
# SBO نسل 25/50 بهترین سود خالص: 10715.15
# SBO نسل 26/50 بهترین سود خالص: 10715.15
# SBO نسل 27/50 بهترین سود خالص: 10715.15
# SBO نسل 28/50 بهترین سود خالص: 10715.15
# SBO نسل 29/50 بهترین سود خالص: 10715.15
# SBO نسل 30/50 بهترین سود خالص: 10715.15
# SBO نسل 31/50 بهترین سود خالص: 10715.15
# SBO نسل 32/50 بهترین سود خالص: 10715.15
# SBO نسل 33/50 بهترین سود خالص: 10715.15
# SBO نسل 34/50 بهترین سود خالص: 10715.15
# SBO نسل 35/50 بهترین سود خالص: 11169.02
# SBO نسل 36/50 بهترین سود خالص: 11169.02
# SBO نسل 37/50 بهترین سود خالص: 11169.02
# SBO نسل 38/50 بهترین سود خالص: 11169.02
# SBO نسل 39/50 بهترین سود خالص: 11169.02
# SBO نسل 40/50 بهترین سود خالص: 11169.02
# SBO نسل 41/50 بهترین سود خالص: 11169.02
# SBO نسل 42/50 بهترین سود خالص: 11169.02
# SBO نسل 43/50 بهترین سود خالص: 11169.02
# SBO نسل 44/50 بهترین سود خالص: 11169.02
# SBO نسل 45/50 بهترین سود خالص: 11169.02
# SBO نسل 46/50 بهترین سود خالص: 11169.02
# SBO نسل 47/50 بهترین سود خالص: 11169.02
# SBO نسل 48/50 بهترین سود خالص: 11169.02
# SBO نسل 49/50 بهترین سود خالص: 11169.02
# SBO نسل 50/50 بهترین سود خالص: 11169.02
# SBO نسل 1/50 بهترین سود خالص: 8779.29
# SBO نسل 2/50 بهترین سود خالص: 9916.23
# SBO نسل 3/50 بهترین سود خالص: 9916.23
# SBO نسل 4/50 بهترین سود خالص: 9916.23
# SBO نسل 5/50 بهترین سود خالص: 9916.23
# SBO نسل 6/50 بهترین سود خالص: 9916.23
# SBO نسل 7/50 بهترین سود خالص: 9916.23
# SBO نسل 8/50 بهترین سود خالص: 9916.23
# SBO نسل 9/50 بهترین سود خالص: 9916.23
# SBO نسل 10/50 بهترین سود خالص: 9916.23
# SBO نسل 11/50 بهترین سود خالص: 9916.23
# SBO نسل 12/50 بهترین سود خالص: 9916.23
# SBO نسل 13/50 بهترین سود خالص: 9916.23
# SBO نسل 14/50 بهترین سود خالص: 9916.23
# SBO نسل 15/50 بهترین سود خالص: 9916.23
# SBO نسل 16/50 بهترین سود خالص: 9916.23
# SBO نسل 17/50 بهترین سود خالص: 9916.23
# SBO نسل 18/50 بهترین سود خالص: 9916.23
# SBO نسل 19/50 بهترین سود خالص: 9916.23
# SBO نسل 20/50 بهترین سود خالص: 9916.23
# SBO نسل 21/50 بهترین سود خالص: 9916.23
# SBO نسل 22/50 بهترین سود خالص: 9916.23
# SBO نسل 23/50 بهترین سود خالص: 9916.23
# SBO نسل 24/50 بهترین سود خالص: 9916.23
# SBO نسل 25/50 بهترین سود خالص: 9916.23
# SBO نسل 26/50 بهترین سود خالص: 9916.23
# SBO نسل 27/50 بهترین سود خالص: 9916.23
# SBO نسل 28/50 بهترین سود خالص: 9916.23
# SBO نسل 29/50 بهترین سود خالص: 9916.23
# SBO نسل 30/50 بهترین سود خالص: 9916.23
# SBO نسل 31/50 بهترین سود خالص: 9916.23
# SBO نسل 32/50 بهترین سود خالص: 9916.23
# SBO نسل 33/50 بهترین سود خالص: 9916.23
# SBO نسل 34/50 بهترین سود خالص: 9916.23
# SBO نسل 35/50 بهترین سود خالص: 9916.23
# SBO نسل 36/50 بهترین سود خالص: 9916.23
# SBO نسل 37/50 بهترین سود خالص: 9916.23
# SBO نسل 38/50 بهترین سود خالص: 9916.23
# SBO نسل 39/50 بهترین سود خالص: 9916.23
# SBO نسل 40/50 بهترین سود خالص: 9916.23
# SBO نسل 41/50 بهترین سود خالص: 9916.23
# SBO نسل 42/50 بهترین سود خالص: 9916.23
# SBO نسل 43/50 بهترین سود خالص: 9916.23
# SBO نسل 44/50 بهترین سود خالص: 9916.23
# SBO نسل 45/50 بهترین سود خالص: 9916.23
# SBO نسل 46/50 بهترین سود خالص: 9916.23
# SBO نسل 47/50 بهترین سود خالص: 9916.23
# SBO نسل 48/50 بهترین سود خالص: 9916.23
# SBO نسل 49/50 بهترین سود خالص: 9916.23
# SBO نسل 50/50 بهترین سود خالص: 9916.23
# SBO نسل 1/50 بهترین سود خالص: 9107.15
# SBO نسل 2/50 بهترین سود خالص: 9107.15
# SBO نسل 3/50 بهترین سود خالص: 9107.15
# SBO نسل 4/50 بهترین سود خالص: 9107.15
# SBO نسل 5/50 بهترین سود خالص: 9107.15
# SBO نسل 6/50 بهترین سود خالص: 9107.15
# SBO نسل 7/50 بهترین سود خالص: 9107.15
# SBO نسل 8/50 بهترین سود خالص: 9107.15
# SBO نسل 9/50 بهترین سود خالص: 9107.15
# SBO نسل 10/50 بهترین سود خالص: 9107.15
# SBO نسل 11/50 بهترین سود خالص: 9107.15
# SBO نسل 12/50 بهترین سود خالص: 9107.15
# SBO نسل 13/50 بهترین سود خالص: 9107.15
# SBO نسل 14/50 بهترین سود خالص: 9107.15
# SBO نسل 15/50 بهترین سود خالص: 9107.15
# SBO نسل 16/50 بهترین سود خالص: 9107.15
# SBO نسل 17/50 بهترین سود خالص: 9107.15
# SBO نسل 18/50 بهترین سود خالص: 9107.15
# SBO نسل 19/50 بهترین سود خالص: 9107.15
# SBO نسل 20/50 بهترین سود خالص: 9107.15
# SBO نسل 21/50 بهترین سود خالص: 9107.15
# SBO نسل 22/50 بهترین سود خالص: 9107.15
# SBO نسل 23/50 بهترین سود خالص: 9107.15
# SBO نسل 24/50 بهترین سود خالص: 9107.15
# SBO نسل 25/50 بهترین سود خالص: 9107.15
# SBO نسل 26/50 بهترین سود خالص: 9107.15
# SBO نسل 27/50 بهترین سود خالص: 9107.15
# SBO نسل 28/50 بهترین سود خالص: 9107.15
# SBO نسل 29/50 بهترین سود خالص: 9107.15
# SBO نسل 30/50 بهترین سود خالص: 9107.15
# SBO نسل 31/50 بهترین سود خالص: 9107.15
# SBO نسل 32/50 بهترین سود خالص: 9107.15
# SBO نسل 33/50 بهترین سود خالص: 9107.15
# SBO نسل 34/50 بهترین سود خالص: 9107.15
# SBO نسل 35/50 بهترین سود خالص: 9107.15
# SBO نسل 36/50 بهترین سود خالص: 9107.15
# SBO نسل 37/50 بهترین سود خالص: 9107.15
# SBO نسل 38/50 بهترین سود خالص: 9107.15
# SBO نسل 39/50 بهترین سود خالص: 9107.15
# SBO نسل 40/50 بهترین سود خالص: 9107.15
# SBO نسل 41/50 بهترین سود خالص: 9107.15
# SBO نسل 42/50 بهترین سود خالص: 9358.26
# SBO نسل 43/50 بهترین سود خالص: 9358.26
# SBO نسل 44/50 بهترین سود خالص: 9358.26
# SBO نسل 45/50 بهترین سود خالص: 9358.26
# SBO نسل 46/50 بهترین سود خالص: 9358.26
# SBO نسل 47/50 بهترین سود خالص: 9358.26
# SBO نسل 48/50 بهترین سود خالص: 9358.26
# SBO نسل 49/50 بهترین سود خالص: 9358.26
# SBO نسل 50/50 بهترین سود خالص: 9358.26
# SBO نسل 1/50 بهترین سود خالص: 7018.20
# SBO نسل 2/50 بهترین سود خالص: 9722.54
# SBO نسل 3/50 بهترین سود خالص: 9722.54
# SBO نسل 4/50 بهترین سود خالص: 9722.54
# SBO نسل 5/50 بهترین سود خالص: 9722.54
# SBO نسل 6/50 بهترین سود خالص: 9722.54
# SBO نسل 7/50 بهترین سود خالص: 9722.54
# SBO نسل 8/50 بهترین سود خالص: 9722.54
# SBO نسل 9/50 بهترین سود خالص: 9722.54
# SBO نسل 10/50 بهترین سود خالص: 9722.54
# SBO نسل 11/50 بهترین سود خالص: 9722.54
# SBO نسل 12/50 بهترین سود خالص: 10154.66
# SBO نسل 13/50 بهترین سود خالص: 10154.66
# SBO نسل 14/50 بهترین سود خالص: 10154.66
# SBO نسل 15/50 بهترین سود خالص: 10154.66
# SBO نسل 16/50 بهترین سود خالص: 10154.66
# SBO نسل 17/50 بهترین سود خالص: 10154.66
# SBO نسل 18/50 بهترین سود خالص: 10154.66
# SBO نسل 19/50 بهترین سود خالص: 10154.66
# SBO نسل 20/50 بهترین سود خالص: 10154.66
# SBO نسل 21/50 بهترین سود خالص: 10154.66
# SBO نسل 22/50 بهترین سود خالص: 10154.66
# SBO نسل 23/50 بهترین سود خالص: 10154.66
# SBO نسل 24/50 بهترین سود خالص: 10154.66
# SBO نسل 25/50 بهترین سود خالص: 10154.66
# SBO نسل 26/50 بهترین سود خالص: 10154.66
# SBO نسل 27/50 بهترین سود خالص: 10154.66
# SBO نسل 28/50 بهترین سود خالص: 10154.66
# SBO نسل 29/50 بهترین سود خالص: 10154.66
# SBO نسل 30/50 بهترین سود خالص: 10154.66
# SBO نسل 31/50 بهترین سود خالص: 10154.66
# SBO نسل 32/50 بهترین سود خالص: 10154.66
# SBO نسل 33/50 بهترین سود خالص: 10154.66
# SBO نسل 34/50 بهترین سود خالص: 10154.66
# SBO نسل 35/50 بهترین سود خالص: 10154.66
# SBO نسل 36/50 بهترین سود خالص: 10154.66
# SBO نسل 37/50 بهترین سود خالص: 10154.66
# SBO نسل 38/50 بهترین سود خالص: 10154.66
# SBO نسل 39/50 بهترین سود خالص: 10154.66
# SBO نسل 40/50 بهترین سود خالص: 10154.66
# SBO نسل 41/50 بهترین سود خالص: 10154.66
# SBO نسل 42/50 بهترین سود خالص: 10154.66
# SBO نسل 43/50 بهترین سود خالص: 10154.66
# SBO نسل 44/50 بهترین سود خالص: 10154.66
# SBO نسل 45/50 بهترین سود خالص: 10154.66
# SBO نسل 46/50 بهترین سود خالص: 10154.66
# SBO نسل 47/50 بهترین سود خالص: 10154.66
# SBO نسل 48/50 بهترین سود خالص: 10154.66
# SBO نسل 49/50 بهترین سود خالص: 10154.66
# SBO نسل 50/50 بهترین سود خالص: 10154.66
# SBO نسل 1/50 بهترین سود خالص: 6311.49
# SBO نسل 2/50 بهترین سود خالص: 7305.19
# SBO نسل 3/50 بهترین سود خالص: 7549.64
# SBO نسل 4/50 بهترین سود خالص: 8506.57
# SBO نسل 5/50 بهترین سود خالص: 8506.57
# SBO نسل 6/50 بهترین سود خالص: 8506.57
# SBO نسل 7/50 بهترین سود خالص: 9422.53
# SBO نسل 8/50 بهترین سود خالص: 10122.36
# SBO نسل 9/50 بهترین سود خالص: 10122.36
# SBO نسل 10/50 بهترین سود خالص: 10122.36
# SBO نسل 11/50 بهترین سود خالص: 10122.36
# SBO نسل 12/50 بهترین سود خالص: 10122.36
# SBO نسل 13/50 بهترین سود خالص: 10122.36
# SBO نسل 14/50 بهترین سود خالص: 10122.36
# SBO نسل 15/50 بهترین سود خالص: 10122.36
# SBO نسل 16/50 بهترین سود خالص: 10122.36
# SBO نسل 17/50 بهترین سود خالص: 10122.36
# SBO نسل 18/50 بهترین سود خالص: 10122.36
# SBO نسل 19/50 بهترین سود خالص: 10122.36
# SBO نسل 20/50 بهترین سود خالص: 11055.45
# SBO نسل 21/50 بهترین سود خالص: 11055.45
# SBO نسل 22/50 بهترین سود خالص: 11055.45
# SBO نسل 23/50 بهترین سود خالص: 11055.45
# SBO نسل 24/50 بهترین سود خالص: 11055.45
# SBO نسل 25/50 بهترین سود خالص: 11055.45
# SBO نسل 26/50 بهترین سود خالص: 11055.45
# SBO نسل 27/50 بهترین سود خالص: 11055.45
# SBO نسل 28/50 بهترین سود خالص: 11055.45
# SBO نسل 29/50 بهترین سود خالص: 11055.45
# SBO نسل 30/50 بهترین سود خالص: 11055.45
# SBO نسل 31/50 بهترین سود خالص: 11055.45
# SBO نسل 32/50 بهترین سود خالص: 11055.45
# SBO نسل 33/50 بهترین سود خالص: 11055.45
# SBO نسل 34/50 بهترین سود خالص: 11055.45
# SBO نسل 35/50 بهترین سود خالص: 11055.45
# SBO نسل 36/50 بهترین سود خالص: 11055.45
# SBO نسل 37/50 بهترین سود خالص: 11055.45
# SBO نسل 38/50 بهترین سود خالص: 11055.45
# SBO نسل 39/50 بهترین سود خالص: 11055.45
# SBO نسل 40/50 بهترین سود خالص: 11055.45
# SBO نسل 41/50 بهترین سود خالص: 11055.45
# SBO نسل 42/50 بهترین سود خالص: 11055.45
# SBO نسل 43/50 بهترین سود خالص: 11055.45
# SBO نسل 44/50 بهترین سود خالص: 11055.45
# SBO نسل 45/50 بهترین سود خالص: 11055.45
# SBO نسل 46/50 بهترین سود خالص: 11055.45
# SBO نسل 47/50 بهترین سود خالص: 11055.45
# SBO نسل 48/50 بهترین سود خالص: 11055.45
# SBO نسل 49/50 بهترین سود خالص: 11055.45
# SBO نسل 50/50 بهترین سود خالص: 11055.45
# SBO نسل 1/50 بهترین سود خالص: 7644.57
# SBO نسل 2/50 بهترین سود خالص: 7644.57
# SBO نسل 3/50 بهترین سود خالص: 9309.40
# SBO نسل 4/50 بهترین سود خالص: 9728.79
# SBO نسل 5/50 بهترین سود خالص: 9728.79
# SBO نسل 6/50 بهترین سود خالص: 9728.79
# SBO نسل 7/50 بهترین سود خالص: 9728.79
# SBO نسل 8/50 بهترین سود خالص: 9728.79
# SBO نسل 9/50 بهترین سود خالص: 9728.79
# SBO نسل 10/50 بهترین سود خالص: 9728.79
# SBO نسل 11/50 بهترین سود خالص: 9728.79
# SBO نسل 12/50 بهترین سود خالص: 9728.79
# SBO نسل 13/50 بهترین سود خالص: 10156.56
# SBO نسل 14/50 بهترین سود خالص: 10156.56
# SBO نسل 15/50 بهترین سود خالص: 10156.56
# SBO نسل 16/50 بهترین سود خالص: 10156.56
# SBO نسل 17/50 بهترین سود خالص: 10156.56
# SBO نسل 18/50 بهترین سود خالص: 10156.56
# SBO نسل 19/50 بهترین سود خالص: 10156.56
# SBO نسل 20/50 بهترین سود خالص: 10156.56
# SBO نسل 21/50 بهترین سود خالص: 10156.56
# SBO نسل 22/50 بهترین سود خالص: 10156.56
# SBO نسل 23/50 بهترین سود خالص: 10156.56
# SBO نسل 24/50 بهترین سود خالص: 10156.56
# SBO نسل 25/50 بهترین سود خالص: 10156.56
# SBO نسل 26/50 بهترین سود خالص: 10156.56
# SBO نسل 27/50 بهترین سود خالص: 10156.56
# SBO نسل 28/50 بهترین سود خالص: 10156.56
# SBO نسل 29/50 بهترین سود خالص: 10156.56
# SBO نسل 30/50 بهترین سود خالص: 10156.56
# SBO نسل 31/50 بهترین سود خالص: 10156.56
# SBO نسل 32/50 بهترین سود خالص: 10156.56
# SBO نسل 33/50 بهترین سود خالص: 10156.56
# SBO نسل 34/50 بهترین سود خالص: 10156.56
# SBO نسل 35/50 بهترین سود خالص: 10156.56
# SBO نسل 36/50 بهترین سود خالص: 10156.56
# SBO نسل 37/50 بهترین سود خالص: 10156.56
# SBO نسل 38/50 بهترین سود خالص: 10156.56
# SBO نسل 39/50 بهترین سود خالص: 10156.56
# SBO نسل 40/50 بهترین سود خالص: 10156.56
# SBO نسل 41/50 بهترین سود خالص: 10583.18
# SBO نسل 42/50 بهترین سود خالص: 10583.18
# SBO نسل 43/50 بهترین سود خالص: 10583.18
# SBO نسل 44/50 بهترین سود خالص: 10583.18
# SBO نسل 45/50 بهترین سود خالص: 10583.18
# SBO نسل 46/50 بهترین سود خالص: 10583.18
# SBO نسل 47/50 بهترین سود خالص: 10583.18
# SBO نسل 48/50 بهترین سود خالص: 10583.18
# SBO نسل 49/50 بهترین سود خالص: 10583.18
# SBO نسل 50/50 بهترین سود خالص: 10583.18
# SBO نسل 1/50 بهترین سود خالص: 8431.70
# SBO نسل 2/50 بهترین سود خالص: 8868.02
# SBO نسل 3/50 بهترین سود خالص: 8868.02
# SBO نسل 4/50 بهترین سود خالص: 8930.63
# SBO نسل 5/50 بهترین سود خالص: 8930.63
# SBO نسل 6/50 بهترین سود خالص: 8930.63
# SBO نسل 7/50 بهترین سود خالص: 8930.63
# SBO نسل 8/50 بهترین سود خالص: 9572.08
# SBO نسل 9/50 بهترین سود خالص: 9572.08
# SBO نسل 10/50 بهترین سود خالص: 9572.08
# SBO نسل 11/50 بهترین سود خالص: 9572.08
# SBO نسل 12/50 بهترین سود خالص: 9572.08
# SBO نسل 13/50 بهترین سود خالص: 9572.08
# SBO نسل 14/50 بهترین سود خالص: 9572.08
# SBO نسل 15/50 بهترین سود خالص: 10033.03
# SBO نسل 16/50 بهترین سود خالص: 10033.03
# SBO نسل 17/50 بهترین سود خالص: 10033.03
# SBO نسل 18/50 بهترین سود خالص: 10263.46
# SBO نسل 19/50 بهترین سود خالص: 10263.46
# SBO نسل 20/50 بهترین سود خالص: 10263.46
# SBO نسل 21/50 بهترین سود خالص: 10263.46
# SBO نسل 22/50 بهترین سود خالص: 10263.46
# SBO نسل 23/50 بهترین سود خالص: 10263.46
# SBO نسل 24/50 بهترین سود خالص: 10263.46
# SBO نسل 25/50 بهترین سود خالص: 10263.46
# SBO نسل 26/50 بهترین سود خالص: 10263.46
# SBO نسل 27/50 بهترین سود خالص: 10263.46
# SBO نسل 28/50 بهترین سود خالص: 10263.46
# SBO نسل 29/50 بهترین سود خالص: 10263.46
# SBO نسل 30/50 بهترین سود خالص: 10263.46
# SBO نسل 31/50 بهترین سود خالص: 10263.46
# SBO نسل 32/50 بهترین سود خالص: 10263.46
# SBO نسل 33/50 بهترین سود خالص: 10263.46
# SBO نسل 34/50 بهترین سود خالص: 10263.46
# SBO نسل 35/50 بهترین سود خالص: 10263.46
# SBO نسل 36/50 بهترین سود خالص: 10263.46
# SBO نسل 37/50 بهترین سود خالص: 10263.46
# SBO نسل 38/50 بهترین سود خالص: 10263.46
# SBO نسل 39/50 بهترین سود خالص: 10263.46
# SBO نسل 40/50 بهترین سود خالص: 10263.46
# SBO نسل 41/50 بهترین سود خالص: 10263.46
# SBO نسل 42/50 بهترین سود خالص: 10263.46
# SBO نسل 43/50 بهترین سود خالص: 10263.46
# SBO نسل 44/50 بهترین سود خالص: 10263.46
# SBO نسل 45/50 بهترین سود خالص: 10724.34
# SBO نسل 46/50 بهترین سود خالص: 10724.34
# SBO نسل 47/50 بهترین سود خالص: 10724.34
# SBO نسل 48/50 بهترین سود خالص: 10954.78
# SBO نسل 49/50 بهترین سود خالص: 10954.78
# SBO نسل 50/50 بهترین سود خالص: 10954.78
# SBO نسل 1/50 بهترین سود خالص: 7876.52
# SBO نسل 2/50 بهترین سود خالص: 8351.63
# SBO نسل 3/50 بهترین سود خالص: 8351.63
# SBO نسل 4/50 بهترین سود خالص: 8351.63
# SBO نسل 5/50 بهترین سود خالص: 8351.63
# SBO نسل 6/50 بهترین سود خالص: 8351.63
# SBO نسل 7/50 بهترین سود خالص: 8661.23
# SBO نسل 8/50 بهترین سود خالص: 10224.40
# SBO نسل 9/50 بهترین سود خالص: 10224.40
# SBO نسل 10/50 بهترین سود خالص: 10224.40
# SBO نسل 11/50 بهترین سود خالص: 10224.40
# SBO نسل 12/50 بهترین سود خالص: 10224.40
# SBO نسل 13/50 بهترین سود خالص: 10224.40
# SBO نسل 14/50 بهترین سود خالص: 10224.40
# SBO نسل 15/50 بهترین سود خالص: 10224.40
# SBO نسل 16/50 بهترین سود خالص: 10224.40
# SBO نسل 17/50 بهترین سود خالص: 10224.40
# SBO نسل 18/50 بهترین سود خالص: 10224.40
# SBO نسل 19/50 بهترین سود خالص: 10224.40
# SBO نسل 20/50 بهترین سود خالص: 10224.40
# SBO نسل 21/50 بهترین سود خالص: 10224.40
# SBO نسل 22/50 بهترین سود خالص: 10224.40
# SBO نسل 23/50 بهترین سود خالص: 10224.40
# SBO نسل 24/50 بهترین سود خالص: 10224.40
# SBO نسل 25/50 بهترین سود خالص: 10224.40
# SBO نسل 26/50 بهترین سود خالص: 10224.40
# SBO نسل 27/50 بهترین سود خالص: 10224.40
# SBO نسل 28/50 بهترین سود خالص: 10224.40
# SBO نسل 29/50 بهترین سود خالص: 10224.40
# SBO نسل 30/50 بهترین سود خالص: 10224.40
# SBO نسل 31/50 بهترین سود خالص: 10224.40
# SBO نسل 32/50 بهترین سود خالص: 10224.40
# SBO نسل 33/50 بهترین سود خالص: 10224.40
# SBO نسل 34/50 بهترین سود خالص: 10224.40
# SBO نسل 35/50 بهترین سود خالص: 10224.40
# SBO نسل 36/50 بهترین سود خالص: 10224.40
# SBO نسل 37/50 بهترین سود خالص: 10224.40
# SBO نسل 38/50 بهترین سود خالص: 10224.40
# SBO نسل 39/50 بهترین سود خالص: 10224.40
# SBO نسل 40/50 بهترین سود خالص: 10224.40
# SBO نسل 41/50 بهترین سود خالص: 10224.40
# SBO نسل 42/50 بهترین سود خالص: 10224.40
# SBO نسل 43/50 بهترین سود خالص: 10224.40
# SBO نسل 44/50 بهترین سود خالص: 10224.40
# SBO نسل 45/50 بهترین سود خالص: 10224.40
# SBO نسل 46/50 بهترین سود خالص: 10224.40
# SBO نسل 47/50 بهترین سود خالص: 10224.40
# SBO نسل 48/50 بهترین سود خالص: 10224.40
# SBO نسل 49/50 بهترین سود خالص: 10224.40
# SBO نسل 50/50 بهترین سود خالص: 10224.40
# SBO نسل 1/50 بهترین سود خالص: 7133.53
# SBO نسل 2/50 بهترین سود خالص: 9609.05
# SBO نسل 3/50 بهترین سود خالص: 9609.05
# SBO نسل 4/50 بهترین سود خالص: 9609.05
# SBO نسل 5/50 بهترین سود خالص: 9609.05
# SBO نسل 6/50 بهترین سود خالص: 9609.05
# SBO نسل 7/50 بهترین سود خالص: 9609.05
# SBO نسل 8/50 بهترین سود خالص: 9609.05
# SBO نسل 9/50 بهترین سود خالص: 9609.05
# SBO نسل 10/50 بهترین سود خالص: 9609.05
# SBO نسل 11/50 بهترین سود خالص: 9609.05
# SBO نسل 12/50 بهترین سود خالص: 9609.05
# SBO نسل 13/50 بهترین سود خالص: 9609.05
# SBO نسل 14/50 بهترین سود خالص: 10292.75
# SBO نسل 15/50 بهترین سود خالص: 10292.75
# SBO نسل 16/50 بهترین سود خالص: 10292.75
# SBO نسل 17/50 بهترین سود خالص: 10292.75
# SBO نسل 18/50 بهترین سود خالص: 10292.75
# SBO نسل 19/50 بهترین سود خالص: 10292.75
# SBO نسل 20/50 بهترین سود خالص: 10292.75
# SBO نسل 21/50 بهترین سود خالص: 10292.75
# SBO نسل 22/50 بهترین سود خالص: 10292.75
# SBO نسل 23/50 بهترین سود خالص: 10292.75
# SBO نسل 24/50 بهترین سود خالص: 10292.75
# SBO نسل 25/50 بهترین سود خالص: 10292.75
# SBO نسل 26/50 بهترین سود خالص: 10292.75
# SBO نسل 27/50 بهترین سود خالص: 10292.75
# SBO نسل 28/50 بهترین سود خالص: 10292.75
# SBO نسل 29/50 بهترین سود خالص: 10292.75
# SBO نسل 30/50 بهترین سود خالص: 10292.75
# SBO نسل 31/50 بهترین سود خالص: 10292.75
# SBO نسل 32/50 بهترین سود خالص: 10292.75
# SBO نسل 33/50 بهترین سود خالص: 10292.75
# SBO نسل 34/50 بهترین سود خالص: 10292.75
# SBO نسل 35/50 بهترین سود خالص: 10292.75
# SBO نسل 36/50 بهترین سود خالص: 10292.75
# SBO نسل 37/50 بهترین سود خالص: 10292.75
# SBO نسل 38/50 بهترین سود خالص: 10292.75
# SBO نسل 39/50 بهترین سود خالص: 10292.75
# SBO نسل 40/50 بهترین سود خالص: 10292.75
# SBO نسل 41/50 بهترین سود خالص: 10292.75
# SBO نسل 42/50 بهترین سود خالص: 10292.75
# SBO نسل 43/50 بهترین سود خالص: 10292.75
# SBO نسل 44/50 بهترین سود خالص: 10292.75
# SBO نسل 45/50 بهترین سود خالص: 10292.75
# SBO نسل 46/50 بهترین سود خالص: 10292.75
# SBO نسل 47/50 بهترین سود خالص: 10292.75
# SBO نسل 48/50 بهترین سود خالص: 10292.75
# SBO نسل 49/50 بهترین سود خالص: 10292.75
# SBO نسل 50/50 بهترین سود خالص: 10292.75
# SBO نسل 1/50 بهترین سود خالص: 7238.19
# SBO نسل 2/50 بهترین سود خالص: 7387.43
# SBO نسل 3/50 بهترین سود خالص: 8068.56
# SBO نسل 4/50 بهترین سود خالص: 8196.41
# SBO نسل 5/50 بهترین سود خالص: 9827.82
# SBO نسل 6/50 بهترین سود خالص: 9827.82
# SBO نسل 7/50 بهترین سود خالص: 9827.82
# SBO نسل 8/50 بهترین سود خالص: 9827.82
# SBO نسل 9/50 بهترین سود خالص: 9827.82
# SBO نسل 10/50 بهترین سود خالص: 9827.82
# SBO نسل 11/50 بهترین سود خالص: 9827.82
# SBO نسل 12/50 بهترین سود خالص: 9827.82
# SBO نسل 13/50 بهترین سود خالص: 9827.82
# SBO نسل 14/50 بهترین سود خالص: 9827.82
# SBO نسل 15/50 بهترین سود خالص: 9827.82
# SBO نسل 16/50 بهترین سود خالص: 9827.82
# SBO نسل 17/50 بهترین سود خالص: 9827.82
# SBO نسل 18/50 بهترین سود خالص: 9827.82
# SBO نسل 19/50 بهترین سود خالص: 9827.82
# SBO نسل 20/50 بهترین سود خالص: 9827.82
# SBO نسل 21/50 بهترین سود خالص: 9827.82
# SBO نسل 22/50 بهترین سود خالص: 9827.82
# SBO نسل 23/50 بهترین سود خالص: 9827.82
# SBO نسل 24/50 بهترین سود خالص: 9827.82
# SBO نسل 25/50 بهترین سود خالص: 9827.82
# SBO نسل 26/50 بهترین سود خالص: 9827.82
# SBO نسل 27/50 بهترین سود خالص: 9827.82
# SBO نسل 28/50 بهترین سود خالص: 10709.46
# SBO نسل 29/50 بهترین سود خالص: 10709.46
# SBO نسل 30/50 بهترین سود خالص: 10709.46
# SBO نسل 31/50 بهترین سود خالص: 10709.46
# SBO نسل 32/50 بهترین سود خالص: 10709.46
# SBO نسل 33/50 بهترین سود خالص: 10709.46
# SBO نسل 34/50 بهترین سود خالص: 10709.46
# SBO نسل 35/50 بهترین سود خالص: 10709.46
# SBO نسل 36/50 بهترین سود خالص: 10709.46
# SBO نسل 37/50 بهترین سود خالص: 10709.46
# SBO نسل 38/50 بهترین سود خالص: 10709.46
# SBO نسل 39/50 بهترین سود خالص: 10709.46
# SBO نسل 40/50 بهترین سود خالص: 10709.46
# SBO نسل 41/50 بهترین سود خالص: 10709.46
# SBO نسل 42/50 بهترین سود خالص: 10709.46
# SBO نسل 43/50 بهترین سود خالص: 10709.46
# SBO نسل 44/50 بهترین سود خالص: 10709.46
# SBO نسل 45/50 بهترین سود خالص: 10709.46
# SBO نسل 46/50 بهترین سود خالص: 10709.46
# SBO نسل 47/50 بهترین سود خالص: 10709.46
# SBO نسل 48/50 بهترین سود خالص: 10709.46
# SBO نسل 49/50 بهترین سود خالص: 10709.46
# SBO نسل 50/50 بهترین سود خالص: 10709.46
# SBO نسل 1/50 بهترین سود خالص: 8207.85
# SBO نسل 2/50 بهترین سود خالص: 8207.85
# SBO نسل 3/50 بهترین سود خالص: 8919.17
# SBO نسل 4/50 بهترین سود خالص: 9216.25
# SBO نسل 5/50 بهترین سود خالص: 9216.25
# SBO نسل 6/50 بهترین سود خالص: 9216.25
# SBO نسل 7/50 بهترین سود خالص: 9216.25
# SBO نسل 8/50 بهترین سود خالص: 9931.73
# SBO نسل 9/50 بهترین سود خالص: 10161.71
# SBO نسل 10/50 بهترین سود خالص: 10161.71
# SBO نسل 11/50 بهترین سود خالص: 10161.71
# SBO نسل 12/50 بهترین سود خالص: 10161.71
# SBO نسل 13/50 بهترین سود خالص: 10161.71
# SBO نسل 14/50 بهترین سود خالص: 10161.71
# SBO نسل 15/50 بهترین سود خالص: 10161.71
# SBO نسل 16/50 بهترین سود خالص: 10161.71
# SBO نسل 17/50 بهترین سود خالص: 10161.71
# SBO نسل 18/50 بهترین سود خالص: 10161.71
# SBO نسل 19/50 بهترین سود خالص: 10161.71
# SBO نسل 20/50 بهترین سود خالص: 10161.71
# SBO نسل 21/50 بهترین سود خالص: 10161.71
# SBO نسل 22/50 بهترین سود خالص: 10161.71
# SBO نسل 23/50 بهترین سود خالص: 10161.71
# SBO نسل 24/50 بهترین سود خالص: 10161.71
# SBO نسل 25/50 بهترین سود خالص: 10161.71
# SBO نسل 26/50 بهترین سود خالص: 10161.71
# SBO نسل 27/50 بهترین سود خالص: 10161.71
# SBO نسل 28/50 بهترین سود خالص: 10161.71
# SBO نسل 29/50 بهترین سود خالص: 10161.71
# SBO نسل 30/50 بهترین سود خالص: 10161.71
# SBO نسل 31/50 بهترین سود خالص: 10161.71
# SBO نسل 32/50 بهترین سود خالص: 10161.71
# SBO نسل 33/50 بهترین سود خالص: 10161.71
# SBO نسل 34/50 بهترین سود خالص: 10161.71
# SBO نسل 35/50 بهترین سود خالص: 10161.71
# SBO نسل 36/50 بهترین سود خالص: 10161.71
# SBO نسل 37/50 بهترین سود خالص: 10161.71
# SBO نسل 38/50 بهترین سود خالص: 10161.71
# SBO نسل 39/50 بهترین سود خالص: 10161.71
# SBO نسل 40/50 بهترین سود خالص: 10161.71
# SBO نسل 41/50 بهترین سود خالص: 10161.71
# SBO نسل 42/50 بهترین سود خالص: 10161.71
# SBO نسل 43/50 بهترین سود خالص: 10161.71
# SBO نسل 44/50 بهترین سود خالص: 10161.71
# SBO نسل 45/50 بهترین سود خالص: 10161.71
# SBO نسل 46/50 بهترین سود خالص: 10161.71
# SBO نسل 47/50 بهترین سود خالص: 10161.71
# SBO نسل 48/50 بهترین سود خالص: 10161.71
# SBO نسل 49/50 بهترین سود خالص: 10161.71
# SBO نسل 50/50 بهترین سود خالص: 10161.71
# SBO نسل 1/50 بهترین سود خالص: 7225.41
# SBO نسل 2/50 بهترین سود خالص: 7464.34
# SBO نسل 3/50 بهترین سود خالص: 7464.34
# SBO نسل 4/50 بهترین سود خالص: 8960.49
# SBO نسل 5/50 بهترین سود خالص: 8960.49
# SBO نسل 6/50 بهترین سود خالص: 8960.49
# SBO نسل 7/50 بهترین سود خالص: 8960.49
# SBO نسل 8/50 بهترین سود خالص: 8960.49
# SBO نسل 9/50 بهترین سود خالص: 9046.60
# SBO نسل 10/50 بهترین سود خالص: 9046.60
# SBO نسل 11/50 بهترین سود خالص: 9046.60
# SBO نسل 12/50 بهترین سود خالص: 9046.60
# SBO نسل 13/50 بهترین سود خالص: 9046.60
# SBO نسل 14/50 بهترین سود خالص: 9046.60
# SBO نسل 15/50 بهترین سود خالص: 9046.60
# SBO نسل 16/50 بهترین سود خالص: 9046.60
# SBO نسل 17/50 بهترین سود خالص: 9046.60
# SBO نسل 18/50 بهترین سود خالص: 9046.60
# SBO نسل 19/50 بهترین سود خالص: 9046.60
# SBO نسل 20/50 بهترین سود خالص: 9046.60
# SBO نسل 21/50 بهترین سود خالص: 9046.60
# SBO نسل 22/50 بهترین سود خالص: 9046.60
# SBO نسل 23/50 بهترین سود خالص: 9046.60
# SBO نسل 24/50 بهترین سود خالص: 9046.60
# SBO نسل 25/50 بهترین سود خالص: 9046.60
# SBO نسل 26/50 بهترین سود خالص: 9046.60
# SBO نسل 27/50 بهترین سود خالص: 9046.60
# SBO نسل 28/50 بهترین سود خالص: 9046.60
# SBO نسل 29/50 بهترین سود خالص: 9467.03
# SBO نسل 30/50 بهترین سود خالص: 9467.03
# SBO نسل 31/50 بهترین سود خالص: 9467.03
# SBO نسل 32/50 بهترین سود خالص: 9467.03
# SBO نسل 33/50 بهترین سود خالص: 9467.03
# SBO نسل 34/50 بهترین سود خالص: 9467.03
# SBO نسل 35/50 بهترین سود خالص: 9467.03
# SBO نسل 36/50 بهترین سود خالص: 9467.03
# SBO نسل 37/50 بهترین سود خالص: 9467.03
# SBO نسل 38/50 بهترین سود خالص: 9467.03
# SBO نسل 39/50 بهترین سود خالص: 9467.03
# SBO نسل 40/50 بهترین سود خالص: 9467.03
# SBO نسل 41/50 بهترین سود خالص: 9467.03
# SBO نسل 42/50 بهترین سود خالص: 9467.03
# SBO نسل 43/50 بهترین سود خالص: 9467.03
# SBO نسل 44/50 بهترین سود خالص: 9887.47
# SBO نسل 45/50 بهترین سود خالص: 9887.47
# SBO نسل 46/50 بهترین سود خالص: 9887.47
# SBO نسل 47/50 بهترین سود خالص: 9887.47
# SBO نسل 48/50 بهترین سود خالص: 9887.47
# SBO نسل 49/50 بهترین سود خالص: 9887.47
# SBO نسل 50/50 بهترین سود خالص: 9887.47
# SBO نسل 1/50 بهترین سود خالص: 7095.19
# SBO نسل 2/50 بهترین سود خالص: 7866.38
# SBO نسل 3/50 بهترین سود خالص: 7866.38
# SBO نسل 4/50 بهترین سود خالص: 8579.38
# SBO نسل 5/50 بهترین سود خالص: 8579.38
# SBO نسل 6/50 بهترین سود خالص: 8579.38
# SBO نسل 7/50 بهترین سود خالص: 8817.53
# SBO نسل 8/50 بهترین سود خالص: 8817.53
# SBO نسل 9/50 بهترین سود خالص: 8817.53
# SBO نسل 10/50 بهترین سود خالص: 8817.53
# SBO نسل 11/50 بهترین سود خالص: 8817.53
# SBO نسل 12/50 بهترین سود خالص: 8817.53
# SBO نسل 13/50 بهترین سود خالص: 8817.53
# SBO نسل 14/50 بهترین سود خالص: 8817.53
# SBO نسل 15/50 بهترین سود خالص: 8817.53
# SBO نسل 16/50 بهترین سود خالص: 8817.53
# SBO نسل 17/50 بهترین سود خالص: 8817.53
# SBO نسل 18/50 بهترین سود خالص: 8817.53
# SBO نسل 19/50 بهترین سود خالص: 8817.53
# SBO نسل 20/50 بهترین سود خالص: 8817.53
# SBO نسل 21/50 بهترین سود خالص: 9304.08
# SBO نسل 22/50 بهترین سود خالص: 9304.08
# SBO نسل 23/50 بهترین سود خالص: 9304.08
# SBO نسل 24/50 بهترین سود خالص: 9304.08
# SBO نسل 25/50 بهترین سود خالص: 9304.08
# SBO نسل 26/50 بهترین سود خالص: 9304.08
# SBO نسل 27/50 بهترین سود خالص: 9304.08
# SBO نسل 28/50 بهترین سود خالص: 9790.64
# SBO نسل 29/50 بهترین سود خالص: 9790.64
# SBO نسل 30/50 بهترین سود خالص: 9790.64
# SBO نسل 31/50 بهترین سود خالص: 9790.64
# SBO نسل 32/50 بهترین سود خالص: 9790.64
# SBO نسل 33/50 بهترین سود خالص: 9790.64
# SBO نسل 34/50 بهترین سود خالص: 9790.64
# SBO نسل 35/50 بهترین سود خالص: 9790.64
# SBO نسل 36/50 بهترین سود خالص: 9790.64
# SBO نسل 37/50 بهترین سود خالص: 9790.64
# SBO نسل 38/50 بهترین سود خالص: 9790.64
# SBO نسل 39/50 بهترین سود خالص: 9790.64
# SBO نسل 40/50 بهترین سود خالص: 9790.64
# SBO نسل 41/50 بهترین سود خالص: 9790.64
# SBO نسل 42/50 بهترین سود خالص: 9790.64
# SBO نسل 43/50 بهترین سود خالص: 9790.64
# SBO نسل 44/50 بهترین سود خالص: 9790.64
# SBO نسل 45/50 بهترین سود خالص: 9790.64
# SBO نسل 46/50 بهترین سود خالص: 9790.64
# SBO نسل 47/50 بهترین سود خالص: 9790.64
# SBO نسل 48/50 بهترین سود خالص: 9790.64
# SBO نسل 49/50 بهترین سود خالص: 9790.64
# SBO نسل 50/50 بهترین سود خالص: 9790.64
# SBO نسل 1/50 بهترین سود خالص: 6804.29
# SBO نسل 2/50 بهترین سود خالص: 7370.11
# SBO نسل 3/50 بهترین سود خالص: 7808.06
# SBO نسل 4/50 بهترین سود خالص: 7808.06
# SBO نسل 5/50 بهترین سود خالص: 7808.06
# SBO نسل 6/50 بهترین سود خالص: 7819.08
# SBO نسل 7/50 بهترین سود خالص: 7819.08
# SBO نسل 8/50 بهترین سود خالص: 8665.55
# SBO نسل 9/50 بهترین سود خالص: 8665.55
# SBO نسل 10/50 بهترین سود خالص: 8668.02
# SBO نسل 11/50 بهترین سود خالص: 8668.02
# SBO نسل 12/50 بهترین سود خالص: 8668.02
# SBO نسل 13/50 بهترین سود خالص: 8668.02
# SBO نسل 14/50 بهترین سود خالص: 8668.02
# SBO نسل 15/50 بهترین سود خالص: 8668.02
# SBO نسل 16/50 بهترین سود خالص: 8668.02
# SBO نسل 17/50 بهترین سود خالص: 9105.22
# SBO نسل 18/50 بهترین سود خالص: 9105.22
# SBO نسل 19/50 بهترین سود خالص: 9105.22
# SBO نسل 20/50 بهترین سود خالص: 9105.22
# SBO نسل 21/50 بهترین سود خالص: 9542.45
# SBO نسل 22/50 بهترین سود خالص: 9542.45
# SBO نسل 23/50 بهترین سود خالص: 9542.45
# SBO نسل 24/50 بهترین سود خالص: 9542.45
# SBO نسل 25/50 بهترین سود خالص: 9542.45
# SBO نسل 26/50 بهترین سود خالص: 9542.45
# SBO نسل 27/50 بهترین سود خالص: 9542.45
# SBO نسل 28/50 بهترین سود خالص: 9542.45
# SBO نسل 29/50 بهترین سود خالص: 9542.45
# SBO نسل 30/50 بهترین سود خالص: 9542.45
# SBO نسل 31/50 بهترین سود خالص: 9542.45
# SBO نسل 32/50 بهترین سود خالص: 9542.45
# SBO نسل 33/50 بهترین سود خالص: 9542.45
# SBO نسل 34/50 بهترین سود خالص: 9542.45
# SBO نسل 35/50 بهترین سود خالص: 9542.45
# SBO نسل 36/50 بهترین سود خالص: 9542.45
# SBO نسل 37/50 بهترین سود خالص: 9542.45
# SBO نسل 38/50 بهترین سود خالص: 9542.45
# SBO نسل 39/50 بهترین سود خالص: 9542.45
# SBO نسل 40/50 بهترین سود خالص: 9542.45
# SBO نسل 41/50 بهترین سود خالص: 9542.45
# SBO نسل 42/50 بهترین سود خالص: 9542.45
# SBO نسل 43/50 بهترین سود خالص: 9542.45
# SBO نسل 44/50 بهترین سود خالص: 9542.45
# SBO نسل 45/50 بهترین سود خالص: 9542.45
# SBO نسل 46/50 بهترین سود خالص: 9542.45
# SBO نسل 47/50 بهترین سود خالص: 9542.45
# SBO نسل 48/50 بهترین سود خالص: 9542.45
# SBO نسل 49/50 بهترین سود خالص: 9542.45
# SBO نسل 50/50 بهترین سود خالص: 9979.68
# SBO نسل 1/50 بهترین سود خالص: 6520.77
# SBO نسل 2/50 بهترین سود خالص: 6520.77
# SBO نسل 3/50 بهترین سود خالص: 6846.80
# SBO نسل 4/50 بهترین سود خالص: 7138.01
# SBO نسل 5/50 بهترین سود خالص: 7336.20
# SBO نسل 6/50 بهترین سود خالص: 7336.20
# SBO نسل 7/50 بهترین سود خالص: 7336.20
# SBO نسل 8/50 بهترین سود خالص: 7336.20
# SBO نسل 9/50 بهترین سود خالص: 7336.20
# SBO نسل 10/50 بهترین سود خالص: 7336.20
# SBO نسل 11/50 بهترین سود خالص: 7336.20
# SBO نسل 12/50 بهترین سود خالص: 7336.20
# SBO نسل 13/50 بهترین سود خالص: 7336.20
# SBO نسل 14/50 بهترین سود خالص: 7336.20
# SBO نسل 15/50 بهترین سود خالص: 7336.20
# SBO نسل 16/50 بهترین سود خالص: 7336.20
# SBO نسل 17/50 بهترین سود خالص: 7767.42
# SBO نسل 18/50 بهترین سود خالص: 7767.42
# SBO نسل 19/50 بهترین سود خالص: 7767.42
# SBO نسل 20/50 بهترین سود خالص: 7767.42
# SBO نسل 21/50 بهترین سود خالص: 7767.42
# SBO نسل 22/50 بهترین سود خالص: 7983.03
# SBO نسل 23/50 بهترین سود خالص: 7983.03
# SBO نسل 24/50 بهترین سود خالص: 7983.03
# SBO نسل 25/50 بهترین سود خالص: 7983.03
# SBO نسل 26/50 بهترین سود خالص: 7983.03
# SBO نسل 27/50 بهترین سود خالص: 7983.03
# SBO نسل 28/50 بهترین سود خالص: 7983.03
# SBO نسل 29/50 بهترین سود خالص: 7983.03
# SBO نسل 30/50 بهترین سود خالص: 7983.03
# SBO نسل 31/50 بهترین سود خالص: 7983.03
# SBO نسل 32/50 بهترین سود خالص: 7983.03
# SBO نسل 33/50 بهترین سود خالص: 7983.03
# SBO نسل 34/50 بهترین سود خالص: 8198.63
# SBO نسل 35/50 بهترین سود خالص: 8198.63
# SBO نسل 36/50 بهترین سود خالص: 8198.63
# SBO نسل 37/50 بهترین سود خالص: 8590.52
# SBO نسل 38/50 بهترین سود خالص: 8590.52
# SBO نسل 39/50 بهترین سود خالص: 8590.52
# SBO نسل 40/50 بهترین سود خالص: 8590.52
# SBO نسل 41/50 بهترین سود خالص: 8590.52
# SBO نسل 42/50 بهترین سود خالص: 8590.52
# SBO نسل 43/50 بهترین سود خالص: 8590.52
# SBO نسل 44/50 بهترین سود خالص: 8590.52
# SBO نسل 45/50 بهترین سود خالص: 8590.52
# SBO نسل 46/50 بهترین سود خالص: 8590.52
# SBO نسل 47/50 بهترین سود خالص: 8590.52
# SBO نسل 48/50 بهترین سود خالص: 8590.52
# SBO نسل 49/50 بهترین سود خالص: 8590.52
# SBO نسل 50/50 بهترین سود خالص: 8590.52
# SBO نسل 1/50 بهترین سود خالص: 6837.21
# SBO نسل 2/50 بهترین سود خالص: 8899.09
# SBO نسل 3/50 بهترین سود خالص: 8899.09
# SBO نسل 4/50 بهترین سود خالص: 8899.09
# SBO نسل 5/50 بهترین سود خالص: 8899.09
# SBO نسل 6/50 بهترین سود خالص: 8899.09
# SBO نسل 7/50 بهترین سود خالص: 8899.09
# SBO نسل 8/50 بهترین سود خالص: 8899.09
# SBO نسل 9/50 بهترین سود خالص: 8899.09
# SBO نسل 10/50 بهترین سود خالص: 8899.09
# SBO نسل 11/50 بهترین سود خالص: 8899.09
# SBO نسل 12/50 بهترین سود خالص: 8899.09
# SBO نسل 13/50 بهترین سود خالص: 8899.09
# SBO نسل 14/50 بهترین سود خالص: 8899.09
# SBO نسل 15/50 بهترین سود خالص: 8899.09
# SBO نسل 16/50 بهترین سود خالص: 9318.01
# SBO نسل 17/50 بهترین سود خالص: 9318.01
# SBO نسل 18/50 بهترین سود خالص: 9318.01
# SBO نسل 19/50 بهترین سود خالص: 9318.01
# SBO نسل 20/50 بهترین سود خالص: 9318.01
# SBO نسل 21/50 بهترین سود خالص: 9318.01
# SBO نسل 22/50 بهترین سود خالص: 9318.01
# SBO نسل 23/50 بهترین سود خالص: 9318.01
# SBO نسل 24/50 بهترین سود خالص: 9318.01
# SBO نسل 25/50 بهترین سود خالص: 9318.01
# SBO نسل 26/50 بهترین سود خالص: 9318.01
# SBO نسل 27/50 بهترین سود خالص: 9318.01
# SBO نسل 28/50 بهترین سود خالص: 9318.01
# SBO نسل 29/50 بهترین سود خالص: 9318.01
# SBO نسل 30/50 بهترین سود خالص: 9318.01
# SBO نسل 31/50 بهترین سود خالص: 9318.01
# SBO نسل 32/50 بهترین سود خالص: 9318.01
# SBO نسل 33/50 بهترین سود خالص: 9318.01
# SBO نسل 34/50 بهترین سود خالص: 9318.01
# SBO نسل 35/50 بهترین سود خالص: 9527.47
# SBO نسل 36/50 بهترین سود خالص: 9527.47
# SBO نسل 37/50 بهترین سود خالص: 9527.47
# SBO نسل 38/50 بهترین سود خالص: 9527.47
# SBO نسل 39/50 بهترین سود خالص: 9527.47
# SBO نسل 40/50 بهترین سود خالص: 9527.47
# SBO نسل 41/50 بهترین سود خالص: 9527.47
# SBO نسل 42/50 بهترین سود خالص: 9527.47
# SBO نسل 43/50 بهترین سود خالص: 9527.47
# SBO نسل 44/50 بهترین سود خالص: 9527.47
# SBO نسل 45/50 بهترین سود خالص: 9527.47
# SBO نسل 46/50 بهترین سود خالص: 9527.47
# SBO نسل 47/50 بهترین سود خالص: 9527.47
# SBO نسل 48/50 بهترین سود خالص: 9527.47
# SBO نسل 49/50 بهترین سود خالص: 9527.47
# SBO نسل 50/50 بهترین سود خالص: 9527.47
# SBO نسل 1/50 بهترین سود خالص: 8364.56
# SBO نسل 2/50 بهترین سود خالص: 9487.84
# SBO نسل 3/50 بهترین سود خالص: 9487.84
# SBO نسل 4/50 بهترین سود خالص: 9487.84
# SBO نسل 5/50 بهترین سود خالص: 9487.84
# SBO نسل 6/50 بهترین سود خالص: 9487.84
# SBO نسل 7/50 بهترین سود خالص: 9487.84
# SBO نسل 8/50 بهترین سود خالص: 9487.84
# SBO نسل 9/50 بهترین سود خالص: 9487.84
# SBO نسل 10/50 بهترین سود خالص: 9487.84
# SBO نسل 11/50 بهترین سود خالص: 9487.84
# SBO نسل 12/50 بهترین سود خالص: 9487.84
# SBO نسل 13/50 بهترین سود خالص: 9487.84
# SBO نسل 14/50 بهترین سود خالص: 9487.84
# SBO نسل 15/50 بهترین سود خالص: 9487.84
# SBO نسل 16/50 بهترین سود خالص: 9487.84
# SBO نسل 17/50 بهترین سود خالص: 9487.84
# SBO نسل 18/50 بهترین سود خالص: 9487.84
# SBO نسل 19/50 بهترین سود خالص: 9487.84
# SBO نسل 20/50 بهترین سود خالص: 9487.84
# SBO نسل 21/50 بهترین سود خالص: 9487.84
# SBO نسل 22/50 بهترین سود خالص: 9487.84
# SBO نسل 23/50 بهترین سود خالص: 9487.84
# SBO نسل 24/50 بهترین سود خالص: 9487.84
# SBO نسل 25/50 بهترین سود خالص: 9487.84
# SBO نسل 26/50 بهترین سود خالص: 9487.84
# SBO نسل 27/50 بهترین سود خالص: 9487.84
# SBO نسل 28/50 بهترین سود خالص: 9487.84
# SBO نسل 29/50 بهترین سود خالص: 10137.74
# SBO نسل 30/50 بهترین سود خالص: 10137.74
# SBO نسل 31/50 بهترین سود خالص: 10137.74
# SBO نسل 32/50 بهترین سود خالص: 10137.74
# SBO نسل 33/50 بهترین سود خالص: 10137.74
# SBO نسل 34/50 بهترین سود خالص: 10137.74
# SBO نسل 35/50 بهترین سود خالص: 10137.74
# SBO نسل 36/50 بهترین سود خالص: 10137.74
# SBO نسل 37/50 بهترین سود خالص: 10137.74
# SBO نسل 38/50 بهترین سود خالص: 10137.74
# SBO نسل 39/50 بهترین سود خالص: 10137.74
# SBO نسل 40/50 بهترین سود خالص: 10137.74
# SBO نسل 41/50 بهترین سود خالص: 10137.74
# SBO نسل 42/50 بهترین سود خالص: 10137.74
# SBO نسل 43/50 بهترین سود خالص: 10137.74
# SBO نسل 44/50 بهترین سود خالص: 10137.74
# SBO نسل 45/50 بهترین سود خالص: 10137.74
# SBO نسل 46/50 بهترین سود خالص: 10137.74
# SBO نسل 47/50 بهترین سود خالص: 10137.74
# SBO نسل 48/50 بهترین سود خالص: 10137.74
# SBO نسل 49/50 بهترین سود خالص: 10137.74
# SBO نسل 50/50 بهترین سود خالص: 10137.74
# SBO نسل 1/50 بهترین سود خالص: 6413.72
# SBO نسل 2/50 بهترین سود خالص: 7359.81
# SBO نسل 3/50 بهترین سود خالص: 8440.03
# SBO نسل 4/50 بهترین سود خالص: 8440.03
# SBO نسل 5/50 بهترین سود خالص: 8440.03
# SBO نسل 6/50 بهترین سود خالص: 8440.03
# SBO نسل 7/50 بهترین سود خالص: 8440.03
# SBO نسل 8/50 بهترین سود خالص: 8672.18
# SBO نسل 9/50 بهترین سود خالص: 8672.18
# SBO نسل 10/50 بهترین سود خالص: 9739.62
# SBO نسل 11/50 بهترین سود خالص: 9739.62
# SBO نسل 12/50 بهترین سود خالص: 9739.62
# SBO نسل 13/50 بهترین سود خالص: 9739.62
# SBO نسل 14/50 بهترین سود خالص: 9739.62
# SBO نسل 15/50 بهترین سود خالص: 9739.62
# SBO نسل 16/50 بهترین سود خالص: 9953.47
# SBO نسل 17/50 بهترین سود خالص: 9953.47
# SBO نسل 18/50 بهترین سود خالص: 9953.47
# SBO نسل 19/50 بهترین سود خالص: 9953.47
# SBO نسل 20/50 بهترین سود خالص: 9953.47
# SBO نسل 21/50 بهترین سود خالص: 9953.47
# SBO نسل 22/50 بهترین سود خالص: 9953.47
# SBO نسل 23/50 بهترین سود خالص: 9953.47
# SBO نسل 24/50 بهترین سود خالص: 9953.47
# SBO نسل 25/50 بهترین سود خالص: 9953.47
# SBO نسل 26/50 بهترین سود خالص: 9953.47
# SBO نسل 27/50 بهترین سود خالص: 9953.47
# SBO نسل 28/50 بهترین سود خالص: 9953.47
# SBO نسل 29/50 بهترین سود خالص: 9953.47
# SBO نسل 30/50 بهترین سود خالص: 9953.47
# SBO نسل 31/50 بهترین سود خالص: 9953.47
# SBO نسل 32/50 بهترین سود خالص: 9953.47
# SBO نسل 33/50 بهترین سود خالص: 9953.47
# SBO نسل 34/50 بهترین سود خالص: 9953.47
# SBO نسل 35/50 بهترین سود خالص: 9953.47
# SBO نسل 36/50 بهترین سود خالص: 9953.47
# SBO نسل 37/50 بهترین سود خالص: 9953.47
# SBO نسل 38/50 بهترین سود خالص: 9953.47
# SBO نسل 39/50 بهترین سود خالص: 9953.47
# SBO نسل 40/50 بهترین سود خالص: 9953.47
# SBO نسل 41/50 بهترین سود خالص: 9953.47
# SBO نسل 42/50 بهترین سود خالص: 9953.47
# SBO نسل 43/50 بهترین سود خالص: 9953.47
# SBO نسل 44/50 بهترین سود خالص: 9953.47
# SBO نسل 45/50 بهترین سود خالص: 9953.47
# SBO نسل 46/50 بهترین سود خالص: 9953.47
# SBO نسل 47/50 بهترین سود خالص: 9953.47
# SBO نسل 48/50 بهترین سود خالص: 9953.47
# SBO نسل 49/50 بهترین سود خالص: 9953.47
# SBO نسل 50/50 بهترین سود خالص: 9953.47
# ✅ فایل‌ها ذخیره شدند: LC_results_train_SBO.xlsx, LC_results_test_SBO.xlsx

# %%
from google.colab import files
files.download('LC_results_train_SBO.xlsx')
files.download('LC_results_test_SBO.xlsx')
